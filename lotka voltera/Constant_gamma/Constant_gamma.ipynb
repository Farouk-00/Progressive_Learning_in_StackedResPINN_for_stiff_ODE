# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
class MLP(tf.Module):
    """
    Multi-Layer Perceptron (MLP) class with regularization handling.

    --------------
    insize: input size (int)
    outsize: output size (int)
    hsize: A list specifying the number of neurons in each hidden layer (list of ints).
    bias: Boolean indicating whether to include a bias term in the linear layers (default: True)
    nonlin: The activation function to be used in the hidden layers (default: nn.Tanh).
    linear_map:  The type of linear transformation to be used (default: nn.Linear)
    """
    def __init__(self, insize, outsize, hsizes, bias=True, nonlin=tf.tanh, linear_map=tf.keras.layers.Dense):
        super().__init__()
        self.in_features, self.out_features = insize, outsize
        self.nhidden = len(hsizes)
        self.layers = []
        self.nonlin = []
        self.seed = 123
        # Create linear layers and activation functions
        layer_sizes = [insize] + hsizes + [outsize]
        for k in range(len(layer_sizes) - 1):
            initializer = tf.keras.initializers.GlorotUniform(self.seed+k)
            self.layers.append(linear_map(units=layer_sizes[k+1], use_bias=bias, kernel_initializer=initializer))
            if k < self.nhidden:
                self.nonlin.append(nonlin)
            else:
                self.nonlin.append(tf.identity)

    def __call__(self, x):
        for i in range(len(self.layers)):
            x = self.nonlin[i](self.layers[i](x))
        return x

    def reg_error(self):
        """
        Compute the regularization error for the linear layers that support it.
        """
        reg_loss = 0.0
        for layer in self.layers:
            if hasattr(layer, "reg_error"):
                reg_loss += layer.reg_error()
        return reg_loss

# %%
class ResNetBlock(tf.Module):
    """
    A single ResNet block that takes the current output (from the previous layer or from the single-fidelity model)
    and the original input x, and learns a residual mapping.

    The block computes:
    out_new = out_old + alpha * F(x)

    F is implemented by an MLP.
    """
    def __init__(self, in_dim_x, in_dim_out, hres_sizes=[20, 20], bias=True, nonlin=tf.tanh):
        """
        in_dim_x : int, dimension of input x
        in_dim_out : int, dimension of the output (u)
        hres_sizes : list of ints, hidden layer sizes for the residual MLP
        bias : bool, whether to include bias in MLP layers
        nonlin : activation function class (e.g., nn.Tanh)
        """
        super().__init__()
        self.res_mlp = MLP(in_dim_x, in_dim_out, hsizes=hres_sizes, bias=bias, nonlin=nonlin)

    def __call__(self, x, out_old, alpha):
        """
        Forward pass of the ResNet block.

        x: tensor of shape (N, in_dim_x)
        out_old: tensor of shape (N, in_dim_out)
        alpha: scalar parameter controlling the amplitude of the residual update.

        return: out_new = out_old + alpha * F(x)
        """
        residual = self.res_mlp(x)
        out_new = out_old + tf.abs(alpha) * residual
        return out_new

# Define the Stacked MLP class for Stacked PINN with ResNet blocks
class StackedMLP(tf.Module):
    """
    Stacked Multi-Layer Perceptron designed for multi-fidelity learning where multiple layers are
    stacked to refine the prediction progressively. Now, each stacked layer is a ResNet block.
    """
    def __init__(
        self,
        insize,
        outsize,
        h_sf_sizes=[20, 20], # The single fidelity hidden size
        n_stacked_mf_layers=3,
        # The residual block hidden sizes for each stacked layer
        h_res_sizes=[20,20,20],
        bias=True,
        nonlin=tf.tanh,
        alpha_init=0.1,
        u_initial=None
    ):
        super().__init__()
        self.insize = insize
        self.outsize = outsize
        self.h_sf_sizes = h_sf_sizes
        self.n_stacked_mf_layers = n_stacked_mf_layers
        self.h_res_sizes = h_res_sizes
        self.bias = bias
        self.nonlin = nonlin
        self.alpha_init = alpha_init
        
        if u_initial is None:
            self.u0 = tf.zeros(shape=(outsize, 1), dtype=tf.float32)
        else:
            self.u0 = u_initial

        # Initial single-fidelity MLP
        self.first_layer = MLP(insize, outsize, hsizes=h_sf_sizes, bias=bias, nonlin=nonlin)

        # Alpha parameters, one per stacked layer
        self.alpha = [tf.Variable(0.0, trainable=True)] + [tf.Variable(alpha_init, trainable=True) for _ in range(n_stacked_mf_layers)]

        # Considering each stacked layer as a ResNet block
        self.layers = []
        for _ in range(n_stacked_mf_layers):
            res_block = ResNetBlock(insize, outsize, hres_sizes=self.h_res_sizes, bias=bias, nonlin=nonlin)
            self.layers.append(res_block)

    def __call__(self, x, i=None):
        if i is None:
            i = self.n_stacked_mf_layers
        i = min(i, self.n_stacked_mf_layers)

        # First layer (single-fidelity MLP)
        out = self.first_layer(x)
        out_old = tf.zeros_like(out)
        residual = out
        
        # Apply stacked ResNet blocks up to layer i
        for j in range(i):
            alpha = self.alpha[j+1]
            layer = self.layers[j]
            # Each layer: out = out + alpha * res_mlp(x)
            out_old = out
            out = layer(x, out_old, alpha)
            residual = out - out_old
        #return out_new, out_old, and residual
        return self.u0 + tf.tanh(x) * out, self.u0 + tf.tanh(x) * out_old, tf.tanh(x) * residual

    def get_alpha_loss(self, i=None):
        """
        Retrieve the accumulated loss from alpha parameters used for regularization purposes.

        :return: Alpha loss as a torch scalar.
        """
        return tf.pow(self.alpha[i], 4)

# Numerical solution for the Lotka–Volterra equation
def analytical_solution(n_steps, T_max=30.0, parameters_init=[1.1, 0.4, 0.4, 0.1], u_0=[10.0, 5.0]):
    """
    Numerical solution of the Lotka–Volterra model using RK4.

    Arguments:
    - n_steps: number of time steps
    - T_max  : final time
    - alpha, beta, gamma, delta: model parameters

    Returns:
    - x: trajectory (n_steps, 2), prey and predator populations
    - t: time (n_steps,)
    """
    alpha, beta, gamma, delta = parameters_init
    dt = T_max / float(n_steps)
    t = np.arange(0, n_steps * dt, dt)
    x = np.zeros((n_steps, 2))
    x[0, :] = u_0  # conditions initiales

    def lv_rhs(t, z):
        x1, x2 = z
        dx1 = alpha * x1 - beta * x1 * x2
        dx2 = delta * x1 * x2 - gamma * x2
        return np.array([dx1, dx2])

    for i in range(n_steps - 1):
        k1 = lv_rhs(t[i], x[i])
        k2 = lv_rhs(t[i] + dt/2, x[i] + dt/2 * k1)
        k3 = lv_rhs(t[i] + dt/2, x[i] + dt/2 * k2)
        k4 = lv_rhs(t[i] + dt, x[i] + dt * k3)
        x[i+1] = x[i] + dt/6 * (k1 + 2*k2 + 2*k3 + k4)

    return tf.convert_to_tensor(x, dtype=tf.float32), tf.convert_to_tensor(t, dtype=tf.float32)

# Define the L2 relative error function
def l2_relative_error(u_pred, u_true):
    """
    Compute L2 relative error between predicted values and true values.

    Parameters:
    u_pred (Tensor): Predicted values (model output)
    u_true (Tensor): True values (ground truth)

    Returns:
    float: L2 relative error
    """
    error = tf.norm(u_pred - u_true, ord=2) / tf.norm(u_true, ord=2)
    return error.numpy().item()

# Define the Stacked PINN class with modifications to store losses
class StackedResPINN:
    def __init__(self, model, optimizer_primal, optimizer_dual, lr_scheduler=None, patience=100, patience_gamma=1000, N_collocation=1000, N_resample=50, N_dual=10, gammas_init=[], parameters_init=[1.1, 0.4, 0.4, 0.1], logger=None, T_max=2.0):
        self.model = model
        self.optimizer_primal = optimizer_primal
        self.optimizer_dual = optimizer_dual
        self.lr_scheduler = lr_scheduler
        self.logger = logger
        self.n_stacked_layers = model.n_stacked_mf_layers+1  # Number of stacked layers (Using for averaging loss) +1 for vanilla layer 0
        self.N_phys = N_collocation
        self.N_resample = N_resample
        self.N_dual = N_dual
        # Early stopping attributes
        self.patience = patience
        self.patience_gamma = patience_gamma
        self.best_loss = 0.0
        self.bad_epochs = 0
        self.bad_epochs_gamma = 0

        self.T_max = T_max
        self.weight = tf.Variable(1.0, dtype=tf.float32)
        self.parameters = parameters_init
        self.alpha, self.beta, self.gamma, self.delta = self.parameters

        self.epsilon = tf.Variable(1.0e-2, dtype=tf.float32, trainable=False)
        self.omegas_t = tf.Variable(tf.zeros((self.n_stacked_layers, N_collocation), dtype=tf.float32), trainable=False)

        self.K = 0  # K is the index of the stack being updated
        self.update_count = 1

        # initialize the sequence alpha and the sitffness sigma of each stack
        self.gammas = tf.Variable(initial_value=gammas_init, trainable=False)
        self.old_gammas = self.gammas # for early stopping check
        self.sigma = tf.Variable(initial_value= (-1.0e-3) * tf.ones([self.n_stacked_layers], dtype=tf.float32),trainable=False)

    def resample(self):
        t_collocation = tf.random.uniform(shape=(self.N_phys, 1), minval=0, maxval=self.T_max)
        return t_collocation


    #############################       UPDATE ALPHA        ############################

    def cummin(self, x):
        """ 
        function cummin to force the sequence gamma_i to be nondecreasing:
            - takes a sequence a_i as entry
            - returns a sequence where each term gamma_i = min(gamma_i, gamma_i+1) begining with the first term
        """
        x = tf.convert_to_tensor(x)
        x_list = tf.unstack(x)

        out = []
        current_min = x_list[0]
        out.append(current_min)

        for xi in x_list[1:]:
            current_min = tf.minimum(current_min, xi)
            out.append(current_min)

        return tf.stack(out)
    
    def update_stiffness_indicators(self, t):
        """
        compute the stiffness indicator of each stack at each time t* = = argmin(sigma_N(t))
        """
        # compute the current solution of each stack
        u1 = []
        u2 = []
        for k in range(self.n_stacked_layers):
            U, _, _ = self.model(t, i=k)
            u1.append(U[:, 0:1])
            u2.append(U[:, 1:2])
        u1 = tf.squeeze(tf.stack(u1, axis=1), axis=2)
        u2 = tf.squeeze(tf.stack(u2, axis=1), axis=2)

        #compute sigma
        sigma = (self.alpha - self.beta*u2 + self.delta*u1 - self.gamma) / 2.0

        # get t* = argmin(sigma_N(t)) and get each sigma_i at t*
        last_layer_sigma = sigma[:, -1]
        min_index = tf.argmin(last_layer_sigma)
        sigma_at_min_index = sigma[min_index, :]
        self.sigma.assign(self.cummin(sigma_at_min_index))

    def update_gammas(self, smoothing_coef, t):
        """
        updates the sequence gamma_i depending on the stiffness gamma_i of the solution of each stack:
            - gamma_i = (i+1)/(N+1) * sigma_N(t*)/sigma_i(t*)
            - t* = argmin(sigma_N(t))
        """
        self.update_stiffness_indicators(t)
        i_s = tf.cumsum(tf.ones([self.n_stacked_layers], dtype=tf.float32))

        # compute each new gamma_i
        alpha_i = tf.abs((i_s*self.sigma[-1]) / (self.n_stacked_layers*self.sigma))

        new_gammas = tf.minimum(alpha_i, tf.ones([self.n_stacked_layers], dtype=tf.float32))   # force gamma_i to range between 0 and 1
        new_gammas = tf.reverse(self.cummin(tf.reverse(new_gammas, axis=[0])), axis=[0]) # prevent each gamma_i to be higher than gamma_(i+1)
        new_gammas = tf.stop_gradient((1 - smoothing_coef) * self.gammas + smoothing_coef * new_gammas) # smooth gamma and prevent gradient propagation through its computation
        self.gammas.assign(new_gammas)


    #############################       LOSS       ############################

    def f(self, u1, u2, alpha_i):
        term1 = alpha_i * (self.alpha*u1 - self.beta*u1*u2)
        term2 = alpha_i * (self.delta*u1*u2 - self.gamma*u2)
        return [term1, term2]

    @tf.function
    def loss_function(self, t, k):
        """
        loss function to compute the residual loss of stack k
            - k is the index of the stack currently being optimized
        """
        losses = []
        omegas_t = []
        inp = t

        for i in range(self.n_stacked_layers):
            if i == k:  # if i is the index of the stack currently being optimized
                if i ==0:
                    with tf.GradientTape(watch_accessed_variables=False) as tape1:
                        tape1.watch(inp)
                        U, _, _ = self.model(inp, i=i)
                    U_t = tape1.batch_jacobian(U, inp)
                    u1 = U[:, 0:1]
                    u2 = U[:, 1:2]
                    
                    f = tf.squeeze(U_t, axis=2) - tf.concat(self.f(u1, u2, self.gammas[i]), axis=1)

                else:
                    with tf.GradientTape(watch_accessed_variables=False) as tape1:
                        tape1.watch(inp)
                        U, U_old, R = self.model(inp, i=i)
                    R_t = tape1.batch_jacobian(R, inp)
                    u1 = U[:, 0:1]
                    u2 = U[:, 1:2]
                    u1_old = U_old[:, 0:1]
                    u2_old = U_old[:, 1:2]
                    
                    f = tf.squeeze(R_t, axis=2) - tf.concat(self.f(u1, u2, self.gammas[i]), axis=1) + tf.concat(self.f(u1_old, u2_old, self.gammas[i-1]), axis=1)
                
                f_squared = tf.square(f)
                f_squared_sum = tf.reduce_sum(f_squared, axis=1, keepdims=True)
                f_squared_cumsum = tf.cumsum(f_squared_sum, exclusive=True)
                omega_t = tf.stop_gradient(tf.exp(-self.epsilon * f_squared_cumsum))
                weighted_f_squared = omega_t * f_squared
                
                ode_i = self.weight * tf.reduce_mean(weighted_f_squared) + self.model.get_alpha_loss(i=i)
                
            else:   # if i is NOT the index of the stack currently being optimized, do not comput loss at this stack
                ode_i = 0.0
                u1 = tf.zeros_like(inp[:, :1])
                if i < k:
                    omega_t = tf.stop_gradient(tf.ones((self.N_phys, 1), dtype=tf.float32))
                else:
                    omega_t = tf.stop_gradient(tf.zeros((self.N_phys, 1), dtype=tf.float32))

            omegas_t.append(omega_t)
            losses.append(ode_i)

        self.omegas_t.assign(tf.squeeze(tf.stack(omegas_t, axis=0), axis=-1))

        return losses
    
    def get_target_variables(self, k):
        """
        get weights and biaises theta of stack k to be optimized
        """
        variables = []
        if k == 0:
            variables.extend(self.model.first_layer.trainable_variables)
        else:
            variables.extend(self.model.layers[k-1].trainable_variables)
        variables.append(self.model.alpha[k])
        return variables

    @tf.function
    def total_loss(self, t_collocation, k):
        physics_loss = self.loss_function(t_collocation, k)
        return sum(physics_loss)

    @tf.function
    def primal_update_k(self, t_collocation, target_variables, k):
        with tf.GradientTape(watch_accessed_variables=False) as loss_tape:
            loss_tape.watch(target_variables)
            loss = self.total_loss(t_collocation, k)
        grads = loss_tape.gradient(loss, target_variables)
        self.optimizer_primal[k].apply_gradients(zip(grads, target_variables))
        return loss
    
    def primal_update(self, t_collocation):
        target_variables = self.get_target_variables(self.K)
        loss = self.primal_update_k(t_collocation, target_variables, self.K)
        return loss
    
    @tf.function
    def dual_update(self, t_collocation):
        with tf.GradientTape(watch_accessed_variables=False) as loss_tape:
            loss_tape.watch(self.weight)
            loss = -self.loss_function(t_collocation, self.K)[self.K]
        grads = loss_tape.gradient(loss, [self.weight])
        self.optimizer_dual.apply_gradients(
            zip(grads, [self.weight])
        )
        return -loss


    #############################       TRAIN       ############################

    def train(self, t_collocation, n_stacked_mf_layers, epochs=1000, t_test=None, u_test=None, u_0=[10.0, 5.0]):
        
        """
        initialize the N+1 optimizers
        """
        all_trainable_vars = []
        for j in range(self.n_stacked_layers):
            _ = self.model(t_collocation, i=j)
            _ = self.model.get_alpha_loss(i=j)
            if j > 0:
                all_trainable_vars.extend(self.model.layers[j-1].trainable_variables)
            else:
                all_trainable_vars.extend(self.model.first_layer.trainable_variables)
            all_trainable_vars.append(self.model.alpha[j])

            with tf.GradientTape() as tape:
                dummy_loss = self.total_loss(t_collocation, j)
            dummy_grads = tape.gradient(dummy_loss, all_trainable_vars)
            grads_and_vars = [(g, v) for g, v in zip(dummy_grads, all_trainable_vars) if g is not None]
            self.optimizer_primal[j].apply_gradients(grads_and_vars)

        train_losses, test_losses, l2_errors, gammas, sigma, layer_updated, omegas_t, lambda_phys = ([] for _ in range(8))

        for epoch in range(epochs):

            loss = self.primal_update(t_collocation)
            if epoch % self.N_dual == 0 and epoch > 0: #dual update
                loss = self.dual_update(t_collocation)
            if epoch % self.N_resample == 0 and epoch > 0: #resampling of t_collocation
                t_collocation = self.resample()

            # Learning rate scheduling if type ReduceLROnPlateau
            if self.lr_scheduler:
                if hasattr(self.lr_scheduler, 'on_epoch_end'):
                    self.lr_scheduler.on_epoch_end(epoch=None, logs={"loss": loss.numpy()})
        
            # Logging
            if self.logger:
                self.logger.log_metrics({"loss": loss.numpy()}, step=epoch)

            # passing to next stack check
            if tf.reduce_mean(self.omegas_t[self.K]).numpy() > self.best_loss:
                self.best_loss = tf.reduce_mean(self.omegas_t[self.K]).numpy()
                self.bad_epochs = 0
            else:
                self.bad_epochs += 1

            if (self.bad_epochs >= self.patience and self.omegas_t[self.K][-1] > 0.9) or self.bad_epochs >= 2000:
                self.best_loss = 0.0
                if self.K < self.n_stacked_layers-1 and self.bad_epochs < 1000:
                    print(f"stack {self.K} has converged, passing to the next stack")
                    self.K += 1
                    self.bad_epochs = 0
                else:
                    print("all stacks converged, returning to stack 0")
                    if self.epsilon <= 1.0e-1:
                        self.epsilon.assign(self.epsilon * 10.0)
                    self.K = 0
                    self.bad_epochs = 0
                    self.update_count += 1
                    
                    # update u_test to visualize convergence with new gammas
                    n_steps = int(5e3)
                    u_test = []
                    for i in range(n_stacked_mf_layers+1):
                        u_t, _ = analytical_solution(n_steps, T_max=self.T_max, parameters_init = self.parameters * self.gammas[i], u_0=u_0)
                        u_test.append(u_t)

                    # early stopping check
                    if tf.reduce_mean(tf.square(self.gammas - self.old_gammas)) > 1.0e-2:
                        self.old_gammas = self.gammas
                        self.bad_epochs_gamma = 0
                    else:
                        self.bad_epochs_gamma += 1

                    if self.bad_epochs_gamma >= self.patience_gamma:
                        print(f"Early stopping triggered")
                        break                
             
            train_losses.append(loss.numpy())
            gammas.append(self.gammas.numpy().copy())
            sigma.append(self.sigma.numpy().copy())
            layer_updated.append(self.K)
            omegas_t.append(self.omegas_t.numpy().copy())
            lambda_phys.append(self.weight.numpy().copy())

            if epoch % 100 == 0 or epoch == epochs-1:
                # Calculate test loss if test data is provided
                if t_test is not None and u_test is not None:

                    u_pred_test = []
                    for i in range(self.model.n_stacked_mf_layers+1):
                        u_i, _, _ = self.model(t_test, i)
                        u_pred_test.append(u_i)
                    test_loss = [tf.reduce_mean(tf.square(u_pred_test_i - u_test_i)).numpy() for u_pred_test_i, u_test_i  in zip(u_pred_test, u_test)]
                    test_losses.append(test_loss)

                    # Compute L2 relative error
                    l2_error = [l2_relative_error(u_pred_test_i, u_test_i) for u_pred_test_i, u_test_i in zip(u_pred_test, u_test)]
                    l2_errors.append(l2_error)

                print(f"Epoch {epoch}, Loss: {loss.numpy():.4e}, L2 Relative_error: {[f'{err:.4f}' for err in l2_error]}, self.gammas: {[f'{gamma:.4f}' for gamma in self.gammas.numpy()]}, epsilon : {self.epsilon.numpy():.1e}, lambda_phys : {self.weight.numpy():.4f}, layer {self.K} is being updated for the {self.update_count}-th time")

        # Plot losses
        plt.figure(figsize=(10, 5))
        plt.plot(train_losses, label="Training Loss")
        if test_losses:
            # test_losses is a list of lists, one per epoch. Plotting the mean test loss across layers.
            mean_test_losses = [np.mean(tl) for tl in test_losses]
            plt.plot(mean_test_losses, label="Test Loss", color="orange")
        plt.xlabel("Epochs")
        plt.ylabel("Loss")
        plt.title("Training and Test Loss")
        plt.legend()
        plt.grid(True)
        plt.savefig("losses over epochs.eps", format='eps')
        plt.show()

         # Plot L2 relative error over epochs
        if l2_errors:  # Check if l2_errors is not empty
            plt.figure()
            plt.plot(range(len(l2_errors)), l2_errors, label=[f"L2 Relative Error{i}" for i in range (n_stacked_mf_layers+1)])
            plt.xlabel("Epochs")
            plt.ylabel("L2 Relative Error")
            plt.title("L2 Relative Error over Training Epochs")
            plt.yscale("log")
            plt.legend()
            plt.grid(True)
            plt.savefig("L2 relative error over epochs.eps", format='eps')
            plt.show()

        # plot final output vs analytical solution
        t_test = tf.reshape(t_test, [-1]).numpy()
        sorted_indices = np.argsort(t_test)
        t_sorted = t_test[sorted_indices]
        
        u_pred_np = u_pred_test[-1].numpy()
        u_sorted = u_pred_np[sorted_indices]
        u_true_np = u_test[-1].numpy()
        u_true_sorted = u_true_np[sorted_indices]

        plt.figure(figsize=(10, 4))
        plt.subplot(3, 1, 1)
        plt.plot(t_sorted, u_sorted[:, 0], label='x_hat1')
        plt.plot(t_sorted, u_true_sorted[:, 0], label='x1')
        plt.xlabel("Time")
        plt.ylabel("State")
        plt.legend()
        plt.grid(True)
        plt.show()

        plt.figure(figsize=(10, 4))
        plt.subplot(3, 1, 2)
        plt.plot(t_sorted, u_sorted[:, 1], label='x_hat2')
        plt.plot(t_sorted, u_true_sorted[:, 1], label='x2')
        plt.xlabel("Time")
        plt.ylabel("State")
        plt.legend()
        plt.grid(True)
        plt.show()

        # Plot gammas over epochs
        gammas_np = np.array([alph for alph in gammas])
        plt.figure()
        for i in range(gammas_np.shape[1]):
            plt.plot(range(len(gammas_np)), gammas_np[:, i], label=f"gamma_{i}")
        plt.xlabel("Epochs")
        plt.ylabel(f"gamma values")
        plt.title("gamma over Training Epochs")
        plt.grid(True)
        plt.legend()
        plt.savefig("gammas over epochs.eps", format='eps')
        plt.show()

        # Plot sigmas over epochs
        sigma_np = np.array([sigm for sigm in sigma])
        plt.figure()
        for i in range(sigma_np.shape[1]):
            plt.plot(range(len(sigma_np)), sigma_np[:, i], label=f"sigma_{i}")
        plt.xlabel("Epochs")
        plt.ylabel(f"sigma values")
        plt.yscale('symlog', linthresh=1e-3)
        plt.title("sigma over Training Epochs")
        plt.grid(True)
        plt.legend()
        plt.savefig("sigma over epochs.eps", format='eps')
        plt.show()

        # Plot k over epochs
        plt.figure()
        plt.plot(range(len(layer_updated)), layer_updated, label="layer_updated")
        plt.xlabel("Epochs")
        plt.ylabel(f"layer_updated values")
        plt.title("layer_updated over Training Epochs")
        plt.grid(True)
        plt.legend()
        plt.savefig("K over epochs.eps", format='eps')
        plt.show()

        # Plot lambda_phys over epochs
        plt.figure()
        plt.plot(range(len(lambda_phys)), lambda_phys, label="lambda_phys")
        plt.xlabel("Epochs")
        plt.ylabel(f"lambda_phys values")
        plt.title("lambda_phys over Training Epochs")
        plt.grid(True)
        plt.legend()
        plt.savefig("lambda_phys over epochs.eps", format='eps')
        plt.show()

# %%
if __name__ == "__main__":
    # Parameters
    T_max = 15.0
    parameters_init = np.array([1.1, 0.4, 0.4, 0.1])
    n_stacked_mf_layers = 2
    u_0 = [2.0, 1.0]
    insize = 1  # Input size (t)
    outsize = 2  # Output size (u)
    h_sf_sizes = [50, 50, 50]
    # Residual block hidden sizes
    h_res_sizes = [50, 50, 50]
    gammas_init = []
    
    for i in range(n_stacked_mf_layers+1):
        gammas_init.append((i+1)/(n_stacked_mf_layers+1))
    print(f'gammas_init : {gammas_init}')

    # Initial condition
    N_initial = 1
    t_initial = tf.zeros(shape=(N_initial, 1), dtype=tf.float32)
    u_initial = tf.convert_to_tensor([u_0] * N_initial, dtype=tf.float32)

    # Create model
    model = StackedMLP(insize, outsize, h_sf_sizes=h_sf_sizes, h_res_sizes=h_res_sizes,
                       n_stacked_mf_layers=n_stacked_mf_layers, alpha_init=0.05, u_initial=u_initial)

    optimizer_primal = [tf.keras.optimizers.legacy.Adam(learning_rate=1e-3)] + [tf.keras.optimizers.legacy.Adam(learning_rate=1e-4) for _ in range(n_stacked_mf_layers)]
    optimizer_dual = tf.keras.optimizers.legacy.Adam(learning_rate=1e-3)

    # Test points (optional for validation/testing)
    n_steps = int(5e3)
    u_tests = []
    for i in range(n_stacked_mf_layers+1):
        u_test, t_test = analytical_solution(n_steps, T_max=T_max, parameters_init=gammas_init[i]*parameters_init, u_0=u_0)
        u_tests.append(u_test)
    t_test = tf.reshape(t_test, (-1, 1))

    # Create collocation points
    N_collocation = 1000
    t_collocation = tf.random.uniform(shape=(N_collocation, 1), minval=0, maxval=T_max)

    # Create instance of Stacked Residual PINN
    pinn = StackedResPINN(model, optimizer_primal, optimizer_dual, gammas_init=gammas_init, T_max=T_max, parameters_init=parameters_init)

    # Train the model with test data for loss visualization
    pinn.train(t_collocation, n_stacked_mf_layers, epochs=300000, t_test=t_test, u_test=u_tests, u_0=u_0)
# Out:
# gammas_init : [0.3333333333333333, 0.6666666666666666, 1.0]
# 2025-08-12 15:32:07.782332: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# Epoch 0, Loss: 4.2995e-02, L2 Relative_error: ['0.9018', '0.8894', '0.8954'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0000, layer 0 is being updated for the 1-th time
# Epoch 100, Loss: 3.6398e-02, L2 Relative_error: ['0.9382', '0.8736', '0.9046'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0100, layer 0 is being updated for the 1-th time
# Epoch 200, Loss: 3.5585e-02, L2 Relative_error: ['0.9347', '0.8698', '0.8948'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0200, layer 0 is being updated for the 1-th time
# Epoch 300, Loss: 2.0553e-02, L2 Relative_error: ['0.5957', '0.7021', '0.6774'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0299, layer 0 is being updated for the 1-th time
# Epoch 400, Loss: 1.1335e-02, L2 Relative_error: ['0.5098', '0.7759', '0.7007'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0373, layer 0 is being updated for the 1-th time
# Epoch 500, Loss: 1.0848e-02, L2 Relative_error: ['0.4978', '0.7737', '0.7100'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0427, layer 0 is being updated for the 1-th time
# Epoch 600, Loss: 6.8631e-03, L2 Relative_error: ['0.4392', '0.7758', '0.7549'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0471, layer 0 is being updated for the 1-th time
# Epoch 700, Loss: 3.6608e-03, L2 Relative_error: ['0.3367', '0.8495', '0.8317'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0503, layer 0 is being updated for the 1-th time
# Epoch 800, Loss: 1.8007e-03, L2 Relative_error: ['0.2606', '0.9080', '0.8999'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0524, layer 0 is being updated for the 1-th time
# Epoch 900, Loss: 1.1153e-03, L2 Relative_error: ['0.2038', '0.9652', '0.9499'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0536, layer 0 is being updated for the 1-th time
# Epoch 1000, Loss: 7.1807e-04, L2 Relative_error: ['0.1704', '0.9952', '0.9826'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0544, layer 0 is being updated for the 1-th time
# Epoch 1100, Loss: 5.0549e-04, L2 Relative_error: ['0.1488', '1.0165', '1.0034'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0549, layer 0 is being updated for the 1-th time
# Epoch 1200, Loss: 3.8866e-04, L2 Relative_error: ['0.1292', '1.0350', '1.0230'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0553, layer 0 is being updated for the 1-th time
# Epoch 1300, Loss: 3.0006e-04, L2 Relative_error: ['0.1134', '1.0492', '1.0394'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0556, layer 0 is being updated for the 1-th time
# Epoch 1400, Loss: 2.7867e-04, L2 Relative_error: ['0.1034', '1.0628', '1.0484'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0559, layer 0 is being updated for the 1-th time
# Epoch 1500, Loss: 1.9809e-04, L2 Relative_error: ['0.0924', '1.0717', '1.0601'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0561, layer 0 is being updated for the 1-th time
# Epoch 1600, Loss: 1.5877e-04, L2 Relative_error: ['0.0826', '1.0809', '1.0702'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0563, layer 0 is being updated for the 1-th time
# Epoch 1700, Loss: 1.2173e-04, L2 Relative_error: ['0.0749', '1.0893', '1.0780'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0564, layer 0 is being updated for the 1-th time
# Epoch 1800, Loss: 1.0229e-04, L2 Relative_error: ['0.0666', '1.0981', '1.0864'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0566, layer 0 is being updated for the 1-th time
# Epoch 1900, Loss: 8.2629e-05, L2 Relative_error: ['0.0587', '1.1062', '1.0944'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0567, layer 0 is being updated for the 1-th time
# Epoch 2000, Loss: 6.9317e-05, L2 Relative_error: ['0.0521', '1.1127', '1.1013'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0567, layer 0 is being updated for the 1-th time
# Epoch 2100, Loss: 5.7499e-05, L2 Relative_error: ['0.0471', '1.1168', '1.1067'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0568, layer 0 is being updated for the 1-th time
# Epoch 2200, Loss: 4.9778e-05, L2 Relative_error: ['0.0416', '1.1225', '1.1124'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0569, layer 0 is being updated for the 1-th time
# Epoch 2300, Loss: 4.0996e-05, L2 Relative_error: ['0.0377', '1.1268', '1.1164'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0569, layer 0 is being updated for the 1-th time
# Epoch 2400, Loss: 6.0584e-05, L2 Relative_error: ['0.0353', '1.1310', '1.1183'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0570, layer 0 is being updated for the 1-th time
# Epoch 2500, Loss: 3.3486e-05, L2 Relative_error: ['0.0322', '1.1330', '1.1219'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0571, layer 0 is being updated for the 1-th time
# stack 0 has converged, passing to the next stack
# Epoch 2600, Loss: 3.0943e-05, L2 Relative_error: ['0.0308', '1.1284', '1.1200'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0571, layer 1 is being updated for the 1-th time
# Epoch 2700, Loss: 3.7589e-05, L2 Relative_error: ['0.0308', '1.1128', '1.1110'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0572, layer 1 is being updated for the 1-th time
# Epoch 2800, Loss: 3.1656e-05, L2 Relative_error: ['0.0308', '1.0976', '1.1013'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0572, layer 1 is being updated for the 1-th time
# Epoch 2900, Loss: 3.2072e-05, L2 Relative_error: ['0.0308', '1.0841', '1.0923'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0572, layer 1 is being updated for the 1-th time
# Epoch 3000, Loss: 3.1797e-05, L2 Relative_error: ['0.0308', '1.0690', '1.0815'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0572, layer 1 is being updated for the 1-th time
# Epoch 3100, Loss: 3.2347e-05, L2 Relative_error: ['0.0308', '1.0506', '1.0705'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0573, layer 1 is being updated for the 1-th time
# Epoch 3200, Loss: 3.1427e-05, L2 Relative_error: ['0.0308', '1.0336', '1.0608'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0573, layer 1 is being updated for the 1-th time
# Epoch 3300, Loss: 3.2803e-05, L2 Relative_error: ['0.0308', '1.0216', '1.0540'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0573, layer 1 is being updated for the 1-th time
# Epoch 3400, Loss: 2.9703e-05, L2 Relative_error: ['0.0308', '1.0153', '1.0481'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0574, layer 1 is being updated for the 1-th time
# Epoch 3500, Loss: 3.0567e-05, L2 Relative_error: ['0.0308', '1.0128', '1.0435'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0574, layer 1 is being updated for the 1-th time
# Epoch 3600, Loss: 3.3129e-05, L2 Relative_error: ['0.0308', '1.0082', '1.0383'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0574, layer 1 is being updated for the 1-th time
# Epoch 3700, Loss: 3.3678e-05, L2 Relative_error: ['0.0308', '0.9992', '1.0303'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0575, layer 1 is being updated for the 1-th time
# Epoch 3800, Loss: 2.9922e-05, L2 Relative_error: ['0.0308', '0.9961', '1.0245'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0575, layer 1 is being updated for the 1-th time
# Epoch 3900, Loss: 2.9354e-05, L2 Relative_error: ['0.0308', '0.9876', '1.0174'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0575, layer 1 is being updated for the 1-th time
# Epoch 4000, Loss: 3.2491e-05, L2 Relative_error: ['0.0308', '0.9838', '1.0098'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0575, layer 1 is being updated for the 1-th time
# Epoch 4100, Loss: 3.1086e-05, L2 Relative_error: ['0.0308', '0.9775', '1.0028'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0576, layer 1 is being updated for the 1-th time
# Epoch 4200, Loss: 2.9717e-05, L2 Relative_error: ['0.0308', '0.9688', '0.9934'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0576, layer 1 is being updated for the 1-th time
# Epoch 4300, Loss: 3.3520e-05, L2 Relative_error: ['0.0308', '0.9591', '0.9823'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0576, layer 1 is being updated for the 1-th time
# Epoch 4400, Loss: 3.1544e-05, L2 Relative_error: ['0.0308', '0.9441', '0.9710'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0577, layer 1 is being updated for the 1-th time
# Epoch 4500, Loss: 3.0261e-05, L2 Relative_error: ['0.0308', '0.9361', '0.9626'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0577, layer 1 is being updated for the 1-th time
# Epoch 4600, Loss: 2.9660e-05, L2 Relative_error: ['0.0308', '0.9160', '0.9493'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0578, layer 1 is being updated for the 1-th time
# Epoch 4700, Loss: 3.4279e-05, L2 Relative_error: ['0.0308', '0.8986', '0.9393'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0578, layer 1 is being updated for the 1-th time
# Epoch 4800, Loss: 3.0933e-05, L2 Relative_error: ['0.0308', '0.8856', '0.9329'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0578, layer 1 is being updated for the 1-th time
# Epoch 4900, Loss: 3.2781e-05, L2 Relative_error: ['0.0308', '0.8703', '0.9237'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0579, layer 1 is being updated for the 1-th time
# Epoch 5000, Loss: 3.2142e-05, L2 Relative_error: ['0.0308', '0.8651', '0.9173'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0579, layer 1 is being updated for the 1-th time
# Epoch 5100, Loss: 2.8797e-05, L2 Relative_error: ['0.0308', '0.8538', '0.9109'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0579, layer 1 is being updated for the 1-th time
# Epoch 5200, Loss: 3.1606e-05, L2 Relative_error: ['0.0308', '0.8451', '0.9053'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0580, layer 1 is being updated for the 1-th time
# Epoch 5300, Loss: 3.1610e-05, L2 Relative_error: ['0.0308', '0.8381', '0.8980'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0580, layer 1 is being updated for the 1-th time
# Epoch 5400, Loss: 3.0149e-05, L2 Relative_error: ['0.0308', '0.8348', '0.8962'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0580, layer 1 is being updated for the 1-th time
# Epoch 5500, Loss: 3.3189e-05, L2 Relative_error: ['0.0308', '0.8223', '0.8886'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0581, layer 1 is being updated for the 1-th time
# Epoch 5600, Loss: 3.1717e-05, L2 Relative_error: ['0.0308', '0.8143', '0.8860'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0581, layer 1 is being updated for the 1-th time
# Epoch 5700, Loss: 3.0776e-05, L2 Relative_error: ['0.0308', '0.8191', '0.8832'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0582, layer 1 is being updated for the 1-th time
# Epoch 5800, Loss: 3.4059e-05, L2 Relative_error: ['0.0308', '0.8134', '0.8798'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0582, layer 1 is being updated for the 1-th time
# Epoch 5900, Loss: 2.9843e-05, L2 Relative_error: ['0.0308', '0.8063', '0.8755'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0582, layer 1 is being updated for the 1-th time
# Epoch 6000, Loss: 3.5638e-05, L2 Relative_error: ['0.0308', '0.7952', '0.8713'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0583, layer 1 is being updated for the 1-th time
# Epoch 6100, Loss: 3.3794e-05, L2 Relative_error: ['0.0308', '0.7938', '0.8674'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0583, layer 1 is being updated for the 1-th time
# Epoch 6200, Loss: 3.8808e-05, L2 Relative_error: ['0.0308', '0.7873', '0.8660'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0584, layer 1 is being updated for the 1-th time
# Epoch 6300, Loss: 3.3239e-05, L2 Relative_error: ['0.0308', '0.7873', '0.8641'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0584, layer 1 is being updated for the 1-th time
# Epoch 6400, Loss: 2.7350e-05, L2 Relative_error: ['0.0308', '0.7782', '0.8598'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0585, layer 1 is being updated for the 1-th time
# Epoch 6500, Loss: 2.8517e-05, L2 Relative_error: ['0.0308', '0.7761', '0.8577'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0585, layer 1 is being updated for the 1-th time
# Epoch 6600, Loss: 2.8691e-05, L2 Relative_error: ['0.0308', '0.7771', '0.8551'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0586, layer 1 is being updated for the 1-th time
# Epoch 6700, Loss: 3.2186e-05, L2 Relative_error: ['0.0308', '0.7682', '0.8550'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0586, layer 1 is being updated for the 1-th time
# Epoch 6800, Loss: 3.0740e-05, L2 Relative_error: ['0.0308', '0.7720', '0.8524'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0586, layer 1 is being updated for the 1-th time
# Epoch 6900, Loss: 3.0465e-05, L2 Relative_error: ['0.0308', '0.7644', '0.8490'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0587, layer 1 is being updated for the 1-th time
# Epoch 7000, Loss: 3.2424e-05, L2 Relative_error: ['0.0308', '0.7523', '0.8469'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0587, layer 1 is being updated for the 1-th time
# Epoch 7100, Loss: 3.1455e-05, L2 Relative_error: ['0.0308', '0.7605', '0.8454'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0588, layer 1 is being updated for the 1-th time
# Epoch 7200, Loss: 3.1277e-05, L2 Relative_error: ['0.0308', '0.7624', '0.8455'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0588, layer 1 is being updated for the 1-th time
# Epoch 7300, Loss: 2.7448e-05, L2 Relative_error: ['0.0308', '0.7517', '0.8407'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0589, layer 1 is being updated for the 1-th time
# Epoch 7400, Loss: 3.2785e-05, L2 Relative_error: ['0.0308', '0.7517', '0.8387'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0589, layer 1 is being updated for the 1-th time
# Epoch 7500, Loss: 3.2662e-05, L2 Relative_error: ['0.0308', '0.7437', '0.8386'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0590, layer 1 is being updated for the 1-th time
# Epoch 7600, Loss: 3.0717e-05, L2 Relative_error: ['0.0308', '0.7401', '0.8344'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0590, layer 1 is being updated for the 1-th time
# Epoch 7700, Loss: 2.9554e-05, L2 Relative_error: ['0.0308', '0.7375', '0.8300'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0591, layer 1 is being updated for the 1-th time
# Epoch 7800, Loss: 2.9949e-05, L2 Relative_error: ['0.0308', '0.7277', '0.8253'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0591, layer 1 is being updated for the 1-th time
# Epoch 7900, Loss: 2.7874e-05, L2 Relative_error: ['0.0308', '0.7288', '0.8265'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0592, layer 1 is being updated for the 1-th time
# Epoch 8000, Loss: 3.0363e-05, L2 Relative_error: ['0.0308', '0.7205', '0.8245'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0592, layer 1 is being updated for the 1-th time
# Epoch 8100, Loss: 3.1589e-05, L2 Relative_error: ['0.0308', '0.7136', '0.8217'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0593, layer 1 is being updated for the 1-th time
# Epoch 8200, Loss: 3.5285e-05, L2 Relative_error: ['0.0308', '0.7060', '0.8206'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0593, layer 1 is being updated for the 1-th time
# Epoch 8300, Loss: 3.2264e-05, L2 Relative_error: ['0.0308', '0.6970', '0.8174'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0594, layer 1 is being updated for the 1-th time
# Epoch 8400, Loss: 3.1689e-05, L2 Relative_error: ['0.0308', '0.6834', '0.8122'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0594, layer 1 is being updated for the 1-th time
# Epoch 8500, Loss: 2.9180e-05, L2 Relative_error: ['0.0308', '0.6855', '0.8095'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0595, layer 1 is being updated for the 1-th time
# Epoch 8600, Loss: 2.9586e-05, L2 Relative_error: ['0.0308', '0.6704', '0.8063'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0595, layer 1 is being updated for the 1-th time
# Epoch 8700, Loss: 2.8362e-05, L2 Relative_error: ['0.0308', '0.6618', '0.7997'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0596, layer 1 is being updated for the 1-th time
# Epoch 8800, Loss: 2.9583e-05, L2 Relative_error: ['0.0308', '0.6540', '0.7975'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0596, layer 1 is being updated for the 1-th time
# Epoch 8900, Loss: 3.1159e-05, L2 Relative_error: ['0.0308', '0.6389', '0.7995'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0597, layer 1 is being updated for the 1-th time
# Epoch 9000, Loss: 2.8134e-05, L2 Relative_error: ['0.0308', '0.6255', '0.7971'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0597, layer 1 is being updated for the 1-th time
# Epoch 9100, Loss: 3.2112e-05, L2 Relative_error: ['0.0308', '0.6143', '0.7962'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0598, layer 1 is being updated for the 1-th time
# Epoch 9200, Loss: 3.3493e-05, L2 Relative_error: ['0.0308', '0.5971', '0.7995'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0599, layer 1 is being updated for the 1-th time
# Epoch 9300, Loss: 3.2261e-05, L2 Relative_error: ['0.0308', '0.5868', '0.7960'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0599, layer 1 is being updated for the 1-th time
# Epoch 9400, Loss: 3.2868e-05, L2 Relative_error: ['0.0308', '0.5704', '0.7940'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0600, layer 1 is being updated for the 1-th time
# Epoch 9500, Loss: 2.9203e-05, L2 Relative_error: ['0.0308', '0.5574', '0.7922'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0600, layer 1 is being updated for the 1-th time
# Epoch 9600, Loss: 3.1471e-05, L2 Relative_error: ['0.0308', '0.5387', '0.7913'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0601, layer 1 is being updated for the 1-th time
# Epoch 9700, Loss: 3.2500e-05, L2 Relative_error: ['0.0308', '0.5282', '0.7917'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0602, layer 1 is being updated for the 1-th time
# Epoch 9800, Loss: 2.8167e-05, L2 Relative_error: ['0.0308', '0.5155', '0.7887'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0602, layer 1 is being updated for the 1-th time
# Epoch 9900, Loss: 3.1251e-05, L2 Relative_error: ['0.0308', '0.5106', '0.7935'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0603, layer 1 is being updated for the 1-th time
# Epoch 10000, Loss: 2.8582e-05, L2 Relative_error: ['0.0308', '0.4999', '0.7873'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0603, layer 1 is being updated for the 1-th time
# Epoch 10100, Loss: 3.1730e-05, L2 Relative_error: ['0.0308', '0.4941', '0.7905'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0604, layer 1 is being updated for the 1-th time
# Epoch 10200, Loss: 2.9846e-05, L2 Relative_error: ['0.0308', '0.4873', '0.7889'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0604, layer 1 is being updated for the 1-th time
# Epoch 10300, Loss: 3.0486e-05, L2 Relative_error: ['0.0308', '0.4788', '0.7856'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0605, layer 1 is being updated for the 1-th time
# Epoch 10400, Loss: 3.3723e-05, L2 Relative_error: ['0.0308', '0.4782', '0.7892'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0606, layer 1 is being updated for the 1-th time
# Epoch 10500, Loss: 3.1275e-05, L2 Relative_error: ['0.0308', '0.4688', '0.7866'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0606, layer 1 is being updated for the 1-th time
# Epoch 10600, Loss: 3.1825e-05, L2 Relative_error: ['0.0308', '0.4685', '0.7877'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0607, layer 1 is being updated for the 1-th time
# Epoch 10700, Loss: 2.9259e-05, L2 Relative_error: ['0.0308', '0.4648', '0.7855'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0608, layer 1 is being updated for the 1-th time
# Epoch 10800, Loss: 3.3463e-05, L2 Relative_error: ['0.0308', '0.4611', '0.7850'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0608, layer 1 is being updated for the 1-th time
# Epoch 10900, Loss: 3.3016e-05, L2 Relative_error: ['0.0308', '0.4585', '0.7869'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0609, layer 1 is being updated for the 1-th time
# Epoch 11000, Loss: 3.1780e-05, L2 Relative_error: ['0.0308', '0.4542', '0.7832'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0610, layer 1 is being updated for the 1-th time
# Epoch 11100, Loss: 2.9855e-05, L2 Relative_error: ['0.0308', '0.4503', '0.7817'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0610, layer 1 is being updated for the 1-th time
# Epoch 11200, Loss: 3.3391e-05, L2 Relative_error: ['0.0308', '0.4481', '0.7804'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0611, layer 1 is being updated for the 1-th time
# Epoch 11300, Loss: 3.2057e-05, L2 Relative_error: ['0.0308', '0.4455', '0.7794'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0612, layer 1 is being updated for the 1-th time
# Epoch 11400, Loss: 3.1162e-05, L2 Relative_error: ['0.0308', '0.4421', '0.7791'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0612, layer 1 is being updated for the 1-th time
# Epoch 11500, Loss: 2.8598e-05, L2 Relative_error: ['0.0308', '0.4397', '0.7770'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0613, layer 1 is being updated for the 1-th time
# Epoch 11600, Loss: 3.1951e-05, L2 Relative_error: ['0.0308', '0.4375', '0.7761'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0614, layer 1 is being updated for the 1-th time
# Epoch 11700, Loss: 3.4345e-05, L2 Relative_error: ['0.0308', '0.4352', '0.7780'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0614, layer 1 is being updated for the 1-th time
# Epoch 11800, Loss: 3.0676e-05, L2 Relative_error: ['0.0308', '0.4354', '0.7755'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0615, layer 1 is being updated for the 1-th time
# Epoch 11900, Loss: 2.8421e-05, L2 Relative_error: ['0.0308', '0.4313', '0.7755'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0616, layer 1 is being updated for the 1-th time
# Epoch 12000, Loss: 3.0041e-05, L2 Relative_error: ['0.0308', '0.4337', '0.7753'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0616, layer 1 is being updated for the 1-th time
# Epoch 12100, Loss: 3.0660e-05, L2 Relative_error: ['0.0308', '0.4304', '0.7786'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0617, layer 1 is being updated for the 1-th time
# Epoch 12200, Loss: 3.2706e-05, L2 Relative_error: ['0.0308', '0.4279', '0.7746'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0618, layer 1 is being updated for the 1-th time
# Epoch 12300, Loss: 2.9337e-05, L2 Relative_error: ['0.0308', '0.4257', '0.7757'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0618, layer 1 is being updated for the 1-th time
# Epoch 12400, Loss: 2.9447e-05, L2 Relative_error: ['0.0308', '0.4224', '0.7720'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0619, layer 1 is being updated for the 1-th time
# Epoch 12500, Loss: 3.0391e-05, L2 Relative_error: ['0.0308', '0.4202', '0.7744'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0620, layer 1 is being updated for the 1-th time
# Epoch 12600, Loss: 2.8686e-05, L2 Relative_error: ['0.0308', '0.4214', '0.7752'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0621, layer 1 is being updated for the 1-th time
# Epoch 12700, Loss: 3.2290e-05, L2 Relative_error: ['0.0308', '0.4198', '0.7711'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0621, layer 1 is being updated for the 1-th time
# Epoch 12800, Loss: 2.8621e-05, L2 Relative_error: ['0.0308', '0.4196', '0.7684'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0622, layer 1 is being updated for the 1-th time
# Epoch 12900, Loss: 2.9865e-05, L2 Relative_error: ['0.0308', '0.4167', '0.7713'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0623, layer 1 is being updated for the 1-th time
# Epoch 13000, Loss: 3.0682e-05, L2 Relative_error: ['0.0308', '0.4143', '0.7670'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0624, layer 1 is being updated for the 1-th time
# Epoch 13100, Loss: 3.2514e-05, L2 Relative_error: ['0.0308', '0.4130', '0.7734'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0624, layer 1 is being updated for the 1-th time
# Epoch 13200, Loss: 3.5016e-05, L2 Relative_error: ['0.0308', '0.4117', '0.7723'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0625, layer 1 is being updated for the 1-th time
# Epoch 13300, Loss: 3.1770e-05, L2 Relative_error: ['0.0308', '0.4109', '0.7661'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0626, layer 1 is being updated for the 1-th time
# Epoch 13400, Loss: 3.2720e-05, L2 Relative_error: ['0.0308', '0.4097', '0.7700'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0627, layer 1 is being updated for the 1-th time
# Epoch 13500, Loss: 2.8670e-05, L2 Relative_error: ['0.0308', '0.4106', '0.7708'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0627, layer 1 is being updated for the 1-th time
# Epoch 13600, Loss: 3.0542e-05, L2 Relative_error: ['0.0308', '0.4081', '0.7665'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0628, layer 1 is being updated for the 1-th time
# Epoch 13700, Loss: 3.4639e-05, L2 Relative_error: ['0.0308', '0.4078', '0.7663'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0629, layer 1 is being updated for the 1-th time
# Epoch 13800, Loss: 2.8760e-05, L2 Relative_error: ['0.0308', '0.4056', '0.7662'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0630, layer 1 is being updated for the 1-th time
# Epoch 13900, Loss: 3.0158e-05, L2 Relative_error: ['0.0308', '0.4054', '0.7659'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0630, layer 1 is being updated for the 1-th time
# Epoch 14000, Loss: 3.2384e-05, L2 Relative_error: ['0.0308', '0.4028', '0.7658'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0631, layer 1 is being updated for the 1-th time
# Epoch 14100, Loss: 3.0892e-05, L2 Relative_error: ['0.0308', '0.4017', '0.7691'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0632, layer 1 is being updated for the 1-th time
# Epoch 14200, Loss: 2.8455e-05, L2 Relative_error: ['0.0308', '0.4018', '0.7669'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0633, layer 1 is being updated for the 1-th time
# Epoch 14300, Loss: 3.0976e-05, L2 Relative_error: ['0.0308', '0.4005', '0.7632'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0634, layer 1 is being updated for the 1-th time
# Epoch 14400, Loss: 3.3441e-05, L2 Relative_error: ['0.0308', '0.3992', '0.7652'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0634, layer 1 is being updated for the 1-th time
# Epoch 14500, Loss: 3.5913e-05, L2 Relative_error: ['0.0308', '0.3974', '0.7652'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0635, layer 1 is being updated for the 1-th time
# Epoch 14600, Loss: 3.5640e-05, L2 Relative_error: ['0.0308', '0.3987', '0.7635'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0636, layer 1 is being updated for the 1-th time
# Epoch 14700, Loss: 2.9736e-05, L2 Relative_error: ['0.0308', '0.3973', '0.7622'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0637, layer 1 is being updated for the 1-th time
# Epoch 14800, Loss: 3.2318e-05, L2 Relative_error: ['0.0308', '0.3982', '0.7645'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0638, layer 1 is being updated for the 1-th time
# Epoch 14900, Loss: 2.9906e-05, L2 Relative_error: ['0.0308', '0.3948', '0.7611'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0639, layer 1 is being updated for the 1-th time
# Epoch 15000, Loss: 2.8916e-05, L2 Relative_error: ['0.0308', '0.3955', '0.7597'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0639, layer 1 is being updated for the 1-th time
# Epoch 15100, Loss: 3.3352e-05, L2 Relative_error: ['0.0308', '0.3916', '0.7607'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0640, layer 1 is being updated for the 1-th time
# Epoch 15200, Loss: 3.3068e-05, L2 Relative_error: ['0.0308', '0.3910', '0.7638'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0641, layer 1 is being updated for the 1-th time
# Epoch 15300, Loss: 2.9788e-05, L2 Relative_error: ['0.0308', '0.3913', '0.7587'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0642, layer 1 is being updated for the 1-th time
# Epoch 15400, Loss: 3.3380e-05, L2 Relative_error: ['0.0308', '0.3886', '0.7618'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0643, layer 1 is being updated for the 1-th time
# Epoch 15500, Loss: 3.6776e-05, L2 Relative_error: ['0.0308', '0.3889', '0.7604'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0644, layer 1 is being updated for the 1-th time
# Epoch 15600, Loss: 3.2789e-05, L2 Relative_error: ['0.0308', '0.3863', '0.7582'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0645, layer 1 is being updated for the 1-th time
# Epoch 15700, Loss: 2.9155e-05, L2 Relative_error: ['0.0308', '0.3849', '0.7620'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0646, layer 1 is being updated for the 1-th time
# Epoch 15800, Loss: 3.2559e-05, L2 Relative_error: ['0.0308', '0.3862', '0.7596'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0647, layer 1 is being updated for the 1-th time
# all stacks converged, returning to stack 0
# Epoch 15900, Loss: 3.0812e-05, L2 Relative_error: ['0.0307', '0.3840', '0.7599'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-01, lambda_phys : 1.0648, layer 0 is being updated for the 2-th time
# Epoch 16000, Loss: 5.9209e-05, L2 Relative_error: ['0.0289', '0.3858', '0.7578'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-01, lambda_phys : 1.0648, layer 0 is being updated for the 2-th time
# stack 0 has converged, passing to the next stack
# Epoch 16100, Loss: 2.3860e-05, L2 Relative_error: ['0.0272', '0.3897', '0.7608'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-01, lambda_phys : 1.0649, layer 1 is being updated for the 2-th time
# Epoch 16200, Loss: 2.4892e-05, L2 Relative_error: ['0.0272', '0.3889', '0.7611'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-01, lambda_phys : 1.0650, layer 1 is being updated for the 2-th time
# Epoch 16300, Loss: 2.3711e-05, L2 Relative_error: ['0.0272', '0.3938', '0.7557'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-01, lambda_phys : 1.0651, layer 1 is being updated for the 2-th time
# Epoch 16400, Loss: 2.6172e-05, L2 Relative_error: ['0.0272', '0.3901', '0.7597'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-01, lambda_phys : 1.0652, layer 1 is being updated for the 2-th time
# Epoch 16500, Loss: 2.4267e-05, L2 Relative_error: ['0.0272', '0.3911', '0.7603'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-01, lambda_phys : 1.0652, layer 1 is being updated for the 2-th time
# Epoch 16600, Loss: 2.5087e-05, L2 Relative_error: ['0.0272', '0.3904', '0.7573'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-01, lambda_phys : 1.0653, layer 1 is being updated for the 2-th time
# Epoch 16700, Loss: 2.7090e-05, L2 Relative_error: ['0.0272', '0.3882', '0.7614'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-01, lambda_phys : 1.0654, layer 1 is being updated for the 2-th time
# Epoch 16800, Loss: 2.7914e-05, L2 Relative_error: ['0.0272', '0.3901', '0.7603'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-01, lambda_phys : 1.0655, layer 1 is being updated for the 2-th time
# Epoch 16900, Loss: 2.2994e-05, L2 Relative_error: ['0.0272', '0.3895', '0.7563'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-01, lambda_phys : 1.0656, layer 1 is being updated for the 2-th time
# Epoch 17000, Loss: 2.5385e-05, L2 Relative_error: ['0.0272', '0.3881', '0.7600'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-01, lambda_phys : 1.0656, layer 1 is being updated for the 2-th time
# Epoch 17100, Loss: 2.9052e-05, L2 Relative_error: ['0.0272', '0.3861', '0.7616'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-01, lambda_phys : 1.0657, layer 1 is being updated for the 2-th time
# Epoch 17200, Loss: 2.7526e-05, L2 Relative_error: ['0.0272', '0.3869', '0.7634'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-01, lambda_phys : 1.0658, layer 1 is being updated for the 2-th time
# Epoch 17300, Loss: 2.3881e-05, L2 Relative_error: ['0.0272', '0.3842', '0.7627'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-01, lambda_phys : 1.0659, layer 1 is being updated for the 2-th time
# Epoch 17400, Loss: 2.4025e-05, L2 Relative_error: ['0.0272', '0.3842', '0.7600'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-01, lambda_phys : 1.0660, layer 1 is being updated for the 2-th time
# Epoch 17500, Loss: 2.4920e-05, L2 Relative_error: ['0.0272', '0.3832', '0.7582'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-01, lambda_phys : 1.0660, layer 1 is being updated for the 2-th time
# Epoch 17600, Loss: 2.3014e-05, L2 Relative_error: ['0.0272', '0.3842', '0.7550'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-01, lambda_phys : 1.0661, layer 1 is being updated for the 2-th time
# Epoch 17700, Loss: 2.4683e-05, L2 Relative_error: ['0.0272', '0.3814', '0.7583'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-01, lambda_phys : 1.0662, layer 1 is being updated for the 2-th time
# Epoch 17800, Loss: 2.3310e-05, L2 Relative_error: ['0.0272', '0.3858', '0.7531'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-01, lambda_phys : 1.0663, layer 1 is being updated for the 2-th time
# Epoch 17900, Loss: 2.7265e-05, L2 Relative_error: ['0.0272', '0.3812', '0.7589'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-01, lambda_phys : 1.0664, layer 1 is being updated for the 2-th time
# Epoch 18000, Loss: 2.5683e-05, L2 Relative_error: ['0.0272', '0.3808', '0.7584'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-01, lambda_phys : 1.0665, layer 1 is being updated for the 2-th time
# Epoch 18100, Loss: 2.5720e-05, L2 Relative_error: ['0.0272', '0.3790', '0.7590'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-01, lambda_phys : 1.0665, layer 1 is being updated for the 2-th time
# Epoch 18200, Loss: 2.3684e-05, L2 Relative_error: ['0.0272', '0.3768', '0.7592'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-01, lambda_phys : 1.0666, layer 1 is being updated for the 2-th time
# Epoch 18300, Loss: 2.6098e-05, L2 Relative_error: ['0.0272', '0.3758', '0.7572'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-01, lambda_phys : 1.0667, layer 1 is being updated for the 2-th time
# Epoch 18400, Loss: 2.5318e-05, L2 Relative_error: ['0.0272', '0.3774', '0.7579'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-01, lambda_phys : 1.0668, layer 1 is being updated for the 2-th time
# Epoch 18500, Loss: 2.6435e-05, L2 Relative_error: ['0.0272', '0.3730', '0.7606'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-01, lambda_phys : 1.0669, layer 1 is being updated for the 2-th time
# Epoch 18600, Loss: 2.6380e-05, L2 Relative_error: ['0.0272', '0.3730', '0.7615'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-01, lambda_phys : 1.0670, layer 1 is being updated for the 2-th time
# Epoch 18700, Loss: 2.7440e-05, L2 Relative_error: ['0.0272', '0.3701', '0.7624'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-01, lambda_phys : 1.0671, layer 1 is being updated for the 2-th time
# Epoch 18800, Loss: 2.6865e-05, L2 Relative_error: ['0.0272', '0.3676', '0.7636'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-01, lambda_phys : 1.0672, layer 1 is being updated for the 2-th time
# Epoch 18900, Loss: 2.6137e-05, L2 Relative_error: ['0.0272', '0.3682', '0.7584'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-01, lambda_phys : 1.0672, layer 1 is being updated for the 2-th time
# Epoch 19000, Loss: 2.7019e-05, L2 Relative_error: ['0.0272', '0.3667', '0.7604'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-01, lambda_phys : 1.0673, layer 1 is being updated for the 2-th time
# Epoch 19100, Loss: 2.4417e-05, L2 Relative_error: ['0.0272', '0.3663', '0.7587'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-01, lambda_phys : 1.0674, layer 1 is being updated for the 2-th time
# Epoch 19200, Loss: 2.5554e-05, L2 Relative_error: ['0.0272', '0.3641', '0.7583'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-01, lambda_phys : 1.0675, layer 1 is being updated for the 2-th time
# Epoch 19300, Loss: 2.5159e-05, L2 Relative_error: ['0.0272', '0.3626', '0.7597'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-01, lambda_phys : 1.0676, layer 1 is being updated for the 2-th time
# Epoch 19400, Loss: 2.7610e-05, L2 Relative_error: ['0.0272', '0.3597', '0.7603'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-01, lambda_phys : 1.0677, layer 1 is being updated for the 2-th time
# Epoch 19500, Loss: 2.5975e-05, L2 Relative_error: ['0.0272', '0.3601', '0.7546'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-01, lambda_phys : 1.0678, layer 1 is being updated for the 2-th time
# Epoch 19600, Loss: 2.5304e-05, L2 Relative_error: ['0.0272', '0.3593', '0.7592'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-01, lambda_phys : 1.0679, layer 1 is being updated for the 2-th time
# Epoch 19700, Loss: 2.1790e-05, L2 Relative_error: ['0.0272', '0.3566', '0.7585'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-01, lambda_phys : 1.0680, layer 1 is being updated for the 2-th time
# Epoch 19800, Loss: 2.5807e-05, L2 Relative_error: ['0.0272', '0.3572', '0.7599'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-01, lambda_phys : 1.0681, layer 1 is being updated for the 2-th time
# Epoch 19900, Loss: 2.8346e-05, L2 Relative_error: ['0.0272', '0.3562', '0.7574'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-01, lambda_phys : 1.0682, layer 1 is being updated for the 2-th time
# Epoch 20000, Loss: 2.7045e-05, L2 Relative_error: ['0.0272', '0.3551', '0.7596'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-01, lambda_phys : 1.0683, layer 1 is being updated for the 2-th time
# Epoch 20100, Loss: 2.3373e-05, L2 Relative_error: ['0.0272', '0.3506', '0.7577'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-01, lambda_phys : 1.0684, layer 1 is being updated for the 2-th time
# Epoch 20200, Loss: 2.6936e-05, L2 Relative_error: ['0.0272', '0.3523', '0.7571'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-01, lambda_phys : 1.0684, layer 1 is being updated for the 2-th time
# Epoch 20300, Loss: 2.6733e-05, L2 Relative_error: ['0.0272', '0.3510', '0.7576'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-01, lambda_phys : 1.0685, layer 1 is being updated for the 2-th time
# Epoch 20400, Loss: 2.6644e-05, L2 Relative_error: ['0.0272', '0.3498', '0.7585'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-01, lambda_phys : 1.0686, layer 1 is being updated for the 2-th time
# Epoch 20500, Loss: 2.7288e-05, L2 Relative_error: ['0.0272', '0.3489', '0.7553'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-01, lambda_phys : 1.0687, layer 1 is being updated for the 2-th time
# Epoch 20600, Loss: 2.5790e-05, L2 Relative_error: ['0.0272', '0.3474', '0.7574'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-01, lambda_phys : 1.0688, layer 1 is being updated for the 2-th time
# Epoch 20700, Loss: 2.7827e-05, L2 Relative_error: ['0.0272', '0.3466', '0.7586'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-01, lambda_phys : 1.0689, layer 1 is being updated for the 2-th time
# Epoch 20800, Loss: 2.3790e-05, L2 Relative_error: ['0.0272', '0.3452', '0.7531'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-01, lambda_phys : 1.0690, layer 1 is being updated for the 2-th time
# Epoch 20900, Loss: 2.5163e-05, L2 Relative_error: ['0.0272', '0.3445', '0.7549'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-01, lambda_phys : 1.0691, layer 1 is being updated for the 2-th time
# Epoch 21000, Loss: 2.7332e-05, L2 Relative_error: ['0.0272', '0.3432', '0.7578'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-01, lambda_phys : 1.0692, layer 1 is being updated for the 2-th time
# Epoch 21100, Loss: 2.5262e-05, L2 Relative_error: ['0.0272', '0.3411', '0.7523'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-01, lambda_phys : 1.0693, layer 1 is being updated for the 2-th time
# Epoch 21200, Loss: 2.3830e-05, L2 Relative_error: ['0.0272', '0.3400', '0.7528'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-01, lambda_phys : 1.0694, layer 1 is being updated for the 2-th time
# Epoch 21300, Loss: 2.5452e-05, L2 Relative_error: ['0.0272', '0.3376', '0.7563'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-01, lambda_phys : 1.0695, layer 1 is being updated for the 2-th time
# Epoch 21400, Loss: 2.5545e-05, L2 Relative_error: ['0.0272', '0.3347', '0.7558'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-01, lambda_phys : 1.0697, layer 1 is being updated for the 2-th time
# Epoch 21500, Loss: 2.5487e-05, L2 Relative_error: ['0.0272', '0.3352', '0.7521'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-01, lambda_phys : 1.0698, layer 1 is being updated for the 2-th time
# Epoch 21600, Loss: 2.4538e-05, L2 Relative_error: ['0.0272', '0.3371', '0.7541'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-01, lambda_phys : 1.0699, layer 1 is being updated for the 2-th time
# Epoch 21700, Loss: 2.6425e-05, L2 Relative_error: ['0.0272', '0.3319', '0.7540'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-01, lambda_phys : 1.0700, layer 1 is being updated for the 2-th time
# Epoch 21800, Loss: 2.5734e-05, L2 Relative_error: ['0.0272', '0.3273', '0.7595'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-01, lambda_phys : 1.0701, layer 1 is being updated for the 2-th time
# Epoch 21900, Loss: 2.7342e-05, L2 Relative_error: ['0.0272', '0.3282', '0.7609'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-01, lambda_phys : 1.0702, layer 1 is being updated for the 2-th time
# Epoch 22000, Loss: 3.1320e-05, L2 Relative_error: ['0.0272', '0.3236', '0.7618'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-01, lambda_phys : 1.0703, layer 1 is being updated for the 2-th time
# Epoch 22100, Loss: 2.3707e-05, L2 Relative_error: ['0.0272', '0.3234', '0.7583'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-01, lambda_phys : 1.0704, layer 1 is being updated for the 2-th time
# Epoch 22200, Loss: 2.6030e-05, L2 Relative_error: ['0.0272', '0.3208', '0.7578'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-01, lambda_phys : 1.0705, layer 1 is being updated for the 2-th time
# Epoch 22300, Loss: 2.5872e-05, L2 Relative_error: ['0.0272', '0.3199', '0.7604'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-01, lambda_phys : 1.0706, layer 1 is being updated for the 2-th time
# Epoch 22400, Loss: 2.6198e-05, L2 Relative_error: ['0.0272', '0.3194', '0.7556'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-01, lambda_phys : 1.0707, layer 1 is being updated for the 2-th time
# Epoch 22500, Loss: 2.3344e-05, L2 Relative_error: ['0.0272', '0.3193', '0.7513'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e-01, lambda_phys : 1.0709, layer 1 is being updated for the 2-th time
# ...
# Epoch 79100, Loss: 4.8817e-05, L2 Relative_error: ['0.0118', '0.0405', '0.7870'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e+00, lambda_phys : 1.5910, layer 2 is being updated for the 9-th time
# Epoch 79200, Loss: 4.7545e-05, L2 Relative_error: ['0.0118', '0.0405', '0.7817'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e+00, lambda_phys : 1.5934, layer 2 is being updated for the 9-th time
# Epoch 79300, Loss: 4.9472e-05, L2 Relative_error: ['0.0118', '0.0405', '0.7871'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e+00, lambda_phys : 1.5958, layer 2 is being updated for the 9-th time
# Epoch 79400, Loss: 4.7498e-05, L2 Relative_error: ['0.0118', '0.0405', '0.7868'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e+00, lambda_phys : 1.5982, layer 2 is being updated for the 9-th time
# Epoch 79500, Loss: 4.9303e-05, L2 Relative_error: ['0.0118', '0.0405', '0.7843'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e+00, lambda_phys : 1.6006, layer 2 is being updated for the 9-th time
# Epoch 79600, Loss: 4.7552e-05, L2 Relative_error: ['0.0118', '0.0405', '0.7885'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e+00, lambda_phys : 1.6030, layer 2 is being updated for the 9-th time
# Epoch 79700, Loss: 4.9823e-05, L2 Relative_error: ['0.0118', '0.0405', '0.7926'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e+00, lambda_phys : 1.6055, layer 2 is being updated for the 9-th time
# Epoch 79800, Loss: 4.7796e-05, L2 Relative_error: ['0.0118', '0.0405', '0.7851'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e+00, lambda_phys : 1.6079, layer 2 is being updated for the 9-th time
# Epoch 79900, Loss: 4.8516e-05, L2 Relative_error: ['0.0118', '0.0405', '0.7837'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e+00, lambda_phys : 1.6104, layer 2 is being updated for the 9-th time
# Epoch 80000, Loss: 4.8657e-05, L2 Relative_error: ['0.0118', '0.0405', '0.7809'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e+00, lambda_phys : 1.6128, layer 2 is being updated for the 9-th time
# Epoch 80100, Loss: 4.8298e-05, L2 Relative_error: ['0.0118', '0.0405', '0.7834'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e+00, lambda_phys : 1.6153, layer 2 is being updated for the 9-th time
# Epoch 80200, Loss: 4.8585e-05, L2 Relative_error: ['0.0118', '0.0405', '0.7788'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e+00, lambda_phys : 1.6177, layer 2 is being updated for the 9-th time
# Epoch 80300, Loss: 4.9306e-05, L2 Relative_error: ['0.0118', '0.0405', '0.7851'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e+00, lambda_phys : 1.6203, layer 2 is being updated for the 9-th time
# Epoch 80400, Loss: 4.9252e-05, L2 Relative_error: ['0.0118', '0.0405', '0.7902'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e+00, lambda_phys : 1.6228, layer 2 is being updated for the 9-th time
# Epoch 80500, Loss: 4.8936e-05, L2 Relative_error: ['0.0118', '0.0405', '0.7879'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e+00, lambda_phys : 1.6253, layer 2 is being updated for the 9-th time
# Epoch 80600, Loss: 4.9506e-05, L2 Relative_error: ['0.0118', '0.0405', '0.7885'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e+00, lambda_phys : 1.6278, layer 2 is being updated for the 9-th time
# Epoch 80700, Loss: 4.9417e-05, L2 Relative_error: ['0.0118', '0.0405', '0.7887'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e+00, lambda_phys : 1.6304, layer 2 is being updated for the 9-th time
# Epoch 80800, Loss: 4.9476e-05, L2 Relative_error: ['0.0118', '0.0405', '0.7833'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e+00, lambda_phys : 1.6329, layer 2 is being updated for the 9-th time
# Epoch 80900, Loss: 5.0355e-05, L2 Relative_error: ['0.0118', '0.0405', '0.7869'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e+00, lambda_phys : 1.6355, layer 2 is being updated for the 9-th time
# Epoch 81000, Loss: 4.8217e-05, L2 Relative_error: ['0.0118', '0.0405', '0.7811'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e+00, lambda_phys : 1.6381, layer 2 is being updated for the 9-th time
# Epoch 81100, Loss: 4.9804e-05, L2 Relative_error: ['0.0118', '0.0405', '0.7906'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e+00, lambda_phys : 1.6407, layer 2 is being updated for the 9-th time
# Epoch 81200, Loss: 5.0912e-05, L2 Relative_error: ['0.0118', '0.0405', '0.7860'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e+00, lambda_phys : 1.6433, layer 2 is being updated for the 9-th time
# Epoch 81300, Loss: 5.1372e-05, L2 Relative_error: ['0.0118', '0.0405', '0.7896'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e+00, lambda_phys : 1.6459, layer 2 is being updated for the 9-th time
# Epoch 81400, Loss: 5.1053e-05, L2 Relative_error: ['0.0118', '0.0405', '0.7879'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e+00, lambda_phys : 1.6486, layer 2 is being updated for the 9-th time
# Epoch 81500, Loss: 4.9389e-05, L2 Relative_error: ['0.0118', '0.0405', '0.7877'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e+00, lambda_phys : 1.6513, layer 2 is being updated for the 9-th time
# Epoch 81600, Loss: 5.0975e-05, L2 Relative_error: ['0.0118', '0.0405', '0.7913'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e+00, lambda_phys : 1.6540, layer 2 is being updated for the 9-th time
# Epoch 81700, Loss: 5.1198e-05, L2 Relative_error: ['0.0118', '0.0405', '0.7837'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e+00, lambda_phys : 1.6567, layer 2 is being updated for the 9-th time
# Epoch 81800, Loss: 5.0738e-05, L2 Relative_error: ['0.0118', '0.0405', '0.7806'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e+00, lambda_phys : 1.6594, layer 2 is being updated for the 9-th time
# Epoch 81900, Loss: 5.1755e-05, L2 Relative_error: ['0.0118', '0.0405', '0.7780'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e+00, lambda_phys : 1.6621, layer 2 is being updated for the 9-th time
# Epoch 82000, Loss: 5.1157e-05, L2 Relative_error: ['0.0118', '0.0405', '0.7761'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e+00, lambda_phys : 1.6649, layer 2 is being updated for the 9-th time
# Epoch 82100, Loss: 5.1419e-05, L2 Relative_error: ['0.0118', '0.0405', '0.7754'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e+00, lambda_phys : 1.6676, layer 2 is being updated for the 9-th time
# Epoch 82200, Loss: 5.1608e-05, L2 Relative_error: ['0.0118', '0.0405', '0.7753'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e+00, lambda_phys : 1.6704, layer 2 is being updated for the 9-th time
# Epoch 82300, Loss: 5.1112e-05, L2 Relative_error: ['0.0118', '0.0405', '0.7792'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e+00, lambda_phys : 1.6732, layer 2 is being updated for the 9-th time
# Epoch 82400, Loss: 5.1639e-05, L2 Relative_error: ['0.0118', '0.0405', '0.7782'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e+00, lambda_phys : 1.6760, layer 2 is being updated for the 9-th time
# Epoch 82500, Loss: 5.1355e-05, L2 Relative_error: ['0.0118', '0.0405', '0.7826'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e+00, lambda_phys : 1.6788, layer 2 is being updated for the 9-th time
# Epoch 82600, Loss: 4.8710e-05, L2 Relative_error: ['0.0118', '0.0405', '0.7775'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e+00, lambda_phys : 1.6815, layer 2 is being updated for the 9-th time
# Epoch 82700, Loss: 5.1457e-05, L2 Relative_error: ['0.0118', '0.0405', '0.7812'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e+00, lambda_phys : 1.6843, layer 2 is being updated for the 9-th time
# all stacks converged, returning to stack 0
# Epoch 82800, Loss: 3.6143e-05, L2 Relative_error: ['0.0118', '0.0409', '0.7784'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e+00, lambda_phys : 1.6871, layer 0 is being updated for the 10-th time
# Epoch 82900, Loss: 4.7356e-05, L2 Relative_error: ['0.0109', '0.0412', '0.7780'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e+00, lambda_phys : 1.6912, layer 0 is being updated for the 10-th time
# Epoch 83000, Loss: 1.4957e-05, L2 Relative_error: ['0.0099', '0.0409', '0.7795'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e+00, lambda_phys : 1.6949, layer 0 is being updated for the 10-th time
# stack 0 has converged, passing to the next stack
# Epoch 83100, Loss: 6.1891e-05, L2 Relative_error: ['0.0096', '0.0364', '0.7852'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e+00, lambda_phys : 1.6975, layer 1 is being updated for the 10-th time
# Epoch 83200, Loss: 6.1189e-05, L2 Relative_error: ['0.0096', '0.0359', '0.7847'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e+00, lambda_phys : 1.7005, layer 1 is being updated for the 10-th time
# Epoch 83300, Loss: 5.8806e-05, L2 Relative_error: ['0.0096', '0.0355', '0.7846'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e+00, lambda_phys : 1.7038, layer 1 is being updated for the 10-th time
# Epoch 83400, Loss: 6.5702e-05, L2 Relative_error: ['0.0096', '0.0351', '0.7851'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e+00, lambda_phys : 1.7072, layer 1 is being updated for the 10-th time
# stack 1 has converged, passing to the next stack
# Epoch 83500, Loss: 6.3033e-05, L2 Relative_error: ['0.0096', '0.0351', '0.7874'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e+00, lambda_phys : 1.7107, layer 2 is being updated for the 10-th time
# Epoch 83600, Loss: 6.0778e-05, L2 Relative_error: ['0.0096', '0.0351', '0.7889'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e+00, lambda_phys : 1.7143, layer 2 is being updated for the 10-th time
# Epoch 83700, Loss: 6.1006e-05, L2 Relative_error: ['0.0096', '0.0351', '0.7835'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e+00, lambda_phys : 1.7178, layer 2 is being updated for the 10-th time
# Epoch 83800, Loss: 6.5480e-05, L2 Relative_error: ['0.0096', '0.0351', '0.7814'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e+00, lambda_phys : 1.7213, layer 2 is being updated for the 10-th time
# Epoch 83900, Loss: 6.3601e-05, L2 Relative_error: ['0.0096', '0.0351', '0.7829'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e+00, lambda_phys : 1.7249, layer 2 is being updated for the 10-th time
# Epoch 84000, Loss: 6.3412e-05, L2 Relative_error: ['0.0096', '0.0351', '0.7777'], self.gammas: ['0.3333', '0.6667', '1.0000'], epsilon : 1.0e+00, lambda_phys : 1.7285, layer 2 is being updated for the 10-th time
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 46
#      43 pinn = StackedResPINN(model, optimizer_primal, optimizer_dual, gammas_init=gammas_init, T_max=T_max, parameters_init=parameters_init)
#      45 # Train the model with test data for loss visualization
# ---> 46 pinn.train(t_collocation, n_stacked_mf_layers, epochs=300000, t_test=t_test, u_test=u_tests, u_0=u_0)
#
# Cell In[3], line 397, in StackedResPINN.train(self, t_collocation, n_stacked_mf_layers, epochs, t_test, u_test, u_0)
#     393 train_losses, test_losses, l2_errors, gammas, sigma, layer_updated, omegas_t, lambda_phys = ([] for _ in range(8))
#     395 for epoch in range(epochs):
# --> 397     loss = self.primal_update(t_collocation)
#     398     if epoch % self.N_dual == 0 and epoch > 0: #dual update
#     399         loss = self.dual_update(t_collocation)
#
# Cell In[3], line 355, in StackedResPINN.primal_update(self, t_collocation)
#     353 def primal_update(self, t_collocation):
#     354     target_variables = self.get_target_variables(self.K)
# --> 355     loss = self.primal_update_k(t_collocation, target_variables, self.K)
#     356     return loss
#
# File /opt/anaconda3/envs/pinn-clean2/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /opt/anaconda3/envs/pinn-clean2/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:894, in Function.__call__(self, *args, **kwds)
#     891 compiler = "xla" if self._jit_compile else "nonXla"
#     893 with OptionalXlaContext(self._jit_compile):
# --> 894   result = self._call(*args, **kwds)
#     896 new_tracing_count = self.experimental_get_tracing_count()
#     897 without_tracing = (tracing_count == new_tracing_count)
#
# File /opt/anaconda3/envs/pinn-clean2/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:933, in Function._call(self, *args, **kwds)
#     930 self._lock.release()
#     931 # In this case we have not created variables on the first call. So we can
#     932 # run the first trace but we should fail if variables are created.
# --> 933 results = self._variable_creation_fn(*args, **kwds)
#     934 if self._created_variables and not ALLOW_DYNAMIC_VARIABLE_CREATION:
#     935   raise ValueError("Creating variables on a non-first call to a function"
#     936                    " decorated with tf.function.")
#
# File /opt/anaconda3/envs/pinn-clean2/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py:143, in TracingCompiler.__call__(self, *args, **kwargs)
#     140 with self._lock:
#     141   (concrete_function,
#     142    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 143 return concrete_function._call_flat(
#     144     filtered_flat_args, captured_inputs=concrete_function.captured_inputs)
#
# File /opt/anaconda3/envs/pinn-clean2/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py:1757, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1753 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1754 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1755     and executing_eagerly):
#    1756   # No tape is watching; skip to running the function.
# -> 1757   return self._build_call_outputs(self._inference_function.call(
#    1758       ctx, args, cancellation_manager=cancellation_manager))
#    1759 forward_backward = self._select_forward_and_backward_functions(
#    1760     args,
#    1761     possible_gradient_type,
#    1762     executing_eagerly)
#    1763 forward_function, args_with_tangents = forward_backward.forward()
#
# File /opt/anaconda3/envs/pinn-clean2/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py:381, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     379 with _InterpolateFunctionError(self):
#     380   if cancellation_manager is None:
# --> 381     outputs = execute.execute(
#     382         str(self.signature.name),
#     383         num_outputs=self._num_outputs,
#     384         inputs=args,
#     385         attrs=attrs,
#     386         ctx=ctx)
#     387   else:
#     388     outputs = execute.execute_with_cancellation(
#     389         str(self.signature.name),
#     390         num_outputs=self._num_outputs,
#    (...)
#     393         ctx=ctx,
#     394         cancellation_manager=cancellation_manager)
#
# File /opt/anaconda3/envs/pinn-clean2/lib/python3.9/site-packages/tensorflow/python/eager/execute.py:52, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50 try:
#      51   ctx.ensure_initialized()
# ---> 52   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                       inputs, attrs, num_outputs)
#      54 except core._NotOkStatusException as e:
#      55   if name is not None:
#
# KeyboardInterrupt:

# %%
for idx,alpha_val in enumerate(model.alpha):
    print(f"alpha_{idx} = {alpha_val}")
# Out:
# alpha_0 = <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=0.0>
# alpha_1 = <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=0.1677357>
# alpha_2 = <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=0.11092465>

# %%
u_pred_test, _, _ = model(t_test)
u_true_test = u_tests[-1]
absolute_error = tf.abs(u_pred_test - u_true_test).numpy()

plt.figure(figsize=(8, 6))
plt.hist(absolute_error, bins=30, alpha=0.75, label=["x1", "x2"], edgecolor='black')
plt.xlabel("Absolute Error")
plt.ylabel("Frequency")
plt.title("Distribution of Absolute Errors")
plt.legend()
plt.grid(True)
plt.savefig("distribution_absolute_errors_vanilla_pinn.eps", format='eps')
plt.show()

# %%
plt.figure(figsize=(6, 4))
plt.boxplot(absolute_error, tick_labels=["x1", "x2"], vert=True)
plt.ylabel('Absolute Error')
plt.title('Error Boxplot')
plt.grid(True)
plt.savefig('error_boxplot_curriculum_stacked_pinn.eps', format='eps')
plt.show()

# %%
"""
Plot the comparison of the output of each stack with the solution it tries to approximate
"""
# get the analytical solution each stack tries to approximate
n_steps = int(5e3)
u_tests = []
for i in range(n_stacked_mf_layers+1):
    u_test, t_test = analytical_solution(n_steps, T_max=T_max, parameters_init=pinn.gammas[i]*parameters_init, u_0=u_0)
    u_tests.append(u_test)
t_test = tf.reshape(t_test, (-1, 1))

u_approx = []
r_approx = []
u_old_approx = []
u_true = []
t_test_np =tf.reshape(t_test, [-1]).numpy()
sorted_indices = np.argsort(t_test_np)
t_sorted = t_test_np[sorted_indices]

# get the output of each stack and plot it
for i in range(n_stacked_mf_layers+1):
    u_i, u_old, r_i  = model(t_test, i=i)
    
    u_i_np = u_i.numpy()
    u_i_sorted = u_i_np[sorted_indices]
    u_approx.append(u_i_sorted)
    
    r_i_np = r_i.numpy()
    r_i_sorted = r_i_np[sorted_indices]
    r_approx.append(r_i_sorted)

    u_old_np = u_old.numpy()
    u_old_sorted = u_old_np[sorted_indices]
    u_old_approx.append(u_old_sorted)

    u_true_i_np = u_tests[i].numpy()
    u_true_i_sorted = u_true_i_np[sorted_indices]
    u_true.append(u_true_i_sorted)

    plt.figure(figsize=(10, 4))

    plt.subplot(2, 1, 1)
    plt.plot(t_sorted, u_i_sorted[:, 0], label=f'x_hat1_{i}')
    plt.plot(t_sorted, u_true_i_sorted[:, 0], linestyle='--', linewidth=1, label=f'x1_{i}')
    plt.plot(t_sorted, r_i_sorted[:, 0], linewidth=1, label=f'r_hat1_{i}', color='#A0A0A0')
    plt.plot(t_sorted, u_old_sorted[:, 0], linewidth=1.5, label=f'x_old_hat1_{i}', color='#AAAAAA')
    plt.xlabel("Time")
    plt.ylabel("State")
    plt.title(f"u_approx_{i} vs u_test_{i}")
    plt.legend()
    plt.grid(True)

    plt.subplot(2, 1, 2)
    plt.plot(t_sorted, u_i_sorted[:, 1], label=f'x_hat2_{i}')
    plt.plot(t_sorted, u_true_i_sorted[:, 1], linestyle='--', linewidth=1, label=f'x2_{i}')
    plt.plot(t_sorted, r_i_sorted[:, 1], linewidth=1, label=f'r_hat2_{i}', color='#A0A0A0')
    plt.plot(t_sorted, u_old_sorted[:, 1], linewidth=1.5, label=f'x_old_hat2_{i}', color='#AAAAAA')
    plt.xlabel("Time")
    plt.ylabel("State")
    plt.legend()
    plt.grid(True)
    plt.savefig(f"u_approx_{i} vs u_test_{i}.eps", format='eps')
    plt.show()
