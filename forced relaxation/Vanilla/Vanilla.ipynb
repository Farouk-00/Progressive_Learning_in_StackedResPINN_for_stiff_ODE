# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
class MLP(tf.Module):
    """
    Multi-Layer Perceptron (MLP) class with regularization handling.

    --------------
    insize: input size (int)
    outsize: output size (int)
    hsize: A list specifying the number of neurons in each hidden layer (list of ints).
    bias: Boolean indicating whether to include a bias term in the linear layers (default: True)
    nonlin: The activation function to be used in the hidden layers (default: nn.Tanh).
    linear_map:  The type of linear transformation to be used (default: nn.Linear)
    """
    def __init__(self, insize, outsize, hsizes, bias=True, nonlin=tf.tanh, linear_map=tf.keras.layers.Dense):
        super().__init__()
        self.in_features, self.out_features = insize, outsize
        self.nhidden = len(hsizes)
        self.layers = []
        self.nonlin = []
        self.seed = 123
        # Create linear layers and activation functions
        layer_sizes = [insize] + hsizes + [outsize]
        for k in range(len(layer_sizes) - 1):
            initializer = tf.keras.initializers.GlorotUniform(self.seed+k)
            self.layers.append(linear_map(units=layer_sizes[k+1], use_bias=bias, kernel_initializer=initializer))
            if k < self.nhidden:
                self.nonlin.append(nonlin)
            else:
                self.nonlin.append(tf.identity)

    def __call__(self, x):
        for i in range(len(self.layers)):
            x = self.nonlin[i](self.layers[i](x))
        return x

    def reg_error(self):
        """
        Compute the regularization error for the linear layers that support it.
        """
        reg_loss = 0.0
        for layer in self.layers:
            if hasattr(layer, "reg_error"):
                reg_loss += layer.reg_error()
        return reg_loss

# %%
class ResNetBlock(tf.Module):
    """
    A single ResNet block that takes the current output (from the previous layer or from the single-fidelity model)
    and the original input x, and learns a residual mapping.

    The block computes:
    out_new = out_old + alpha * F(x)

    F is implemented by an MLP.
    """
    def __init__(self, in_dim_x, in_dim_out, hres_sizes=[20, 20], bias=True, nonlin=tf.tanh):
        """
        in_dim_x : int, dimension of input x
        in_dim_out : int, dimension of the output (u)
        hres_sizes : list of ints, hidden layer sizes for the residual MLP
        bias : bool, whether to include bias in MLP layers
        nonlin : activation function class (e.g., nn.Tanh)
        """
        super().__init__()
        self.res_mlp = MLP(in_dim_x, in_dim_out, hsizes=hres_sizes, bias=bias, nonlin=nonlin)

    def __call__(self, x, out_old, alpha):
        """
        Forward pass of the ResNet block.

        x: tensor of shape (N, in_dim_x)
        out_old: tensor of shape (N, in_dim_out)
        alpha: scalar parameter controlling the amplitude of the residual update.

        return: out_new = out_old + alpha * F(x)
        """
        residual = self.res_mlp(x)
        out_new = out_old + tf.abs(alpha) * residual
        return out_new

# Define the Stacked MLP class for Stacked PINN with ResNet blocks
class StackedMLP(tf.Module):
    """
    Stacked Multi-Layer Perceptron designed for multi-fidelity learning where multiple layers are
    stacked to refine the prediction progressively. Now, each stacked layer is a ResNet block.
    """
    def __init__(
        self,
        insize,
        outsize,
        h_sf_sizes=[20, 20], # The single fidelity hidden size
        n_stacked_mf_layers=3,
        # The residual block hidden sizes for each stacked layer
        h_res_sizes=[20,20,20],
        bias=True,
        nonlin=tf.tanh,
        alpha_init=0.1,
        u_initial=None
    ):
        super().__init__()
        self.insize = insize
        self.outsize = outsize
        self.h_sf_sizes = h_sf_sizes
        self.n_stacked_mf_layers = n_stacked_mf_layers
        self.h_res_sizes = h_res_sizes
        self.bias = bias
        self.nonlin = nonlin
        self.alpha_init = alpha_init
        
        if u_initial is None:
            self.u0 = tf.zeros(shape=(outsize, 1), dtype=tf.float32)
        else:
            self.u0 = u_initial

        # Initial single-fidelity MLP
        self.first_layer = MLP(insize, outsize, hsizes=h_sf_sizes, bias=bias, nonlin=nonlin)

        # Alpha parameters, one per stacked layer
        self.alpha = [tf.Variable(0.0, trainable=True)] + [tf.Variable(alpha_init, trainable=True) for _ in range(n_stacked_mf_layers)]

        # Considering each stacked layer as a ResNet block
        self.layers = []
        for _ in range(n_stacked_mf_layers):
            res_block = ResNetBlock(insize, outsize, hres_sizes=self.h_res_sizes, bias=bias, nonlin=nonlin)
            self.layers.append(res_block)

    def __call__(self, x, i=None):
        if i is None:
            i = self.n_stacked_mf_layers
        i = min(i, self.n_stacked_mf_layers)

        # First layer (single-fidelity MLP)
        out = self.first_layer(x)
        out_old = tf.zeros_like(out)
        residual = out
        
        # Apply stacked ResNet blocks up to layer i
        for j in range(i):
            alpha = self.alpha[j+1]
            layer = self.layers[j]
            # Each layer: out = out + alpha * res_mlp(x)
            out_old = out
            out = layer(x, out_old, alpha)
            residual = out - out_old
        #return out_new, out_old, and residual
        return self.u0 + tf.tanh(x) * out, self.u0 + tf.tanh(x) * out_old, tf.tanh(x) * residual

    def get_alpha_loss(self, i=None):
        """
        Retrieve the accumulated loss from alpha parameters used for regularization purposes.

        :return: Alpha loss as a torch scalar.
        """
        return tf.pow(self.alpha[i], 4)

# Analytical solution for the forced relaxation equation
def analytical_solution(n_steps, T_max=1, parameters_init=50.0, u_0=0.0):
    """
    Analytical solution of the forced relaxation equation.

    Arguments:
    - n_steps        : number of time steps
    - T_max          : final time
    - parameters_init: value of the parameter μ (mu) in the equation
    - u_0            : initial condition u(0)

    Returns:
    - x: analytical trajectory (n_steps,), solution values over time
    - t: time array (n_steps,)
    """
    mu = parameters_init
    dt = T_max / float(n_steps)
    t = np.arange(0, n_steps * dt, dt)
    
    # Formule exacte
    x = (mu**2 * np.cos(t) + mu * np.sin(t)) / (mu**2 + 1) \
        - (mu**2 / (mu**2 + 1)) * np.exp(-mu * t)
    
    return tf.convert_to_tensor(x, dtype=tf.float32), tf.convert_to_tensor(t, dtype=tf.float32)

def l2_relative_error(u_pred, u_true, eps=1e-12):
    """
    Compute L2 relative error between predicted values and true values.

    Parameters:
    u_pred (Tensor): Predicted values (model output)
    u_true (Tensor): True values (ground truth)

    Returns:
    float: L2 relative error
    """
    u_pred = tf.convert_to_tensor(u_pred, dtype=tf.float32)
    u_true = tf.convert_to_tensor(u_true, dtype=tf.float32)

    u_pred = tf.reshape(u_pred, [-1])
    u_true = tf.reshape(u_true, [-1])

    num = tf.norm(u_pred - u_true, ord='euclidean')
    denom = tf.norm(u_true, ord='euclidean')
    return (num / (denom + eps)).numpy().item()

# Define the Stacked PINN class with modifications to store losses
class StackedResPINN:
    def __init__(self, model, optimizer_primal, optimizer_dual, lr_scheduler=None, patience=100, patience_gamma=100, N_collocation=1000, N_resample=50, N_dual=10, gammas_init=[], parameters_init=50.0, logger=None, T_max=1):
        self.model = model
        self.optimizer_primal = optimizer_primal
        self.optimizer_dual = optimizer_dual
        self.lr_scheduler = lr_scheduler
        self.logger = logger
        self.n_stacked_layers = model.n_stacked_mf_layers+1  # Number of stacked layers (Using for averaging loss) +1 for vanilla layer 0
        self.N_phys = N_collocation
        self.N_resample = N_resample
        self.N_dual = N_dual
        # Early stopping attributes
        self.patience = patience
        self.patience_gamma = patience_gamma
        self.best_loss = 0.0
        self.bad_epochs = 0
        self.bad_epochs_gamma = 0
        
        self.T_max = T_max
        self.weight = tf.Variable(1.0, dtype=tf.float32)
        self.parameters = parameters_init
        self.mu = self.parameters

        self.epsilon = tf.Variable(1.0e-2, dtype=tf.float32, trainable=False)
        self.omegas_t = tf.Variable(tf.zeros((self.n_stacked_layers, N_collocation), dtype=tf.float32), trainable=False)

        self.K = 0  # K is the index of the stack being updated
        self.update_count = 1

        # initialize the sequence alpha and the sitffness sigma of each stack
        self.gammas = tf.Variable(initial_value=gammas_init, trainable=False)
        self.old_gammas = self.gammas # for early stopping check
        self.sigma = tf.Variable(initial_value= (-1.0e-3) * tf.ones([self.n_stacked_layers], dtype=tf.float32),trainable=False)

    def resample(self):
        t_collocation = tf.random.uniform(shape=(self.N_phys, 1), minval=0, maxval=self.T_max)
        return t_collocation


    #############################       UPDATE ALPHA        ############################

    def cummin(self, x):
        """ 
        function cummin to force the sequence gamma_i to be nondecreasing:
            - takes a sequence a_i as entry
            - returns a sequence where each term gamma_i = min(gamma_i, gamma_i+1) begining with the first term
        """
        x = tf.convert_to_tensor(x)
        x_list = tf.unstack(x)

        out = []
        current_min = x_list[0]
        out.append(current_min)

        for xi in x_list[1:]:
            current_min = tf.minimum(current_min, xi)
            out.append(current_min)

        return tf.stack(out)
    
    def update_stiffness_indicators(self, t):
        """
        compute the stiffness indicator of each stack at each time t* = = argmin(sigma_N(t))
        """
        # compute the current solution of each stack
        u1 = []
        for k in range(self.n_stacked_layers):
            U, _, _ = self.model(t, i=k)
            u1.append(U[:, 0:1])
        u1 = tf.squeeze(tf.stack(u1, axis=1), axis=2)

        #compute sigma
        sigma = -self.parameters + 0.0*u1

        # get t* = argmin(sigma_N(t)) and get each sigma_i at t*
        last_layer_sigma = sigma[:, -1]
        min_index = tf.argmin(last_layer_sigma)
        sigma_at_min_index = sigma[min_index, :]
        self.sigma.assign(self.cummin(sigma_at_min_index))

    def update_gammas(self, smoothing_coef, t):
        """
        updates the sequence gamma_i depending on the stiffness gamma_i of the solution of each stack:
            - gamma_i = (i+1)/(N+1) * sigma_N(t*)/sigma_i(t*)
            - t* = argmin(sigma_N(t))
        """
        self.update_stiffness_indicators(t)
        i_s = tf.cumsum(tf.ones([self.n_stacked_layers], dtype=tf.float32))

        # compute each new gamma_i
        alpha_i = tf.abs((i_s*self.sigma[-1]) / (self.n_stacked_layers*self.sigma))

        new_gammas = tf.minimum(alpha_i, tf.ones([self.n_stacked_layers], dtype=tf.float32))   # force gamma_i to range between 0 and 1
        new_gammas = tf.reverse(self.cummin(tf.reverse(new_gammas, axis=[0])), axis=[0]) # prevent each gamma_i to be higher than gamma_(i+1)
        new_gammas = tf.stop_gradient((1 - smoothing_coef) * self.gammas + smoothing_coef * new_gammas) # smooth gamma and prevent gradient propagation through its computation
        self.gammas.assign(new_gammas)


    #############################       LOSS       ############################

    def f(self, u1, t, alpha_i):
        term1 = self.mu*alpha_i * (tf.cos(t) - u1)
        return term1

    @tf.function
    def loss_function(self, t, k):
        """
        loss function to compute the residual loss of stack k
            - k is the index of the stack currently being optimized
        """
        losses = []
        omegas_t = []
        inp = t

        for i in range(self.n_stacked_layers):
            if i == k:  # if i is the index of the stack currently being optimized
                if i ==0:
                    with tf.GradientTape(watch_accessed_variables=False) as tape1:
                        tape1.watch(inp)
                        U, _, _ = self.model(inp, i=i)
                    U_t = tape1.batch_jacobian(U, inp)
                    u1 = U[:, 0:1]
                    
                    f = tf.squeeze(U_t, axis=2) - tf.concat(self.f(u1, t, self.gammas[i]), axis=1)

                else:
                    with tf.GradientTape(watch_accessed_variables=False) as tape1:
                        tape1.watch(inp)
                        U, U_old, R = self.model(inp, i=i)
                    R_t = tape1.batch_jacobian(R, inp)
                    u1 = U[:, 0:1]
                    u1_old = U_old[:, 0:1]
                    
                    f = tf.squeeze(R_t, axis=2) - tf.concat(self.f(u1, t, self.gammas[i]), axis=1) + tf.concat(self.f(u1_old, t, self.gammas[i-1]), axis=1)
                
                f_squared = tf.square(f)
                f_squared_sum = tf.reduce_sum(f_squared, axis=1, keepdims=True)
                f_squared_cumsum = tf.cumsum(f_squared_sum, exclusive=True)
                omega_t = tf.stop_gradient(tf.exp(-self.epsilon * f_squared_cumsum))
                weighted_f_squared = omega_t * f_squared
                
                ode_i = self.weight * tf.reduce_mean(weighted_f_squared) + self.model.get_alpha_loss(i=i)
                
            else: # if i is NOT the index of the stack currently being optimized, do not comput loss at this stack
                ode_i = 0.0
                u1 = tf.zeros_like(inp[:, :1])
                if i < k:
                    omega_t = tf.stop_gradient(tf.ones((self.N_phys, 1), dtype=tf.float32))
                else:
                    omega_t = tf.stop_gradient(tf.zeros((self.N_phys, 1), dtype=tf.float32))

            omegas_t.append(omega_t)
            losses.append(ode_i)

        self.omegas_t.assign(tf.squeeze(tf.stack(omegas_t, axis=0), axis=-1))

        return losses
    
    def get_target_variables(self, k):
        """
        get weights and biaises theta of stack k to be optimized
        """
        variables = []
        if k == 0:
            variables.extend(self.model.first_layer.trainable_variables)
        else:
            variables.extend(self.model.layers[k-1].trainable_variables)
        variables.append(self.model.alpha[k])
        return variables

    @tf.function
    def total_loss(self, t_collocation, k):
        physics_loss = self.loss_function(t_collocation, k)
        return sum(physics_loss)

    @tf.function
    def primal_update_k(self, t_collocation, target_variables, k):
        with tf.GradientTape(watch_accessed_variables=False) as loss_tape:
            loss_tape.watch(target_variables)
            loss = self.total_loss(t_collocation, k)
        grads = loss_tape.gradient(loss, target_variables)
        self.optimizer_primal[k].apply_gradients(zip(grads, target_variables))
        return loss
    
    def primal_update(self, t_collocation):
        target_variables = self.get_target_variables(self.K)
        loss = self.primal_update_k(t_collocation, target_variables, self.K)
        return loss
    
    @tf.function
    def dual_update(self, t_collocation):
        with tf.GradientTape(watch_accessed_variables=False) as loss_tape:
            loss_tape.watch(self.weight)
            loss = -self.loss_function(t_collocation, self.K)[self.K]
        grads = loss_tape.gradient(loss, [self.weight])
        self.optimizer_dual.apply_gradients(
            zip(grads, [self.weight])
        )
        return -loss


    #############################       TRAIN       ############################

    def train(self, t_collocation, n_stacked_mf_layers, epochs=1000, t_test=None, u_test=None, u_0=[10.0, 5.0]):
        
        """
        initialize the N+1 optimizers
        """
        all_trainable_vars = []
        for j in range(self.n_stacked_layers):
            _ = self.model(t_collocation, i=j)
            _ = self.model.get_alpha_loss(i=j)
            if j > 0:
                all_trainable_vars.extend(self.model.layers[j-1].trainable_variables)
            else:
                all_trainable_vars.extend(self.model.first_layer.trainable_variables)
            all_trainable_vars.append(self.model.alpha[j])

            with tf.GradientTape() as tape:
                dummy_loss = self.total_loss(t_collocation, j)
            dummy_grads = tape.gradient(dummy_loss, all_trainable_vars)
            grads_and_vars = [(g, v) for g, v in zip(dummy_grads, all_trainable_vars) if g is not None]
            self.optimizer_primal[j].apply_gradients(grads_and_vars)


        train_losses, test_losses, l2_errors, gammas, sigma, layer_updated, omegas_t, lambda_phys = ([] for _ in range(8))

        for epoch in range(epochs):

            loss = self.primal_update(t_collocation)
            if epoch % self.N_dual == 0 and epoch > 0: #dual update
                loss = self.dual_update(t_collocation)
            if epoch % self.N_resample == 0 and epoch > 0: #resampling of t_collocation
                t_collocation = self.resample()

            # Learning rate scheduling if type ReduceLROnPlateau
            if self.lr_scheduler:
                if hasattr(self.lr_scheduler, 'on_epoch_end'):
                    self.lr_scheduler.on_epoch_end(epoch=None, logs={"loss": loss.numpy()})
        
            # Logging
            if self.logger:
                self.logger.log_metrics({"loss": loss.numpy()}, step=epoch)

            train_losses.append(loss.numpy())
            gammas.append(self.gammas.numpy().copy())
            sigma.append(self.sigma.numpy().copy())
            layer_updated.append(self.K)
            omegas_t.append(self.omegas_t.numpy().copy())
            lambda_phys.append(self.weight.numpy().copy())

            if epoch % 100 == 0 or epoch == epochs-1:

                # Calculate test loss if test data is provided
                if t_test is not None and u_test is not None:

                    u_pred_test = []
                    for i in range(self.model.n_stacked_mf_layers+1):
                        u_i, _, _ = self.model(t_test, i)
                        u_pred_test.append(u_i)
                    test_loss = [tf.reduce_mean(tf.square(u_pred_test_i - u_test_i)).numpy() for u_pred_test_i, u_test_i  in zip(u_pred_test, u_test)]
                    test_losses.append(test_loss)

                    # Compute L2 relative error
                    l2_error = [l2_relative_error(u_pred_test_i, u_test_i) for u_pred_test_i, u_test_i in zip(u_pred_test, u_test)]
                    l2_errors.append(l2_error)

            
                print(f"Epoch {epoch}, Loss: {loss.numpy():.4e}, L2 Relative_error: {[f'{err:.4f}' for err in l2_error]}, self.gammas: {[f'{gamma:.4f}' for gamma in self.gammas.numpy()]}, epsilon : {self.epsilon.numpy():.1e}, lambda_phys : {self.weight.numpy():.4f}, layer {self.K} is being updated for the {self.update_count}-th time")

        # Plot losses
        plt.figure(figsize=(10, 5))
        plt.plot(train_losses, label="Training Loss")
        if test_losses:
            # test_losses is a list of lists, one per epoch. Plotting the mean test loss across layers.
            mean_test_losses = [np.mean(tl) for tl in test_losses]
            plt.plot(mean_test_losses, label="Test Loss", color="orange")
        plt.xlabel("Epochs")
        plt.ylabel("Loss")
        plt.title("Training and Test Loss")
        plt.legend()
        plt.grid(True)
        plt.savefig("losses over epochs.eps", format='eps')
        plt.show()

        # Plot L2 relative error over epochs
        if l2_errors:  # Check if l2_errors is not empty
            plt.figure()
            plt.plot(range(len(l2_errors)), l2_errors, label=f"L2 Relative Error (0-{n_stacked_mf_layers})")
            plt.xlabel("Epochs")
            plt.ylabel("L2 Relative Error")
            plt.title("L2 Relative Error over Training Epochs")
            plt.yscale("log")
            plt.legend()
            plt.grid(True, which="both")
            plt.savefig("L2 relative error over epochs.eps", format='eps')
            plt.show()

        # plot final output vs analytical solution
        t_test = tf.reshape(t_test, [-1]).numpy()
        sorted_indices = np.argsort(t_test)
        t_sorted = t_test[sorted_indices]
        
        u_pred_np = u_pred_test[-1].numpy()
        u_sorted = u_pred_np[sorted_indices]
        u_true_np = u_test[-1].numpy()
        u_true_sorted = u_true_np[sorted_indices]

        plt.figure(figsize=(10, 20))
        plt.subplot(3, 1, 1)
        plt.plot(t_sorted, u_sorted, label='x_hat1')
        plt.plot(t_sorted, u_true_sorted, label='x1')
        plt.xlabel("Time")
        plt.ylabel("State")
        plt.legend()
        plt.grid(True)
        plt.show()

        # Plot gammas over epochs
        gammas_np = np.array([alph for alph in gammas])
        plt.figure()
        for i in range(gammas_np.shape[1]):
            plt.plot(range(len(gammas_np)), gammas_np[:, i], label=f"gamma_{i}")
        plt.xlabel("Epochs")
        plt.ylabel(f"gamma values")
        plt.title("gamma over Training Epochs")
        plt.grid(True)
        plt.legend()
        plt.savefig("gammas over epochs.eps", format='eps')
        plt.show()

        # Plot sigmas over epochs
        sigma_np = np.array([sigm for sigm in sigma])
        plt.figure()
        for i in range(sigma_np.shape[1]):
            plt.plot(range(len(sigma_np)), sigma_np[:, i], label=f"sigma_{i}")
        plt.xlabel("Epochs")
        plt.ylabel(f"sigma values")
        plt.yscale('symlog', linthresh=1e-3)
        plt.title("sigma over Training Epochs")
        plt.grid(True)
        plt.legend()
        plt.savefig("sigma over epochs.eps", format='eps')
        plt.show()

        # Plot k over epochs
        plt.figure()
        plt.plot(range(len(layer_updated)), layer_updated, label="layer_updated")
        plt.xlabel("Epochs")
        plt.ylabel(f"layer_updated values")
        plt.title("layer_updated over Training Epochs")
        plt.grid(True)
        plt.legend()
        plt.savefig("K over epochs.eps", format='eps')
        plt.show()

        # Plot lambda_phys over epochs
        plt.figure()
        plt.plot(range(len(lambda_phys)), lambda_phys, label="lambda_phys")
        plt.xlabel("Epochs")
        plt.ylabel(f"lambda_phys values")
        plt.title("lambda_phys over Training Epochs")
        plt.grid(True)
        plt.legend()
        plt.savefig("lambda_phys over epochs.eps", format='eps')
        plt.show()

# %%
if __name__ == "__main__":
    # Parameters
    T_max = 1
    parameters_init = 50.0
    n_stacked_mf_layers = 0
    u_0 = 0.0
    insize = 1  # Input size (t)
    outsize = 1  # Output size (u)
    h_sf_sizes = [40, 40, 40]
    # Residual block hidden sizes
    h_res_sizes = [40, 40, 40]
    gammas_init = []
    
    for i in range(n_stacked_mf_layers+1):
        gammas_init.append((i+1)/(n_stacked_mf_layers+1))
    print(f'gammas_init : {gammas_init}')

    # Initial condition
    N_initial = 1
    t_initial = tf.zeros(shape=(N_initial, 1), dtype=tf.float32)
    u_initial = tf.convert_to_tensor([u_0] * N_initial, dtype=tf.float32)

    # Create model
    model = StackedMLP(insize, outsize, h_sf_sizes=h_sf_sizes, h_res_sizes=h_res_sizes,
                       n_stacked_mf_layers=n_stacked_mf_layers, alpha_init=0.05, u_initial=u_initial)

    optimizer_primal = [tf.keras.optimizers.legacy.Adam(learning_rate=1e-3)] + [tf.keras.optimizers.legacy.Adam(learning_rate=1e-4) for _ in range(n_stacked_mf_layers)]
    optimizer_dual = tf.keras.optimizers.legacy.Adam(learning_rate=1e-3)

    # Test points (optional for validation/testing)
    n_steps = int(5e3)
    u_tests = []
    for i in range(n_stacked_mf_layers+1):
        u_test, t_test = analytical_solution(n_steps, T_max=T_max, parameters_init=gammas_init[i]*parameters_init, u_0=u_0)
        u_tests.append(u_test)
    t_test = tf.reshape(t_test, (-1, 1))

    # Create collocation points
    N_collocation = 1000
    t_collocation = tf.random.uniform(shape=(N_collocation, 1), minval=0, maxval=T_max)

    # Create instance of Stacked Residual PINN
    pinn = StackedResPINN(model, optimizer_primal, optimizer_dual, gammas_init=gammas_init, T_max=T_max, parameters_init=parameters_init)

    # Train the model with test data for loss visualization
    pinn.train(t_collocation, n_stacked_mf_layers, epochs=300000, t_test=t_test, u_test=u_tests, u_0=u_0)
# Out:
# gammas_init : [1.0]
# 2025-08-12 14:45:44.611078: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# Epoch 0, Loss: 4.2662e-01, L2 Relative_error: ['0.8158'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0000, layer 0 is being updated for the 1-th time
# Epoch 100, Loss: 3.6320e-01, L2 Relative_error: ['0.5606'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0087, layer 0 is being updated for the 1-th time
# Epoch 200, Loss: 6.1256e-01, L2 Relative_error: ['0.3509'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0141, layer 0 is being updated for the 1-th time
# Epoch 300, Loss: 6.8101e-01, L2 Relative_error: ['1.6710'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0202, layer 0 is being updated for the 1-th time
# Epoch 400, Loss: 1.7693e-01, L2 Relative_error: ['0.8777'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0285, layer 0 is being updated for the 1-th time
# Epoch 500, Loss: 1.4939e-01, L2 Relative_error: ['0.3262'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0340, layer 0 is being updated for the 1-th time
# Epoch 600, Loss: 2.2489e-01, L2 Relative_error: ['0.3248'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0384, layer 0 is being updated for the 1-th time
# Epoch 700, Loss: 4.5422e-01, L2 Relative_error: ['0.6271'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0428, layer 0 is being updated for the 1-th time
# Epoch 800, Loss: 6.2669e-01, L2 Relative_error: ['0.2544'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0484, layer 0 is being updated for the 1-th time
# Epoch 900, Loss: 1.9169e+00, L2 Relative_error: ['0.3644'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0556, layer 0 is being updated for the 1-th time
# Epoch 1000, Loss: 4.8301e-01, L2 Relative_error: ['0.1973'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0641, layer 0 is being updated for the 1-th time
# Epoch 1100, Loss: 1.3374e+00, L2 Relative_error: ['0.1796'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0759, layer 0 is being updated for the 1-th time
# Epoch 1200, Loss: 1.6566e+00, L2 Relative_error: ['0.2516'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0884, layer 0 is being updated for the 1-th time
# Epoch 1300, Loss: 3.5543e-01, L2 Relative_error: ['0.1294'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0982, layer 0 is being updated for the 1-th time
# Epoch 1400, Loss: 9.9782e-01, L2 Relative_error: ['0.1765'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.1055, layer 0 is being updated for the 1-th time
# Epoch 1500, Loss: 2.6041e-01, L2 Relative_error: ['0.1000'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.1115, layer 0 is being updated for the 1-th time
# Epoch 1600, Loss: 8.0615e-01, L2 Relative_error: ['0.2302'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.1178, layer 0 is being updated for the 1-th time
# Epoch 1700, Loss: 3.2532e-01, L2 Relative_error: ['0.0816'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.1252, layer 0 is being updated for the 1-th time
# Epoch 1800, Loss: 4.1151e-01, L2 Relative_error: ['0.1612'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.1311, layer 0 is being updated for the 1-th time
# Epoch 1900, Loss: 2.9464e-01, L2 Relative_error: ['0.0653'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.1355, layer 0 is being updated for the 1-th time
# Epoch 2000, Loss: 6.0253e-01, L2 Relative_error: ['0.0588'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.1414, layer 0 is being updated for the 1-th time
# Epoch 2100, Loss: 1.9743e-01, L2 Relative_error: ['0.0533'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.1472, layer 0 is being updated for the 1-th time
# Epoch 2200, Loss: 9.7026e-01, L2 Relative_error: ['0.1239'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.1535, layer 0 is being updated for the 1-th time
# Epoch 2300, Loss: 1.2967e-01, L2 Relative_error: ['0.0559'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.1602, layer 0 is being updated for the 1-th time
# Epoch 2400, Loss: 3.5608e-01, L2 Relative_error: ['0.0447'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.1652, layer 0 is being updated for the 1-th time
# Epoch 2500, Loss: 7.3435e-01, L2 Relative_error: ['0.0994'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.1713, layer 0 is being updated for the 1-th time
# Epoch 2600, Loss: 2.5773e-01, L2 Relative_error: ['0.0396'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.1775, layer 0 is being updated for the 1-th time
# Epoch 2700, Loss: 3.0577e-01, L2 Relative_error: ['0.1054'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.1822, layer 0 is being updated for the 1-th time
# Epoch 2800, Loss: 3.2227e-01, L2 Relative_error: ['0.0353'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.1861, layer 0 is being updated for the 1-th time
# Epoch 2900, Loss: 3.7989e-01, L2 Relative_error: ['0.0684'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.1901, layer 0 is being updated for the 1-th time
# Epoch 3000, Loss: 2.0445e-01, L2 Relative_error: ['0.0387'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.1948, layer 0 is being updated for the 1-th time
# Epoch 3100, Loss: 3.3034e-01, L2 Relative_error: ['0.0300'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.1992, layer 0 is being updated for the 1-th time
# Epoch 3200, Loss: 3.1102e-01, L2 Relative_error: ['0.0514'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.2031, layer 0 is being updated for the 1-th time
# Epoch 3300, Loss: 1.9728e-01, L2 Relative_error: ['0.0275'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.2063, layer 0 is being updated for the 1-th time
# Epoch 3400, Loss: 2.5107e-01, L2 Relative_error: ['0.0286'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.2100, layer 0 is being updated for the 1-th time
# Epoch 3500, Loss: 2.4444e-01, L2 Relative_error: ['0.0255'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.2137, layer 0 is being updated for the 1-th time
# Epoch 3600, Loss: 2.2453e-01, L2 Relative_error: ['0.0267'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.2177, layer 0 is being updated for the 1-th time
# Epoch 3700, Loss: 2.8202e-01, L2 Relative_error: ['0.0245'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.2224, layer 0 is being updated for the 1-th time
# Epoch 3800, Loss: 5.0350e-01, L2 Relative_error: ['0.0260'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.2269, layer 0 is being updated for the 1-th time
# Epoch 3900, Loss: 2.6433e-01, L2 Relative_error: ['0.0235'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.2324, layer 0 is being updated for the 1-th time
# Epoch 4000, Loss: 1.9885e-01, L2 Relative_error: ['0.0240'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.2371, layer 0 is being updated for the 1-th time
# Epoch 4100, Loss: 2.0119e-01, L2 Relative_error: ['0.0224'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.2409, layer 0 is being updated for the 1-th time
# Epoch 4200, Loss: 2.4634e-01, L2 Relative_error: ['0.0208'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.2444, layer 0 is being updated for the 1-th time
# Epoch 4300, Loss: 6.4500e-01, L2 Relative_error: ['0.0203'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.2488, layer 0 is being updated for the 1-th time
# Epoch 4400, Loss: 4.3758e-01, L2 Relative_error: ['0.0219'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.2555, layer 0 is being updated for the 1-th time
# Epoch 4500, Loss: 2.8787e-01, L2 Relative_error: ['0.0191'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.2610, layer 0 is being updated for the 1-th time
# Epoch 4600, Loss: 3.7189e-01, L2 Relative_error: ['0.0201'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.2658, layer 0 is being updated for the 1-th time
# Epoch 4700, Loss: 1.2919e-01, L2 Relative_error: ['0.0345'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.2701, layer 0 is being updated for the 1-th time
# Epoch 4800, Loss: 5.7792e-01, L2 Relative_error: ['0.0181'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.2742, layer 0 is being updated for the 1-th time
# Epoch 4900, Loss: 2.8316e-01, L2 Relative_error: ['0.0181'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.2794, layer 0 is being updated for the 1-th time
# Epoch 5000, Loss: 2.9955e-01, L2 Relative_error: ['0.0173'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.2851, layer 0 is being updated for the 1-th time
# Epoch 5100, Loss: 2.8852e-01, L2 Relative_error: ['0.0174'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.2902, layer 0 is being updated for the 1-th time
# Epoch 5200, Loss: 2.4316e-01, L2 Relative_error: ['0.0184'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.2956, layer 0 is being updated for the 1-th time
# Epoch 5300, Loss: 5.7351e-01, L2 Relative_error: ['0.0167'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.3008, layer 0 is being updated for the 1-th time
# Epoch 5400, Loss: 2.3248e-01, L2 Relative_error: ['0.0172'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.3062, layer 0 is being updated for the 1-th time
# Epoch 5500, Loss: 4.2469e-01, L2 Relative_error: ['0.0160'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.3112, layer 0 is being updated for the 1-th time
# Epoch 5600, Loss: 3.4811e-01, L2 Relative_error: ['0.0156'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.3164, layer 0 is being updated for the 1-th time
# Epoch 5700, Loss: 4.5087e-01, L2 Relative_error: ['0.0166'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.3210, layer 0 is being updated for the 1-th time
# Epoch 5800, Loss: 5.3043e-01, L2 Relative_error: ['0.0157'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.3262, layer 0 is being updated for the 1-th time
# Epoch 5900, Loss: 5.3772e-01, L2 Relative_error: ['0.0154'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.3325, layer 0 is being updated for the 1-th time
# Epoch 6000, Loss: 3.0024e-01, L2 Relative_error: ['0.0168'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.3378, layer 0 is being updated for the 1-th time
# Epoch 6100, Loss: 2.7827e-01, L2 Relative_error: ['0.0157'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.3424, layer 0 is being updated for the 1-th time
# Epoch 6200, Loss: 2.3820e-01, L2 Relative_error: ['0.0141'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.3466, layer 0 is being updated for the 1-th time
# Epoch 6300, Loss: 3.3235e-01, L2 Relative_error: ['0.0128'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.3515, layer 0 is being updated for the 1-th time
# Epoch 6400, Loss: 2.6566e-01, L2 Relative_error: ['0.0135'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.3569, layer 0 is being updated for the 1-th time
# Epoch 6500, Loss: 2.0519e-01, L2 Relative_error: ['0.0142'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.3623, layer 0 is being updated for the 1-th time
# Epoch 6600, Loss: 2.5804e-01, L2 Relative_error: ['0.0121'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.3667, layer 0 is being updated for the 1-th time
# Epoch 6700, Loss: 3.5040e-01, L2 Relative_error: ['0.0130'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.3715, layer 0 is being updated for the 1-th time
# Epoch 6800, Loss: 2.0264e-01, L2 Relative_error: ['0.0124'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.3769, layer 0 is being updated for the 1-th time
# Epoch 6900, Loss: 3.5757e-01, L2 Relative_error: ['0.0118'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.3817, layer 0 is being updated for the 1-th time
# Epoch 7000, Loss: 2.0273e-01, L2 Relative_error: ['0.0140'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.3866, layer 0 is being updated for the 1-th time
# Epoch 7100, Loss: 2.3170e-01, L2 Relative_error: ['0.0107'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.3910, layer 0 is being updated for the 1-th time
# Epoch 7200, Loss: 3.5392e-01, L2 Relative_error: ['0.0115'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.3960, layer 0 is being updated for the 1-th time
# Epoch 7300, Loss: 3.5560e-01, L2 Relative_error: ['0.0120'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.4013, layer 0 is being updated for the 1-th time
# Epoch 7400, Loss: 2.5165e-01, L2 Relative_error: ['0.0108'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.4064, layer 0 is being updated for the 1-th time
# Epoch 7500, Loss: 2.9017e-01, L2 Relative_error: ['0.0102'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.4116, layer 0 is being updated for the 1-th time
# Epoch 7600, Loss: 3.3283e-01, L2 Relative_error: ['0.0117'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.4165, layer 0 is being updated for the 1-th time
# Epoch 7700, Loss: 1.7716e-01, L2 Relative_error: ['0.1322'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.4213, layer 0 is being updated for the 1-th time
# Epoch 7800, Loss: 4.4716e-01, L2 Relative_error: ['0.0103'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.4254, layer 0 is being updated for the 1-th time
# Epoch 7900, Loss: 2.2869e-01, L2 Relative_error: ['0.0099'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.4306, layer 0 is being updated for the 1-th time
# Epoch 8000, Loss: 3.6100e-01, L2 Relative_error: ['0.0113'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.4360, layer 0 is being updated for the 1-th time
# Epoch 8100, Loss: 2.6195e-01, L2 Relative_error: ['0.0106'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.4417, layer 0 is being updated for the 1-th time
# Epoch 8200, Loss: 2.5336e-01, L2 Relative_error: ['0.0094'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.4478, layer 0 is being updated for the 1-th time
# Epoch 8300, Loss: 3.3528e-01, L2 Relative_error: ['0.0103'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.4526, layer 0 is being updated for the 1-th time
# Epoch 8400, Loss: 4.2035e-01, L2 Relative_error: ['0.0101'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.4577, layer 0 is being updated for the 1-th time
# Epoch 8500, Loss: 3.9027e-01, L2 Relative_error: ['0.0099'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.4639, layer 0 is being updated for the 1-th time
# Epoch 8600, Loss: 2.4089e-01, L2 Relative_error: ['0.0094'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.4701, layer 0 is being updated for the 1-th time
# Epoch 8700, Loss: 2.6318e-01, L2 Relative_error: ['0.0099'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.4755, layer 0 is being updated for the 1-th time
# Epoch 8800, Loss: 2.1324e-01, L2 Relative_error: ['0.0099'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.4807, layer 0 is being updated for the 1-th time
# Epoch 8900, Loss: 3.7580e-01, L2 Relative_error: ['0.0088'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.4850, layer 0 is being updated for the 1-th time
# Epoch 9000, Loss: 3.9696e-01, L2 Relative_error: ['0.0092'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.4900, layer 0 is being updated for the 1-th time
# Epoch 9100, Loss: 2.8911e-01, L2 Relative_error: ['0.0087'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.4962, layer 0 is being updated for the 1-th time
# Epoch 9200, Loss: 2.8236e-01, L2 Relative_error: ['0.0078'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.5024, layer 0 is being updated for the 1-th time
# Epoch 9300, Loss: 3.0269e-01, L2 Relative_error: ['0.0084'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.5082, layer 0 is being updated for the 1-th time
# Epoch 9400, Loss: 2.4642e-01, L2 Relative_error: ['0.0100'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.5134, layer 0 is being updated for the 1-th time
# Epoch 9500, Loss: 2.9316e-01, L2 Relative_error: ['0.0081'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.5184, layer 0 is being updated for the 1-th time
# Epoch 9600, Loss: 2.2263e-01, L2 Relative_error: ['0.0071'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.5234, layer 0 is being updated for the 1-th time
# Epoch 9700, Loss: 3.0629e-01, L2 Relative_error: ['0.0081'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.5287, layer 0 is being updated for the 1-th time
# Epoch 9800, Loss: 1.5493e-01, L2 Relative_error: ['0.0224'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.5338, layer 0 is being updated for the 1-th time
# Epoch 9900, Loss: 2.7942e-01, L2 Relative_error: ['0.0082'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.5383, layer 0 is being updated for the 1-th time
# Epoch 10000, Loss: 2.8787e-01, L2 Relative_error: ['0.0080'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.5434, layer 0 is being updated for the 1-th time
# Epoch 10100, Loss: 2.4843e-01, L2 Relative_error: ['0.0063'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.5484, layer 0 is being updated for the 1-th time
# Epoch 10200, Loss: 2.0943e-01, L2 Relative_error: ['0.0083'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.5531, layer 0 is being updated for the 1-th time
# Epoch 10300, Loss: 1.6453e-01, L2 Relative_error: ['0.0154'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.5575, layer 0 is being updated for the 1-th time
# Epoch 10400, Loss: 2.6993e-01, L2 Relative_error: ['0.0074'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.5621, layer 0 is being updated for the 1-th time
# Epoch 10500, Loss: 2.4403e-01, L2 Relative_error: ['0.0068'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.5670, layer 0 is being updated for the 1-th time
# Epoch 10600, Loss: 2.8330e-01, L2 Relative_error: ['0.0067'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.5717, layer 0 is being updated for the 1-th time
# Epoch 10700, Loss: 3.3070e-01, L2 Relative_error: ['0.0069'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.5768, layer 0 is being updated for the 1-th time
# Epoch 10800, Loss: 1.7454e-01, L2 Relative_error: ['0.0237'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.5814, layer 0 is being updated for the 1-th time
# Epoch 10900, Loss: 2.0660e-01, L2 Relative_error: ['0.0075'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.5862, layer 0 is being updated for the 1-th time
# Epoch 11000, Loss: 1.6061e-01, L2 Relative_error: ['0.0264'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.5905, layer 0 is being updated for the 1-th time
# Epoch 11100, Loss: 2.5320e-01, L2 Relative_error: ['0.0062'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.5950, layer 0 is being updated for the 1-th time
# Epoch 11200, Loss: 3.4009e-01, L2 Relative_error: ['0.0065'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.6002, layer 0 is being updated for the 1-th time
# Epoch 11300, Loss: 2.6550e-01, L2 Relative_error: ['0.0068'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.6052, layer 0 is being updated for the 1-th time
# Epoch 11400, Loss: 3.0763e-01, L2 Relative_error: ['0.0066'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.6102, layer 0 is being updated for the 1-th time
# Epoch 11500, Loss: 2.6861e-01, L2 Relative_error: ['0.0063'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.6153, layer 0 is being updated for the 1-th time
# Epoch 11600, Loss: 2.7772e-01, L2 Relative_error: ['0.0062'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.6203, layer 0 is being updated for the 1-th time
# Epoch 11700, Loss: 2.5455e-01, L2 Relative_error: ['0.0063'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.6250, layer 0 is being updated for the 1-th time
# Epoch 11800, Loss: 2.9074e-01, L2 Relative_error: ['0.0060'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.6303, layer 0 is being updated for the 1-th time
# Epoch 11900, Loss: 2.4910e-01, L2 Relative_error: ['0.0058'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.6351, layer 0 is being updated for the 1-th time
# Epoch 12000, Loss: 3.0336e-01, L2 Relative_error: ['0.0060'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.6396, layer 0 is being updated for the 1-th time
# Epoch 12100, Loss: 2.5614e-01, L2 Relative_error: ['0.0059'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.6441, layer 0 is being updated for the 1-th time
# Epoch 12200, Loss: 2.3934e-01, L2 Relative_error: ['0.0060'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.6488, layer 0 is being updated for the 1-th time
# Epoch 12300, Loss: 2.9714e-01, L2 Relative_error: ['0.0053'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.6537, layer 0 is being updated for the 1-th time
# Epoch 12400, Loss: 2.2992e-01, L2 Relative_error: ['0.0051'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.6589, layer 0 is being updated for the 1-th time
# Epoch 12500, Loss: 2.7715e-01, L2 Relative_error: ['0.0054'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.6640, layer 0 is being updated for the 1-th time
# Epoch 12600, Loss: 2.5795e-01, L2 Relative_error: ['0.0052'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.6691, layer 0 is being updated for the 1-th time
# Epoch 12700, Loss: 2.5064e-01, L2 Relative_error: ['0.0058'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.6743, layer 0 is being updated for the 1-th time
# Epoch 12800, Loss: 2.4150e-01, L2 Relative_error: ['0.0052'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.6792, layer 0 is being updated for the 1-th time
# Epoch 12900, Loss: 1.7015e-01, L2 Relative_error: ['0.0206'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.6837, layer 0 is being updated for the 1-th time
# Epoch 13000, Loss: 2.7766e-01, L2 Relative_error: ['0.0052'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.6884, layer 0 is being updated for the 1-th time
# Epoch 13100, Loss: 2.4021e-01, L2 Relative_error: ['0.0106'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.6929, layer 0 is being updated for the 1-th time
# Epoch 13200, Loss: 2.9119e-01, L2 Relative_error: ['0.0054'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.6977, layer 0 is being updated for the 1-th time
# Epoch 13300, Loss: 2.8747e-01, L2 Relative_error: ['0.0050'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.7034, layer 0 is being updated for the 1-th time
# Epoch 13400, Loss: 2.1239e-01, L2 Relative_error: ['0.0061'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.7091, layer 0 is being updated for the 1-th time
# Epoch 13500, Loss: 2.2063e-01, L2 Relative_error: ['0.0050'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.7143, layer 0 is being updated for the 1-th time
# Epoch 13600, Loss: 1.9592e-01, L2 Relative_error: ['0.0080'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.7196, layer 0 is being updated for the 1-th time
# Epoch 13700, Loss: 2.2882e-01, L2 Relative_error: ['0.0050'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.7244, layer 0 is being updated for the 1-th time
# Epoch 13800, Loss: 2.5989e-01, L2 Relative_error: ['0.0048'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.7295, layer 0 is being updated for the 1-th time
# Epoch 13900, Loss: 1.7445e-01, L2 Relative_error: ['0.0218'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.7343, layer 0 is being updated for the 1-th time
# Epoch 14000, Loss: 2.2955e-01, L2 Relative_error: ['0.0049'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.7388, layer 0 is being updated for the 1-th time
# Epoch 14100, Loss: 2.7395e-01, L2 Relative_error: ['0.0045'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.7436, layer 0 is being updated for the 1-th time
# Epoch 14200, Loss: 2.8034e-01, L2 Relative_error: ['0.0046'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.7488, layer 0 is being updated for the 1-th time
# Epoch 14300, Loss: 2.9404e-01, L2 Relative_error: ['0.0046'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.7540, layer 0 is being updated for the 1-th time
# Epoch 14400, Loss: 2.6827e-01, L2 Relative_error: ['0.0046'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.7595, layer 0 is being updated for the 1-th time
# Epoch 14500, Loss: 2.6973e-01, L2 Relative_error: ['0.0046'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.7648, layer 0 is being updated for the 1-th time
# Epoch 14600, Loss: 3.0237e-01, L2 Relative_error: ['0.0039'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.7703, layer 0 is being updated for the 1-th time
# Epoch 14700, Loss: 2.5963e-01, L2 Relative_error: ['0.0049'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.7758, layer 0 is being updated for the 1-th time
# Epoch 14800, Loss: 2.6212e-01, L2 Relative_error: ['0.0097'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.7813, layer 0 is being updated for the 1-th time
# Epoch 14900, Loss: 2.3038e-01, L2 Relative_error: ['0.0040'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.7863, layer 0 is being updated for the 1-th time
# Epoch 15000, Loss: 1.4737e-01, L2 Relative_error: ['0.0062'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.7912, layer 0 is being updated for the 1-th time
# Epoch 15100, Loss: 2.5275e-01, L2 Relative_error: ['0.0040'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.7958, layer 0 is being updated for the 1-th time
# Epoch 15200, Loss: 2.6849e-01, L2 Relative_error: ['0.0041'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.8005, layer 0 is being updated for the 1-th time
# Epoch 15300, Loss: 2.7466e-01, L2 Relative_error: ['0.0037'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.8056, layer 0 is being updated for the 1-th time
# Epoch 15400, Loss: 1.8267e-01, L2 Relative_error: ['0.0194'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.8107, layer 0 is being updated for the 1-th time
# Epoch 15500, Loss: 2.8047e-01, L2 Relative_error: ['0.0040'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.8157, layer 0 is being updated for the 1-th time
# Epoch 15600, Loss: 2.4849e-01, L2 Relative_error: ['0.0036'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.8206, layer 0 is being updated for the 1-th time
# Epoch 15700, Loss: 2.2038e-01, L2 Relative_error: ['0.0036'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.8256, layer 0 is being updated for the 1-th time
# Epoch 15800, Loss: 2.1403e-01, L2 Relative_error: ['0.0038'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.8301, layer 0 is being updated for the 1-th time
# Epoch 15900, Loss: 1.0601e-01, L2 Relative_error: ['0.0064'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.8342, layer 0 is being updated for the 1-th time
# Epoch 16000, Loss: 1.4449e-01, L2 Relative_error: ['0.0037'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.8381, layer 0 is being updated for the 1-th time
# Epoch 16100, Loss: 2.5017e-01, L2 Relative_error: ['0.0035'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.8424, layer 0 is being updated for the 1-th time
# Epoch 16200, Loss: 2.4411e-01, L2 Relative_error: ['0.0035'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.8473, layer 0 is being updated for the 1-th time
# Epoch 16300, Loss: 2.2263e-01, L2 Relative_error: ['0.0035'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.8522, layer 0 is being updated for the 1-th time
# Epoch 16400, Loss: 2.4338e-01, L2 Relative_error: ['0.0037'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.8568, layer 0 is being updated for the 1-th time
# Epoch 16500, Loss: 1.8783e-01, L2 Relative_error: ['0.0250'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.8618, layer 0 is being updated for the 1-th time
# Epoch 16600, Loss: 2.0370e-01, L2 Relative_error: ['0.0082'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.8664, layer 0 is being updated for the 1-th time
# Epoch 16700, Loss: 2.6045e-01, L2 Relative_error: ['0.0035'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.8708, layer 0 is being updated for the 1-th time
# Epoch 16800, Loss: 2.6432e-01, L2 Relative_error: ['0.0035'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.8757, layer 0 is being updated for the 1-th time
# Epoch 16900, Loss: 2.9046e-01, L2 Relative_error: ['0.0034'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.8806, layer 0 is being updated for the 1-th time
# Epoch 17000, Loss: 1.8984e-01, L2 Relative_error: ['0.0033'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.8856, layer 0 is being updated for the 1-th time
# Epoch 17100, Loss: 1.9238e-01, L2 Relative_error: ['0.0055'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.8903, layer 0 is being updated for the 1-th time
# Epoch 17200, Loss: 2.5846e-01, L2 Relative_error: ['0.0034'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.8954, layer 0 is being updated for the 1-th time
# Epoch 17300, Loss: 1.9136e-01, L2 Relative_error: ['0.0190'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.9006, layer 0 is being updated for the 1-th time
# Epoch 17400, Loss: 2.6475e-01, L2 Relative_error: ['0.0037'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.9054, layer 0 is being updated for the 1-th time
# Epoch 17500, Loss: 2.0435e-01, L2 Relative_error: ['0.0033'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.9105, layer 0 is being updated for the 1-th time
# Epoch 17600, Loss: 2.0447e-01, L2 Relative_error: ['0.0051'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.9155, layer 0 is being updated for the 1-th time
# Epoch 17700, Loss: 1.4577e-01, L2 Relative_error: ['0.0055'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.9200, layer 0 is being updated for the 1-th time
# Epoch 17800, Loss: 1.8589e-01, L2 Relative_error: ['0.0030'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.9245, layer 0 is being updated for the 1-th time
# Epoch 17900, Loss: 1.9582e-01, L2 Relative_error: ['0.0031'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.9294, layer 0 is being updated for the 1-th time
# Epoch 18000, Loss: 1.7305e-01, L2 Relative_error: ['0.0044'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.9340, layer 0 is being updated for the 1-th time
# Epoch 18100, Loss: 2.4146e-01, L2 Relative_error: ['0.0031'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.9381, layer 0 is being updated for the 1-th time
# Epoch 18200, Loss: 8.5394e-02, L2 Relative_error: ['0.0043'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.9418, layer 0 is being updated for the 1-th time
# Epoch 18300, Loss: 2.0583e-01, L2 Relative_error: ['0.0031'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.9457, layer 0 is being updated for the 1-th time
# Epoch 18400, Loss: 1.8715e-01, L2 Relative_error: ['0.0030'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.9504, layer 0 is being updated for the 1-th time
# Epoch 18500, Loss: 8.9605e-02, L2 Relative_error: ['0.0048'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.9549, layer 0 is being updated for the 1-th time
# Epoch 18600, Loss: 1.1489e-01, L2 Relative_error: ['0.0042'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.9587, layer 0 is being updated for the 1-th time
# Epoch 18700, Loss: 2.6519e-01, L2 Relative_error: ['0.0029'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.9631, layer 0 is being updated for the 1-th time
# Epoch 18800, Loss: 1.3528e-01, L2 Relative_error: ['0.0035'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.9674, layer 0 is being updated for the 1-th time
# Epoch 18900, Loss: 1.9934e-01, L2 Relative_error: ['0.0266'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.9710, layer 0 is being updated for the 1-th time
# Epoch 19000, Loss: 1.9822e-01, L2 Relative_error: ['0.0027'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.9751, layer 0 is being updated for the 1-th time
# Epoch 19100, Loss: 1.4930e-01, L2 Relative_error: ['0.0038'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.9792, layer 0 is being updated for the 1-th time
# Epoch 19200, Loss: 1.3202e-01, L2 Relative_error: ['0.0063'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.9830, layer 0 is being updated for the 1-th time
# Epoch 19300, Loss: 2.5484e-01, L2 Relative_error: ['0.0027'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.9870, layer 0 is being updated for the 1-th time
# Epoch 19400, Loss: 2.4232e-01, L2 Relative_error: ['0.0026'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.9919, layer 0 is being updated for the 1-th time
# Epoch 19500, Loss: 2.0136e-01, L2 Relative_error: ['0.0209'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 1.9968, layer 0 is being updated for the 1-th time
# Epoch 19600, Loss: 1.1915e-01, L2 Relative_error: ['0.0038'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 2.0015, layer 0 is being updated for the 1-th time
# Epoch 19700, Loss: 1.8073e-01, L2 Relative_error: ['0.0026'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 2.0061, layer 0 is being updated for the 1-th time
# Epoch 19800, Loss: 1.5405e-01, L2 Relative_error: ['0.0044'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 2.0110, layer 0 is being updated for the 1-th time
# Epoch 19900, Loss: 2.4612e-01, L2 Relative_error: ['0.0025'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 2.0159, layer 0 is being updated for the 1-th time
# Epoch 20000, Loss: 2.4272e-01, L2 Relative_error: ['0.0027'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 2.0214, layer 0 is being updated for the 1-th time
# Epoch 20100, Loss: 2.7741e-01, L2 Relative_error: ['0.0026'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 2.0271, layer 0 is being updated for the 1-th time
# Epoch 20200, Loss: 2.4448e-01, L2 Relative_error: ['0.0025'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 2.0325, layer 0 is being updated for the 1-th time
# Epoch 20300, Loss: 1.9750e-01, L2 Relative_error: ['0.0025'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 2.0371, layer 0 is being updated for the 1-th time
# Epoch 20400, Loss: 1.6757e-01, L2 Relative_error: ['0.0041'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 2.0417, layer 0 is being updated for the 1-th time
# Epoch 20500, Loss: 2.1391e-01, L2 Relative_error: ['0.0034'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 2.0464, layer 0 is being updated for the 1-th time
# Epoch 20600, Loss: 1.7723e-01, L2 Relative_error: ['0.0035'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 2.0509, layer 0 is being updated for the 1-th time
# Epoch 20700, Loss: 2.6360e-01, L2 Relative_error: ['0.0024'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 2.0554, layer 0 is being updated for the 1-th time
# Epoch 20800, Loss: 2.1951e-01, L2 Relative_error: ['0.0024'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 2.0603, layer 0 is being updated for the 1-th time
# Epoch 20900, Loss: 1.6579e-01, L2 Relative_error: ['0.0023'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 2.0649, layer 0 is being updated for the 1-th time
# Epoch 21000, Loss: 2.2813e-01, L2 Relative_error: ['0.0024'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 2.0691, layer 0 is being updated for the 1-th time
# Epoch 21100, Loss: 1.9123e-01, L2 Relative_error: ['0.0039'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 2.0734, layer 0 is being updated for the 1-th time
# Epoch 21200, Loss: 1.9349e-01, L2 Relative_error: ['0.0041'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 2.0775, layer 0 is being updated for the 1-th time
# Epoch 21300, Loss: 1.9972e-01, L2 Relative_error: ['0.0125'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 2.0820, layer 0 is being updated for the 1-th time
# Epoch 21400, Loss: 8.7930e-02, L2 Relative_error: ['0.0027'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 2.0863, layer 0 is being updated for the 1-th time
# Epoch 21500, Loss: 1.0980e-01, L2 Relative_error: ['0.0040'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 2.0899, layer 0 is being updated for the 1-th time
# Epoch 21600, Loss: 1.7525e-01, L2 Relative_error: ['0.0023'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 2.0937, layer 0 is being updated for the 1-th time
# Epoch 21700, Loss: 2.3209e-01, L2 Relative_error: ['0.0023'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 2.0983, layer 0 is being updated for the 1-th time
# Epoch 21800, Loss: 9.0586e-02, L2 Relative_error: ['0.0055'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 2.1027, layer 0 is being updated for the 1-th time
# Epoch 21900, Loss: 1.4435e-01, L2 Relative_error: ['0.0030'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 2.1059, layer 0 is being updated for the 1-th time
# Epoch 22000, Loss: 1.1804e-01, L2 Relative_error: ['0.0018'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 2.1087, layer 0 is being updated for the 1-th time
# Epoch 22100, Loss: 1.1379e-01, L2 Relative_error: ['0.0023'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 2.1122, layer 0 is being updated for the 1-th time
# Epoch 22200, Loss: 7.7261e-02, L2 Relative_error: ['0.0042'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 2.1160, layer 0 is being updated for the 1-th time
# Epoch 22300, Loss: 5.7340e-02, L2 Relative_error: ['0.0041'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 2.1187, layer 0 is being updated for the 1-th time
# Epoch 22400, Loss: 2.1392e-01, L2 Relative_error: ['0.0023'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 2.1214, layer 0 is being updated for the 1-th time
# Epoch 22500, Loss: 1.5986e-01, L2 Relative_error: ['0.0023'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 2.1256, layer 0 is being updated for the 1-th time
# Epoch 22600, Loss: 9.7053e-02, L2 Relative_error: ['0.0021'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 2.1295, layer 0 is being updated for the 1-th time
# Epoch 22700, Loss: 2.4430e-01, L2 Relative_error: ['0.0022'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 2.1334, layer 0 is being updated for the 1-th time
# Epoch 22800, Loss: 8.7126e-02, L2 Relative_error: ['0.0056'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 2.1374, layer 0 is being updated for the 1-th time
# Epoch 22900, Loss: 1.5706e-01, L2 Relative_error: ['0.0021'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 2.1405, layer 0 is being updated for the 1-th time
# Epoch 23000, Loss: 2.0575e-01, L2 Relative_error: ['0.0019'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 2.1445, layer 0 is being updated for the 1-th time
# Epoch 23100, Loss: 2.5398e-01, L2 Relative_error: ['0.0021'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 2.1487, layer 0 is being updated for the 1-th time
# Epoch 23200, Loss: 1.1812e-01, L2 Relative_error: ['0.0039'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 2.1537, layer 0 is being updated for the 1-th time
# Epoch 23300, Loss: 2.1275e-01, L2 Relative_error: ['0.0022'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 2.1586, layer 0 is being updated for the 1-th time
# Epoch 23400, Loss: 2.1601e-01, L2 Relative_error: ['0.0068'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 2.1631, layer 0 is being updated for the 1-th time
# Epoch 23500, Loss: 1.7439e-01, L2 Relative_error: ['0.0017'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 2.1677, layer 0 is being updated for the 1-th time
# Epoch 23600, Loss: 2.5394e-01, L2 Relative_error: ['0.0020'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 2.1728, layer 0 is being updated for the 1-th time
# Epoch 23700, Loss: 9.0909e-02, L2 Relative_error: ['0.0049'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 2.1773, layer 0 is being updated for the 1-th time
# Epoch 23800, Loss: 2.1017e-01, L2 Relative_error: ['0.0018'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 2.1807, layer 0 is being updated for the 1-th time
# Epoch 23900, Loss: 1.0619e-01, L2 Relative_error: ['0.0043'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 2.1847, layer 0 is being updated for the 1-th time
# Epoch 24000, Loss: 1.0288e-01, L2 Relative_error: ['0.0028'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 2.1879, layer 0 is being updated for the 1-th time
# Epoch 24100, Loss: 7.7440e-02, L2 Relative_error: ['0.0038'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 2.1910, layer 0 is being updated for the 1-th time
# Epoch 24200, Loss: 7.3846e-02, L2 Relative_error: ['0.0020'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 2.1935, layer 0 is being updated for the 1-th time
# Epoch 24300, Loss: 6.8140e-02, L2 Relative_error: ['0.0037'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 2.1963, layer 0 is being updated for the 1-th time
# Epoch 24400, Loss: 1.7393e-01, L2 Relative_error: ['0.0020'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 2.2002, layer 0 is being updated for the 1-th time
# Epoch 24500, Loss: 1.0302e-01, L2 Relative_error: ['0.0017'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 2.2043, layer 0 is being updated for the 1-th time
# Epoch 24600, Loss: 1.3908e-01, L2 Relative_error: ['0.0032'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 2.2079, layer 0 is being updated for the 1-th time
# Epoch 24700, Loss: 2.2428e-01, L2 Relative_error: ['0.0302'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 2.2117, layer 0 is being updated for the 1-th time
# Epoch 24800, Loss: 1.1018e-01, L2 Relative_error: ['0.0032'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 2.2161, layer 0 is being updated for the 1-th time
# Epoch 24900, Loss: 1.3825e-01, L2 Relative_error: ['0.0037'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 2.2195, layer 0 is being updated for the 1-th time
# Epoch 25000, Loss: 9.1318e-02, L2 Relative_error: ['0.0033'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 2.2234, layer 0 is being updated for the 1-th time
# Epoch 25100, Loss: 8.5285e-02, L2 Relative_error: ['0.0043'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 2.2269, layer 0 is being updated for the 1-th time
# Epoch 25200, Loss: 1.1154e-01, L2 Relative_error: ['0.0038'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 2.2299, layer 0 is being updated for the 1-th time
# Epoch 25300, Loss: 1.4459e-01, L2 Relative_error: ['0.0018'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 2.2327, layer 0 is being updated for the 1-th time
# Epoch 25400, Loss: 1.4462e-01, L2 Relative_error: ['0.0017'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 2.2354, layer 0 is being updated for the 1-th time
# Epoch 25500, Loss: 8.5201e-02, L2 Relative_error: ['0.0043'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 2.2387, layer 0 is being updated for the 1-th time
# Epoch 25600, Loss: 1.2322e-01, L2 Relative_error: ['0.0017'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 2.2416, layer 0 is being updated for the 1-th time
# Epoch 25700, Loss: 1.2499e-01, L2 Relative_error: ['0.0018'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 2.2450, layer 0 is being updated for the 1-th time
# Epoch 25800, Loss: 1.8312e-01, L2 Relative_error: ['0.0015'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 2.2496, layer 0 is being updated for the 1-th time
# Epoch 25900, Loss: 2.3126e-01, L2 Relative_error: ['0.0015'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 2.2545, layer 0 is being updated for the 1-th time
# Epoch 26000, Loss: 9.5626e-02, L2 Relative_error: ['0.0058'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 2.2590, layer 0 is being updated for the 1-th time
# Epoch 26100, Loss: 1.0950e-01, L2 Relative_error: ['0.0044'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 2.2633, layer 0 is being updated for the 1-th time
# Epoch 26200, Loss: 1.0570e-01, L2 Relative_error: ['0.0043'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 2.2671, layer 0 is being updated for the 1-th time
# Epoch 26300, Loss: 2.4369e-01, L2 Relative_error: ['0.0016'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 2.2713, layer 0 is being updated for the 1-th time
# Epoch 26400, Loss: 1.8218e-01, L2 Relative_error: ['0.0015'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 2.2764, layer 0 is being updated for the 1-th time
# Epoch 26500, Loss: 1.3231e-01, L2 Relative_error: ['0.0054'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 2.2816, layer 0 is being updated for the 1-th time
# Epoch 26600, Loss: 2.3444e-01, L2 Relative_error: ['0.0419'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 2.2869, layer 0 is being updated for the 1-th time
# Epoch 26700, Loss: 1.0792e-01, L2 Relative_error: ['0.0026'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 2.2923, layer 0 is being updated for the 1-th time
# Epoch 26800, Loss: 9.9157e-02, L2 Relative_error: ['0.0043'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 2.2970, layer 0 is being updated for the 1-th time
# Epoch 26900, Loss: 1.4816e-01, L2 Relative_error: ['0.0014'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 2.3015, layer 0 is being updated for the 1-th time
# Epoch 27000, Loss: 1.4555e-01, L2 Relative_error: ['0.0014'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 2.3053, layer 0 is being updated for the 1-th time
# Epoch 27100, Loss: 1.6925e-01, L2 Relative_error: ['0.0015'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 2.3094, layer 0 is being updated for the 1-th time
# Epoch 27200, Loss: 1.0845e-01, L2 Relative_error: ['0.0041'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 2.3137, layer 0 is being updated for the 1-th time
# Epoch 27300, Loss: 1.9347e-01, L2 Relative_error: ['0.0014'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 2.3177, layer 0 is being updated for the 1-th time
# Epoch 27400, Loss: 1.4463e-01, L2 Relative_error: ['0.0015'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 2.3217, layer 0 is being updated for the 1-th time
# Epoch 27500, Loss: 2.1011e-01, L2 Relative_error: ['0.0014'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 2.3261, layer 0 is being updated for the 1-th time
# Epoch 27600, Loss: 1.3532e-01, L2 Relative_error: ['0.0014'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 2.3298, layer 0 is being updated for the 1-th time
# Epoch 27700, Loss: 1.5025e-01, L2 Relative_error: ['0.0016'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 2.3338, layer 0 is being updated for the 1-th time
# Epoch 27800, Loss: 7.5947e-02, L2 Relative_error: ['0.0048'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 2.3374, layer 0 is being updated for the 1-th time
# Epoch 27900, Loss: 9.0697e-02, L2 Relative_error: ['0.0032'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 2.3404, layer 0 is being updated for the 1-th time
# ...
# Epoch 114500, Loss: 8.3581e-02, L2 Relative_error: ['0.0021'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 7.3378, layer 0 is being updated for the 1-th time
# Epoch 114600, Loss: 6.0544e-02, L2 Relative_error: ['0.0021'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 7.3458, layer 0 is being updated for the 1-th time
# Epoch 114700, Loss: 5.8692e-02, L2 Relative_error: ['0.0021'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 7.3537, layer 0 is being updated for the 1-th time
# Epoch 114800, Loss: 5.8713e-02, L2 Relative_error: ['0.0019'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 7.3615, layer 0 is being updated for the 1-th time
# Epoch 114900, Loss: 7.3043e-02, L2 Relative_error: ['0.0018'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 7.3690, layer 0 is being updated for the 1-th time
# Epoch 115000, Loss: 7.6629e-02, L2 Relative_error: ['0.0024'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 7.3776, layer 0 is being updated for the 1-th time
# Epoch 115100, Loss: 6.2603e-02, L2 Relative_error: ['0.0018'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 7.3863, layer 0 is being updated for the 1-th time
# Epoch 115200, Loss: 6.7317e-02, L2 Relative_error: ['0.0022'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 7.3949, layer 0 is being updated for the 1-th time
# Epoch 115300, Loss: 6.9251e-02, L2 Relative_error: ['0.0023'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 7.4047, layer 0 is being updated for the 1-th time
# Epoch 115400, Loss: 6.1235e-02, L2 Relative_error: ['0.0018'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 7.4134, layer 0 is being updated for the 1-th time
# Epoch 115500, Loss: 6.0501e-02, L2 Relative_error: ['0.0022'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 7.4218, layer 0 is being updated for the 1-th time
# Epoch 115600, Loss: 5.1232e-02, L2 Relative_error: ['0.0019'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 7.4307, layer 0 is being updated for the 1-th time
# Epoch 115700, Loss: 6.7553e-02, L2 Relative_error: ['0.0020'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 7.4392, layer 0 is being updated for the 1-th time
# Epoch 115800, Loss: 4.9110e-02, L2 Relative_error: ['0.0013'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 7.4477, layer 0 is being updated for the 1-th time
# Epoch 115900, Loss: 5.7394e-02, L2 Relative_error: ['0.0017'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 7.4557, layer 0 is being updated for the 1-th time
# Epoch 116000, Loss: 6.0447e-02, L2 Relative_error: ['0.0016'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 7.4635, layer 0 is being updated for the 1-th time
# Epoch 116100, Loss: 6.2671e-02, L2 Relative_error: ['0.0022'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 7.4719, layer 0 is being updated for the 1-th time
# Epoch 116200, Loss: 6.7932e-02, L2 Relative_error: ['0.0019'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 7.4810, layer 0 is being updated for the 1-th time
# Epoch 116300, Loss: 5.5773e-02, L2 Relative_error: ['0.0020'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 7.4898, layer 0 is being updated for the 1-th time
# Epoch 116400, Loss: 7.1802e-02, L2 Relative_error: ['0.0018'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 7.4984, layer 0 is being updated for the 1-th time
# Epoch 116500, Loss: 5.0482e-02, L2 Relative_error: ['0.0018'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 7.5075, layer 0 is being updated for the 1-th time
# Epoch 116600, Loss: 6.6316e-02, L2 Relative_error: ['0.0018'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 7.5165, layer 0 is being updated for the 1-th time
# Epoch 116700, Loss: 5.2687e-02, L2 Relative_error: ['0.0019'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 7.5253, layer 0 is being updated for the 1-th time
# Epoch 116800, Loss: 6.1738e-02, L2 Relative_error: ['0.0018'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 7.5331, layer 0 is being updated for the 1-th time
# Epoch 116900, Loss: 6.0750e-02, L2 Relative_error: ['0.0021'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 7.5409, layer 0 is being updated for the 1-th time
# Epoch 117000, Loss: 6.2032e-02, L2 Relative_error: ['0.0021'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 7.5487, layer 0 is being updated for the 1-th time
# Epoch 117100, Loss: 7.9729e-02, L2 Relative_error: ['0.0020'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 7.5562, layer 0 is being updated for the 1-th time
# Epoch 117200, Loss: 8.2718e-02, L2 Relative_error: ['0.0025'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 7.5660, layer 0 is being updated for the 1-th time
# Epoch 117300, Loss: 5.5271e-02, L2 Relative_error: ['0.0020'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 7.5760, layer 0 is being updated for the 1-th time
# Epoch 117400, Loss: 3.7395e-02, L2 Relative_error: ['0.0016'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 7.5844, layer 0 is being updated for the 1-th time
# Epoch 117500, Loss: 6.0248e-02, L2 Relative_error: ['0.0020'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 7.5924, layer 0 is being updated for the 1-th time
# Epoch 117600, Loss: 7.6320e-02, L2 Relative_error: ['0.0021'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 7.6001, layer 0 is being updated for the 1-th time
# Epoch 117700, Loss: 5.9498e-02, L2 Relative_error: ['0.0021'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 7.6075, layer 0 is being updated for the 1-th time
# Epoch 117800, Loss: 6.2204e-02, L2 Relative_error: ['0.0021'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 7.6143, layer 0 is being updated for the 1-th time
# Epoch 117900, Loss: 6.6957e-02, L2 Relative_error: ['0.0016'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 7.6222, layer 0 is being updated for the 1-th time
# Epoch 118000, Loss: 5.0749e-02, L2 Relative_error: ['0.0018'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 7.6298, layer 0 is being updated for the 1-th time
# Epoch 118100, Loss: 6.9174e-02, L2 Relative_error: ['0.0020'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 7.6376, layer 0 is being updated for the 1-th time
# Epoch 118200, Loss: 5.0708e-02, L2 Relative_error: ['0.0019'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 7.6452, layer 0 is being updated for the 1-th time
# Epoch 118300, Loss: 5.4317e-02, L2 Relative_error: ['0.0020'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 7.6532, layer 0 is being updated for the 1-th time
# Epoch 118400, Loss: 8.3612e-02, L2 Relative_error: ['0.0025'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 7.6618, layer 0 is being updated for the 1-th time
# Epoch 118500, Loss: 6.1260e-02, L2 Relative_error: ['0.0021'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 7.6723, layer 0 is being updated for the 1-th time
# Epoch 118600, Loss: 5.2245e-02, L2 Relative_error: ['0.0019'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 7.6813, layer 0 is being updated for the 1-th time
# Epoch 118700, Loss: 5.1045e-02, L2 Relative_error: ['0.0019'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 7.6889, layer 0 is being updated for the 1-th time
# Epoch 118800, Loss: 6.9087e-02, L2 Relative_error: ['0.0022'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 7.6963, layer 0 is being updated for the 1-th time
# Epoch 118900, Loss: 6.4416e-02, L2 Relative_error: ['0.0021'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 7.7038, layer 0 is being updated for the 1-th time
# Epoch 119000, Loss: 3.7106e-02, L2 Relative_error: ['0.0017'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 7.7112, layer 0 is being updated for the 1-th time
# Epoch 119100, Loss: 5.5515e-02, L2 Relative_error: ['0.0020'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 7.7187, layer 0 is being updated for the 1-th time
# Epoch 119200, Loss: 6.1627e-02, L2 Relative_error: ['0.0018'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 7.7268, layer 0 is being updated for the 1-th time
# Epoch 119300, Loss: 4.9720e-02, L2 Relative_error: ['0.0019'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 7.7348, layer 0 is being updated for the 1-th time
# Epoch 119400, Loss: 7.4527e-02, L2 Relative_error: ['0.0018'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 7.7425, layer 0 is being updated for the 1-th time
# Epoch 119500, Loss: 6.7240e-02, L2 Relative_error: ['0.0020'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 7.7504, layer 0 is being updated for the 1-th time
# Epoch 119600, Loss: 6.9275e-02, L2 Relative_error: ['0.0021'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 7.7589, layer 0 is being updated for the 1-th time
# Epoch 119700, Loss: 5.2379e-02, L2 Relative_error: ['0.0018'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 7.7678, layer 0 is being updated for the 1-th time
# Epoch 119800, Loss: 6.1944e-02, L2 Relative_error: ['0.0019'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 7.7763, layer 0 is being updated for the 1-th time
# Epoch 119900, Loss: 5.4352e-02, L2 Relative_error: ['0.0020'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 7.7841, layer 0 is being updated for the 1-th time
# Epoch 120000, Loss: 6.1935e-02, L2 Relative_error: ['0.0021'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 7.7911, layer 0 is being updated for the 1-th time
# Epoch 120100, Loss: 7.4813e-02, L2 Relative_error: ['0.0020'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 7.7988, layer 0 is being updated for the 1-th time
# Epoch 120200, Loss: 6.9470e-02, L2 Relative_error: ['0.0020'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 7.8075, layer 0 is being updated for the 1-th time
# Epoch 120300, Loss: 4.8748e-02, L2 Relative_error: ['0.0019'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 7.8167, layer 0 is being updated for the 1-th time
# Epoch 120400, Loss: 5.3548e-02, L2 Relative_error: ['0.0019'], self.gammas: ['1.0000'], epsilon : 1.0e-02, lambda_phys : 7.8248, layer 0 is being updated for the 1-th time
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 46
#      43 pinn = StackedResPINN(model, optimizer_primal, optimizer_dual, gammas_init=gammas_init, T_max=T_max, parameters_init=parameters_init)
#      45 # Train the model with test data for loss visualization
# ---> 46 pinn.train(t_collocation, n_stacked_mf_layers, epochs=300000, t_test=t_test, u_test=u_tests, u_0=u_0)
#
# Cell In[3], line 387, in StackedResPINN.train(self, t_collocation, n_stacked_mf_layers, epochs, t_test, u_test, u_0)
#     383 train_losses, test_losses, l2_errors, gammas, sigma, layer_updated, omegas_t, lambda_phys = ([] for _ in range(8))
#     385 for epoch in range(epochs):
# --> 387     loss = self.primal_update(t_collocation)
#     388     if epoch % self.N_dual == 0 and epoch > 0: #dual update
#     389         loss = self.dual_update(t_collocation)
#
# Cell In[3], line 344, in StackedResPINN.primal_update(self, t_collocation)
#     342 def primal_update(self, t_collocation):
#     343     target_variables = self.get_target_variables(self.K)
# --> 344     loss = self.primal_update_k(t_collocation, target_variables, self.K)
#     345     return loss
#
# File /opt/anaconda3/envs/pinn-clean2/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /opt/anaconda3/envs/pinn-clean2/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:894, in Function.__call__(self, *args, **kwds)
#     891 compiler = "xla" if self._jit_compile else "nonXla"
#     893 with OptionalXlaContext(self._jit_compile):
# --> 894   result = self._call(*args, **kwds)
#     896 new_tracing_count = self.experimental_get_tracing_count()
#     897 without_tracing = (tracing_count == new_tracing_count)
#
# File /opt/anaconda3/envs/pinn-clean2/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:933, in Function._call(self, *args, **kwds)
#     930 self._lock.release()
#     931 # In this case we have not created variables on the first call. So we can
#     932 # run the first trace but we should fail if variables are created.
# --> 933 results = self._variable_creation_fn(*args, **kwds)
#     934 if self._created_variables and not ALLOW_DYNAMIC_VARIABLE_CREATION:
#     935   raise ValueError("Creating variables on a non-first call to a function"
#     936                    " decorated with tf.function.")
#
# File /opt/anaconda3/envs/pinn-clean2/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py:143, in TracingCompiler.__call__(self, *args, **kwargs)
#     140 with self._lock:
#     141   (concrete_function,
#     142    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 143 return concrete_function._call_flat(
#     144     filtered_flat_args, captured_inputs=concrete_function.captured_inputs)
#
# File /opt/anaconda3/envs/pinn-clean2/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py:1757, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1753 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1754 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1755     and executing_eagerly):
#    1756   # No tape is watching; skip to running the function.
# -> 1757   return self._build_call_outputs(self._inference_function.call(
#    1758       ctx, args, cancellation_manager=cancellation_manager))
#    1759 forward_backward = self._select_forward_and_backward_functions(
#    1760     args,
#    1761     possible_gradient_type,
#    1762     executing_eagerly)
#    1763 forward_function, args_with_tangents = forward_backward.forward()
#
# File /opt/anaconda3/envs/pinn-clean2/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py:381, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     379 with _InterpolateFunctionError(self):
#     380   if cancellation_manager is None:
# --> 381     outputs = execute.execute(
#     382         str(self.signature.name),
#     383         num_outputs=self._num_outputs,
#     384         inputs=args,
#     385         attrs=attrs,
#     386         ctx=ctx)
#     387   else:
#     388     outputs = execute.execute_with_cancellation(
#     389         str(self.signature.name),
#     390         num_outputs=self._num_outputs,
#    (...)
#     393         ctx=ctx,
#     394         cancellation_manager=cancellation_manager)
#
# File /opt/anaconda3/envs/pinn-clean2/lib/python3.9/site-packages/tensorflow/python/eager/execute.py:48, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      27 def quick_execute(op_name, num_outputs, inputs, attrs, ctx, name=None):
#      28   """Execute a TensorFlow operation.
#      29
#      30   Args:
#    (...)
#      46     An exception on error.
#      47   """
# ---> 48   device_name = ctx.device_name
#      49   # pylint: disable=protected-access
#      50   try:
#
# File /opt/anaconda3/envs/pinn-clean2/lib/python3.9/site-packages/tensorflow/python/eager/context.py:1001, in Context.device_name(self)
#     998 @property
#     999 def device_name(self):
#    1000   """Returns the device name for the current thread."""
# -> 1001   return self._thread_local_data.device_name
#
# KeyboardInterrupt:

# %%
for idx,alpha_val in enumerate(model.alpha):
    print(f"alpha_{idx} = {alpha_val}")

# %%
u_pred_test, _, _ = model(t_test)
u_true_test = u_tests[-1]

absolute_error = tf.abs(u_pred_test - u_true_test).numpy().flatten()  # 1D

plt.figure(figsize=(8, 6))
plt.hist(absolute_error, bins=30, alpha=0.75, label="x1", edgecolor='black')
plt.xlabel("Absolute Error")
plt.ylabel("Frequency")
plt.title("Distribution of Absolute Errors")
plt.legend()
plt.grid(True)
plt.savefig("Distribution of Absolute Errors.eps", format='eps')
plt.show()

# %%
plt.figure(figsize=(6, 4))
plt.boxplot(absolute_error, vert=True, labels=["x1"])  # labels au singulier
plt.ylabel('Absolute Error')
plt.title('Error Boxplot')
plt.grid(True)
plt.savefig("Absolute Error.eps", format='eps')
plt.show()

# %%
"""
Plot the comparison of the output of each stack with the solution it tries to approximate
"""
# get the analytical solution each stack tries to approximate
n_steps = int(5e3)
u_tests = []
for i in range(n_stacked_mf_layers+1):
    u_test, t_test = analytical_solution(n_steps, T_max=T_max, parameters_init=pinn.gammas[i]*parameters_init, u_0=u_0)
    u_tests.append(u_test)
t_test = tf.reshape(t_test, (-1, 1))

u_approx = []
r_approx = []
u_old_approx = []
u_true = []
t_test_np =tf.reshape(t_test, [-1]).numpy()
sorted_indices = np.argsort(t_test_np)
t_sorted = t_test_np[sorted_indices]

# get the output of each stack and plot it
for i in range(n_stacked_mf_layers+1):
    u_i, u_old, r_i  = model(t_test, i=i)
    
    u_i_np = u_i.numpy()
    u_i_sorted = u_i_np[sorted_indices]
    u_approx.append(u_i_sorted)
    
    r_i_np = r_i.numpy()
    r_i_sorted = r_i_np[sorted_indices]
    r_approx.append(r_i_sorted)

    u_old_np = u_old.numpy()
    u_old_sorted = u_old_np[sorted_indices]
    u_old_approx.append(u_old_sorted)

    u_true_i_np = u_tests[i].numpy()
    u_true_i_sorted = u_true_i_np[sorted_indices]
    u_true.append(u_true_i_sorted)

    plt.figure(figsize=(10, 10))

    plt.subplot(3, 1, 1)
    plt.plot(t_sorted, u_i_sorted, label=f'x_hat1_{i}')
    plt.plot(t_sorted, u_true_i_sorted, linestyle='--', linewidth=1, label=f'x1_{i}')
    plt.plot(t_sorted, r_i_sorted, linewidth=1, label=f'r_hat1_{i}', color='#A0A0A0')
    plt.plot(t_sorted, u_old_sorted, linewidth=1.5, label=f'x_old_hat1_{i}', color='#AAAAAA')
    plt.xlabel("Time")
    plt.ylabel("State")
    plt.title(f"u_approx_{i} vs u_test_{i}")
    plt.legend()
    plt.grid(True)
    plt.savefig(f"u_approx_{i} vs u_test_{i}.eps", format='eps')
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 n_steps = int(5e3)
#       2 u_tests = []
# ----> 3 for i in range(n_stacked_mf_layers+1):
#       4     u_test, t_test = analytical_solution(n_steps, T_max=T_max, parameters_init=pinn.alphas[i]*parameters_init, u_0=u_0)
#       5     u_tests.append(u_test)
#
# NameError: name 'n_stacked_mf_layers' is not defined
