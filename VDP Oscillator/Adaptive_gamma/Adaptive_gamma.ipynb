# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
class MLP(tf.Module):
    """
    Multi-Layer Perceptron (MLP) class with regularization handling.

    --------------
    insize: input size (int)
    outsize: output size (int)
    hsize: A list specifying the number of neurons in each hidden layer (list of ints).
    bias: Boolean indicating whether to include a bias term in the linear layers (default: True)
    nonlin: The activation function to be used in the hidden layers (default: nn.Tanh).
    linear_map:  The type of linear transformation to be used (default: nn.Linear)
    """
    def __init__(self, insize, outsize, hsizes, bias=True, nonlin=tf.tanh, linear_map=tf.keras.layers.Dense):
        super().__init__()
        self.in_features, self.out_features = insize, outsize
        self.nhidden = len(hsizes)
        self.layers = []
        self.nonlin = []
        self.seed = 123
        # Create linear layers and activation functions
        layer_sizes = [insize] + hsizes + [outsize]
        for k in range(len(layer_sizes) - 1):
            initializer = tf.keras.initializers.GlorotUniform(self.seed+k)
            self.layers.append(linear_map(units=layer_sizes[k+1], use_bias=bias, kernel_initializer=initializer))
            if k < self.nhidden:
                self.nonlin.append(nonlin)
            else:
                self.nonlin.append(tf.identity)

    def __call__(self, x):
        for i in range(len(self.layers)):
            x = self.nonlin[i](self.layers[i](x))
        return x

    def reg_error(self):
        """
        Compute the regularization error for the linear layers that support it.
        """
        reg_loss = 0.0
        for layer in self.layers:
            if hasattr(layer, "reg_error"):
                reg_loss += layer.reg_error()
        return reg_loss

# %%
class ResNetBlock(tf.Module):
    """
    A single ResNet block that takes the current output (from the previous layer or from the single-fidelity model)
    and the original input x, and learns a residual mapping.

    The block computes:
    out_new = out_old + alpha * F(x)

    F is implemented by an MLP.
    """
    def __init__(self, in_dim_x, in_dim_out, hres_sizes=[20, 20], bias=True, nonlin=tf.tanh):
        """
        in_dim_x : int, dimension of input x
        in_dim_out : int, dimension of the output (u)
        hres_sizes : list of ints, hidden layer sizes for the residual MLP
        bias : bool, whether to include bias in MLP layers
        nonlin : activation function class (e.g., nn.Tanh)
        """
        super().__init__()
        self.res_mlp = MLP(in_dim_x, in_dim_out, hsizes=hres_sizes, bias=bias, nonlin=nonlin)

    def __call__(self, x, out_old, alpha):
        """
        Forward pass of the ResNet block.

        x: tensor of shape (N, in_dim_x)
        out_old: tensor of shape (N, in_dim_out)
        alpha: scalar parameter controlling the amplitude of the residual update.

        return: out_new = out_old + alpha * F(x)
        """
        residual = self.res_mlp(x)
        out_new = out_old + tf.abs(alpha) * residual
        return out_new

# Define the Stacked MLP class for Stacked PINN with ResNet blocks
class StackedMLP(tf.Module):
    """
    Stacked Multi-Layer Perceptron designed for multi-fidelity learning where multiple layers are
    stacked to refine the prediction progressively. Now, each stacked layer is a ResNet block.
    """
    def __init__(
        self,
        insize,
        outsize,
        h_sf_sizes=[20, 20], # The single fidelity hidden size
        n_stacked_mf_layers=3,
        # The residual block hidden sizes for each stacked layer
        h_res_sizes=[20,20,20],
        bias=True,
        nonlin=tf.tanh,
        alpha_init=0.1,
        u_initial=None
    ):
        super().__init__()
        self.insize = insize
        self.outsize = outsize
        self.h_sf_sizes = h_sf_sizes
        self.n_stacked_mf_layers = n_stacked_mf_layers
        self.h_res_sizes = h_res_sizes
        self.bias = bias
        self.nonlin = nonlin
        self.alpha_init = alpha_init
        
        if u_initial is None:
            self.u0 = tf.zeros(shape=(outsize, 1), dtype=tf.float32)
        else:
            self.u0 = u_initial

        # Initial single-fidelity MLP
        self.first_layer = MLP(insize, outsize, hsizes=h_sf_sizes, bias=bias, nonlin=nonlin)

        # Alpha parameters, one per stacked layer
        self.alpha = [tf.Variable(0.0, trainable=True)] + [tf.Variable(alpha_init, trainable=True) for _ in range(n_stacked_mf_layers)]

        # Considering each stacked layer as a ResNet block
        self.layers = []
        for _ in range(n_stacked_mf_layers):
            res_block = ResNetBlock(insize, outsize, hres_sizes=self.h_res_sizes, bias=bias, nonlin=nonlin)
            self.layers.append(res_block)

    def __call__(self, x, i=None):
        if i is None:
            i = self.n_stacked_mf_layers
        i = min(i, self.n_stacked_mf_layers)

        # First layer (single-fidelity MLP)
        out = self.first_layer(x)
        out_old = tf.zeros_like(out)
        residual = out
        
        # Apply stacked ResNet blocks up to layer i
        for j in range(i):
            alpha = self.alpha[j+1]
            layer = self.layers[j]
            # Each layer: out = out + alpha * res_mlp(x)
            out_old = out
            out = layer(x, out_old, alpha)
            residual = out - out_old
        #return out_new, out_old, and residual
        return self.u0 + tf.tanh(x) * out, self.u0 + tf.tanh(x) * out_old, tf.tanh(x) * residual

    def get_alpha_loss(self, i=None):
        """
        Retrieve the accumulated loss from alpha parameters used for regularization purposes.

        :return: Alpha loss as a torch scalar.
        """
        return tf.pow(self.alpha[i], 4)

# Numerical solution for the Van Der Pol Oscillator
def analytical_solution(n_steps, mu=3.0, T_max=2.0, u_0=[1.0, 0.0]):
    """
    Numerical solution of the Van der Pol oscillator using the RK4 method.

    Arguments:
    - n_steps: number of time steps
    - mu     : nonlinearity/damping parameter of the Van der Pol equation
    - T_max  : final time
    - u_0    : initial state [x1(0), x2(0)], where:
            x1 = position
            x2 = velocity

    Returns:
    - x: trajectory (n_steps, 2), position and velocity over time
    - t: time array (n_steps,)
    """
    dt = T_max / float(n_steps)
    t = np.arange(0, n_steps * dt, dt)
    x = np.zeros((n_steps, 2))
    x[0, :] = u_0
    
    def vdp(t, x):
        x1, x2 = x
        dx1 = x2
        dx2 = mu * (1 - x1**2) * x2 - x1
        return np.array([dx1, dx2])
    
    for i in range(n_steps - 1):
        k1 = vdp(t[i], x[i])
        k2 = vdp(t[i] + dt/2, x[i] + dt/2 * k1)
        k3 = vdp(t[i] + dt/2, x[i] + dt/2 * k2)
        k4 = vdp(t[i] + dt, x[i] + dt * k3)
        x[i+1] = x[i] + dt/6 * (k1 + 2*k2 + 2*k3 + k4)

    return tf.convert_to_tensor(x, dtype=tf.float32), tf.convert_to_tensor(t, dtype=tf.float32)

# Define the L2 relative error function
def l2_relative_error(u_pred, u_true):
    """
    Compute L2 relative error between predicted values and true values.

    Parameters:
    u_pred (Tensor): Predicted values (model output)
    u_true (Tensor): True values (ground truth)

    Returns:
    float: L2 relative error
    """
    error = tf.norm(u_pred - u_true, ord=2) / tf.norm(u_true, ord=2)
    return error.numpy().item()

# Define the Stacked PINN class with modifications to store losses
class StackedResPINN:
    def __init__(self, model, optimizer_primal, optimizer_dual, lr_scheduler=None, patience=100, patience_gamma=100, N_collocation=1000, N_resample=50, N_dual=10, gammas_init=[], parameters_init=3.0, logger=None, T_max=2.0):
        self.model = model
        self.optimizer_primal = optimizer_primal
        self.optimizer_dual = optimizer_dual
        self.lr_scheduler = lr_scheduler
        self.logger = logger
        self.n_stacked_layers = model.n_stacked_mf_layers+1  # Number of stacked layers (Using for averaging loss) +1 for vanilla layer 0
        self.N_phys = N_collocation
        self.N_resample = N_resample
        self.N_dual = N_dual
        # Early stopping attributes
        self.patience = patience
        self.patience_gamma = patience_gamma
        self.best_loss = 0.0
        self.bad_epochs = 0
        self.bad_epochs_gamma = 0

        self.T_max = T_max
        self.weight = tf.Variable(1.0, dtype=tf.float32)
        self.parameters = parameters_init
        self.mu = self.parameters

        self.epsilon = tf.Variable(1.0e-2, dtype=tf.float32, trainable=False)
        self.omegas_t = tf.Variable(tf.zeros((self.n_stacked_layers, N_collocation), dtype=tf.float32), trainable=False)

        self.K = 0  # K is the index of the stack being updated
        self.update_count = 1

        # initialize the sequence alpha and the sitffness sigma of each stack
        self.gammas = tf.Variable(initial_value=gammas_init, trainable=False)
        self.old_gammas = self.gammas # for early stopping check
        self.sigma = tf.Variable(initial_value= (-1.0e-3) * tf.ones([self.n_stacked_layers], dtype=tf.float32),trainable=False)

    def resample(self):
        t_collocation = tf.random.uniform(shape=(self.N_phys, 1), minval=0, maxval=self.T_max)
        return t_collocation


    #############################       UPDATE ALPHA        ############################

    def cummin(self, x):
        """ 
        function cummin to force the sequence gamma_i to be nondecreasing:
            - takes a sequence a_i as entry
            - returns a sequence where each term gamma_i = min(gamma_i, gamma_i+1) begining with the first term
        """
        x = tf.convert_to_tensor(x)
        x_list = tf.unstack(x)

        out = []
        current_min = x_list[0]
        out.append(current_min)

        for xi in x_list[1:]:
            current_min = tf.minimum(current_min, xi)
            out.append(current_min)

        return tf.stack(out)
    
    def update_stiffness_indicators(self, t):
        """
        compute the stiffness indicator of each stack at each time t* = = argmin(sigma_N(t))
        """
        # compute the current solution of each stack
        u1 = []
        for k in range(self.n_stacked_layers):
            U, _, _ = self.model(t, i=k)
            u1.append(U[:, 0:1])
        u1 = tf.squeeze(tf.stack(u1, axis=1), axis=2)

        #compute sigma
        sigma = self.mu * (1.0 - u1**2) / 2.0

        # get t* = argmin(sigma_N(t)) and get each sigma_i at t*
        last_layer_sigma = sigma[:, -1]
        min_index = tf.argmin(last_layer_sigma)
        sigma_at_min_index = sigma[min_index, :]
        self.sigma.assign(self.cummin(sigma_at_min_index))

    def update_gammas(self, smoothing_coef, t):
        """
        updates the sequence gamma_i depending on the stiffness gamma_i of the solution of each stack:
            - gamma_i = (i+1)/(N+1) * sigma_N(t*)/sigma_i(t*)
            - t* = argmin(sigma_N(t))
        """
        self.update_stiffness_indicators(t)
        i_s = tf.cumsum(tf.ones([self.n_stacked_layers], dtype=tf.float32))

        # compute each new gamma_i
        alpha_i = tf.abs((i_s*self.sigma[-1]) / (self.n_stacked_layers*self.sigma))

        new_gammas = tf.minimum(alpha_i, tf.ones([self.n_stacked_layers], dtype=tf.float32))   # force gamma_i to range between 0 and 1
        new_gammas = tf.reverse(self.cummin(tf.reverse(new_gammas, axis=[0])), axis=[0]) # prevent each gamma_i to be higher than gamma_(i+1)
        new_gammas = tf.stop_gradient((1 - smoothing_coef) * self.gammas + smoothing_coef * new_gammas) # smooth gamma and prevent gradient propagation through its computation
        self.gammas.assign(new_gammas)


    #############################       LOSS       ############################

    def f(self, u1, u2, alpha):
        term1 = u2
        term2 = alpha * self.mu * (1 - tf.square(u1)) * u2 - u1
        return [term1, term2]

    @tf.function
    def loss_function(self, t, k):
        """
        loss function to compute the residual loss of stack k
            - k is the index of the stack currently being optimized
        """
        losses = []
        omegas_t = []
        inp = t

        for i in range(self.n_stacked_layers):
            if i == k:  # if i is the index of the stack currently being optimized
                if i ==0:
                    with tf.GradientTape(watch_accessed_variables=False) as tape1:
                        tape1.watch(inp)
                        U, _, _ = self.model(inp, i=i)
                    U_t = tape1.batch_jacobian(U, inp)
                    u1 = U[:, 0:1]
                    u2 = U[:, 1:2]
                    
                    f = tf.squeeze(U_t, axis=2) - tf.concat(self.f(u1, u2, self.gammas[i]), axis=1)

                else:
                    with tf.GradientTape(watch_accessed_variables=False) as tape1:
                        tape1.watch(inp)
                        U, U_old, R = self.model(inp, i=i)
                    R_t = tape1.batch_jacobian(R, inp)
                    u1 = U[:, 0:1]
                    u2 = U[:, 1:2]
                    u1_old = U_old[:, 0:1]
                    u2_old = U_old[:, 1:2]
                    
                    f = tf.squeeze(R_t, axis=2) - tf.concat(self.f(u1, u2, self.gammas[i]), axis=1) + tf.concat(self.f(u1_old, u2_old, self.gammas[i-1]), axis=1)
                
                f_squared = tf.square(f)
                f_squared_sum = tf.reduce_sum(f_squared, axis=1, keepdims=True)
                f_squared_cumsum = tf.cumsum(f_squared_sum, exclusive=True)
                omega_t = tf.stop_gradient(tf.exp(-self.epsilon * f_squared_cumsum))
                weighted_f_squared = omega_t * f_squared
                
                ode_i = self.weight * tf.reduce_mean(weighted_f_squared) + self.model.get_alpha_loss(i=i)
                
            else:   # if i is NOT the index of the stack currently being optimized, do not comput loss at this stack
                ode_i = 0.0
                u1 = tf.zeros_like(inp[:, :1])
                if i < k:
                    omega_t = tf.stop_gradient(tf.ones((self.N_phys, 1), dtype=tf.float32))
                else:
                    omega_t = tf.stop_gradient(tf.zeros((self.N_phys, 1), dtype=tf.float32))

            omegas_t.append(omega_t)
            losses.append(ode_i)

        self.omegas_t.assign(tf.squeeze(tf.stack(omegas_t, axis=0), axis=-1))

        return losses
    
    def get_target_variables(self, k):
        """
        get weights and biaises theta of stack k to be optimized
        """
        variables = []
        if k == 0:
            variables.extend(self.model.first_layer.trainable_variables)
        else:
            variables.extend(self.model.layers[k-1].trainable_variables)
        variables.append(self.model.alpha[k])
        return variables

    @tf.function
    def total_loss(self, t_collocation, k):
        physics_loss = self.loss_function(t_collocation, k)
        return sum(physics_loss)

    @tf.function
    def primal_update_k(self, t_collocation, target_variables, k):
        with tf.GradientTape(watch_accessed_variables=False) as loss_tape:
            loss_tape.watch(target_variables)
            loss = self.total_loss(t_collocation, k)
        grads = loss_tape.gradient(loss, target_variables)
        self.optimizer_primal[k].apply_gradients(zip(grads, target_variables))
        return loss
    
    def primal_update(self, t_collocation):
        target_variables = self.get_target_variables(self.K)
        loss = self.primal_update_k(t_collocation, target_variables, self.K)
        return loss
    
    @tf.function
    def dual_update(self, t_collocation):
        with tf.GradientTape(watch_accessed_variables=False) as loss_tape:
            loss_tape.watch(self.weight)
            loss = -self.loss_function(t_collocation, self.K)[self.K]
        grads = loss_tape.gradient(loss, [self.weight])
        self.optimizer_dual.apply_gradients(
            zip(grads, [self.weight])
        )
        return -loss


    #############################       TRAIN       ############################

    def train(self, t_collocation, n_stacked_mf_layers, epochs=1000, t_test=None, u_test=None, u_0=[1.0, 0.0]):
        
        """
        initialize the N+1 optimizers
        """
        all_trainable_vars = []
        for j in range(self.n_stacked_layers):
            _ = self.model(t_collocation, i=j)
            _ = self.model.get_alpha_loss(i=j)
            if j > 0:
                all_trainable_vars.extend(self.model.layers[j-1].trainable_variables)
            else:
                all_trainable_vars.extend(self.model.first_layer.trainable_variables)
            all_trainable_vars.append(self.model.alpha[j])

            with tf.GradientTape() as tape:
                dummy_loss = self.total_loss(t_collocation, j)
            dummy_grads = tape.gradient(dummy_loss, all_trainable_vars)
            grads_and_vars = [(g, v) for g, v in zip(dummy_grads, all_trainable_vars) if g is not None]
            self.optimizer_primal[j].apply_gradients(grads_and_vars)

        train_losses, test_losses, l2_errors, gammas, sigma, layer_updated, omegas_t, lambda_phys = ([] for _ in range(8))

        for epoch in range(epochs):

            loss = self.primal_update(t_collocation)
            if epoch % self.N_dual == 0 and epoch > 0: #dual update
                loss = self.dual_update(t_collocation)
            if epoch % self.N_resample == 0 and epoch > 0: #resampling of t_collocation
                t_collocation = self.resample()

            # Learning rate scheduling if type ReduceLROnPlateau
            if self.lr_scheduler:
                if hasattr(self.lr_scheduler, 'on_epoch_end'):
                    self.lr_scheduler.on_epoch_end(epoch=None, logs={"loss": loss.numpy()})
        
            # Logging
            if self.logger:
                self.logger.log_metrics({"loss": loss.numpy()}, step=epoch)

            # passing to next stack check
            if tf.reduce_mean(self.omegas_t[self.K]).numpy() > self.best_loss:
                self.best_loss = tf.reduce_mean(self.omegas_t[self.K]).numpy()
                self.bad_epochs = 0
            else:
                self.bad_epochs += 1

            if (self.bad_epochs >= self.patience and self.omegas_t[self.K][-1] > 0.9) or self.bad_epochs >= 2000:
                self.best_loss = 0.0
                print(f"self.omegas_t[self.K][-1] : {self.omegas_t[self.K][-1]}, loss.numpy() : {loss.numpy()}")
                if self.K < self.n_stacked_layers-1 and self.bad_epochs < 1000:
                    print(f"stack {self.K} has converged, passing to the next stack")
                    self.K += 1
                    self.bad_epochs = 0
                else:
                    print("all stacks converged, updating gammas")
                    self.update_gammas(smoothing_coef=0.1, t=t_collocation)
                    if self.epsilon <= 1.0e-1:
                        self.epsilon.assign(self.epsilon * 10.0)
                    self.K = 0
                    self.bad_epochs = 0
                    self.update_count += 1
                    
                    # update u_test to visualize convergence with new gammas
                    n_steps = int(5e3)
                    u_test = []
                    for i in range(n_stacked_mf_layers+1):
                        u_t, _ = analytical_solution(n_steps, mu=self.mu * self.gammas[i], T_max=self.T_max, u_0=u_0)
                        u_test.append(u_t)

                    # early stopping check
                    if tf.reduce_mean(tf.square(self.gammas - self.old_gammas)) > 1.0e-2:
                        self.old_gammas = self.gammas
                        self.bad_epochs_gamma = 0
                    else:
                        self.bad_epochs_gamma += 1

                    if self.bad_epochs_gamma >= self.patience_gamma:
                        print(f"Early stopping triggered")
                        break                
             
            train_losses.append(loss.numpy())
            gammas.append(self.gammas.numpy().copy())
            sigma.append(self.sigma.numpy().copy())
            layer_updated.append(self.K)
            omegas_t.append(self.omegas_t.numpy().copy())
            lambda_phys.append(self.weight.numpy().copy())

            if epoch % 100 == 0 or epoch == epochs-1:
                # Calculate test loss if test data is provided
                if t_test is not None and u_test is not None:

                    u_pred_test = []
                    for i in range(self.model.n_stacked_mf_layers+1):
                        u_i, _, _ = self.model(t_test, i)
                        u_pred_test.append(u_i)
                    test_loss = [tf.reduce_mean(tf.square(u_pred_test_i - u_test_i)).numpy() for u_pred_test_i, u_test_i  in zip(u_pred_test, u_test)]
                    test_losses.append(test_loss)

                    # Compute L2 relative error
                    l2_error = [l2_relative_error(u_pred_test_i, u_test_i) for u_pred_test_i, u_test_i in zip(u_pred_test, u_test)]
                    l2_errors.append(l2_error)

                print(f"Epoch {epoch}, Loss: {loss.numpy():.4e}, L2 Relative_error: {[f'{err:.4f}' for err in l2_error]}, self.gammas: {[f'{gamma:.4f}' for gamma in self.gammas.numpy()]}, epsilon : {self.epsilon.numpy():.1e}, lambda_phys : {self.weight.numpy():.4f}, layer {self.K} is being updated for the {self.update_count}-th time")

        # Plot losses
        plt.figure(figsize=(10, 5))
        plt.plot(train_losses, label="Training Loss")
        if test_losses:
            # test_losses is a list of lists, one per epoch. Plotting the mean test loss across layers.
            mean_test_losses = [np.mean(tl) for tl in test_losses]
            plt.plot(mean_test_losses, label="Test Loss", color="orange")
        plt.xlabel("Epochs")
        plt.ylabel("Loss")
        plt.title("Training and Test Loss")
        plt.legend()
        plt.grid(True)
        plt.savefig("losses over epochs.eps", format='eps')
        plt.show()

         # Plot L2 relative error over epochs
        if l2_errors:  # Check if l2_errors is not empty
            plt.figure()
            plt.plot(range(len(l2_errors)), l2_errors, label=[f"L2 Relative Error{i}" for i in range (n_stacked_mf_layers+1)])
            plt.xlabel("Epochs")
            plt.ylabel("L2 Relative Error")
            plt.title("L2 Relative Error over Training Epochs")
            plt.yscale("log")
            plt.legend()
            plt.grid(True)
            plt.savefig("L2 relative error over epochs.eps", format='eps')
            plt.show()

        # plot final output vs analytical solution
        t_test = tf.reshape(t_test, [-1]).numpy()
        sorted_indices = np.argsort(t_test)
        t_sorted = t_test[sorted_indices]
        
        u_pred_np = u_pred_test[-1].numpy()
        u_sorted = u_pred_np[sorted_indices]
        u_true_np = u_test[-1].numpy()
        u_true_sorted = u_true_np[sorted_indices]

        plt.figure(figsize=(10, 4))
        plt.subplot(3, 1, 1)
        plt.plot(t_sorted, u_sorted[:, 0], label='x_hat1')
        plt.plot(t_sorted, u_true_sorted[:, 0], label='x1')
        plt.xlabel("Time")
        plt.ylabel("State")
        plt.legend()
        plt.grid(True)
        plt.show()

        plt.figure(figsize=(10, 4))
        plt.subplot(3, 1, 2)
        plt.plot(t_sorted, u_sorted[:, 1], label='x_hat2')
        plt.plot(t_sorted, u_true_sorted[:, 1], label='x2')
        plt.xlabel("Time")
        plt.ylabel("State")
        plt.legend()
        plt.grid(True)
        plt.show()

        # Plot gammas over epochs
        gammas_np = np.array([alph for alph in gammas])
        plt.figure()
        for i in range(gammas_np.shape[1]):
            plt.plot(range(len(gammas_np)), gammas_np[:, i], label=f"gamma_{i}")
        plt.xlabel("Epochs")
        plt.ylabel(f"gamma values")
        plt.title("gamma over Training Epochs")
        plt.grid(True)
        plt.legend()
        plt.savefig("gammas over epochs.eps", format='eps')
        plt.show()
        
        # Plot sigmas over epochs
        sigma_np = np.array([sigm for sigm in sigma])
        plt.figure()
        for i in range(sigma_np.shape[1]):
            plt.plot(range(len(sigma_np)), sigma_np[:, i], label=f"sigma_{i}")
        plt.xlabel("Epochs")
        plt.ylabel(f"sigma values")
        plt.yscale('symlog', linthresh=1e-3)
        plt.title("sigma over Training Epochs")
        plt.grid(True)
        plt.legend()
        plt.savefig("sigma over epochs.eps", format='eps')
        plt.show()

        # Plot k over epochs
        plt.figure()
        plt.plot(range(len(layer_updated)), layer_updated, label="layer_updated")
        plt.xlabel("Epochs")
        plt.ylabel(f"layer_updated values")
        plt.title("layer_updated over Training Epochs")
        plt.grid(True)
        plt.legend()
        plt.savefig("K over epochs.eps", format='eps')
        plt.show()

        # Plot lambda_phys over epochs
        plt.figure()
        plt.plot(range(len(lambda_phys)), lambda_phys, label="lambda_phys")
        plt.xlabel("Epochs")
        plt.ylabel(f"lambda_phys values")
        plt.title("lambda_phys over Training Epochs")
        plt.grid(True)
        plt.legend()
        plt.savefig("lambda_phys over epochs.eps", format='eps')
        plt.show()

# %%
if __name__ == "__main__":
    # Parameters
    T_max = 3.0
    real_mu = 4.0
    n_stacked_mf_layers = 3
    u_0=[1.0, 0.0]
    insize = 1  # Input size (t)
    outsize = 2  # Output size (u)
    h_sf_sizes = [40, 40, 40]
    # Residual block hidden sizes
    h_res_sizes = [40, 40, 40]
    gammas_init = []
    
    for i in range(n_stacked_mf_layers+1):
        gammas_init.append((i+1)/(n_stacked_mf_layers+1))
    print(f'gammas_init : {gammas_init}')

    # Initial condition
    N_initial = 1
    t_initial = tf.zeros(shape=(N_initial, 1), dtype=tf.float32)
    u_initial = tf.convert_to_tensor([u_0] * N_initial, dtype=tf.float32)

    # Create model
    model = StackedMLP(insize, outsize, h_sf_sizes=h_sf_sizes, h_res_sizes=h_res_sizes,
                       n_stacked_mf_layers=n_stacked_mf_layers, alpha_init=0.05, u_initial=u_initial)

    optimizer_primal = [tf.keras.optimizers.legacy.Adam(learning_rate=1e-3)] + [tf.keras.optimizers.legacy.Adam(learning_rate=1e-4) for _ in range(n_stacked_mf_layers)]
    optimizer_dual = tf.keras.optimizers.legacy.Adam(learning_rate=1e-3)

    # Test points (optional for validation/testing)
    n_steps = int(5e3)
    u_tests = []
    for i in range(n_stacked_mf_layers+1):
        u_test, t_test = analytical_solution(n_steps, mu=gammas_init[i]*real_mu, T_max=T_max, u_0=u_0)
        u_tests.append(u_test)
    t_test = tf.reshape(t_test, (-1, 1))

    # Create collocation points
    N_collocation = 1000
    t_collocation = tf.random.uniform(shape=(N_collocation, 1), minval=0, maxval=T_max)

    # Create instance of Stacked Residual PINN
    pinn = StackedResPINN(model, optimizer_primal, optimizer_dual, gammas_init=gammas_init, parameters_init=real_mu, T_max=T_max)

    # Train the model with test data for loss visualization
    pinn.train(t_collocation, n_stacked_mf_layers, epochs=300000, t_test=t_test, u_test=u_tests, u_0=u_0)
# Out:
# gammas_init : [0.25, 0.5, 0.75, 1.0]
# 2025-08-12 11:47:33.095844: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# Epoch 0, Loss: 5.0054e-02, L2 Relative_error: ['1.0454', '1.0568', '1.0585', '1.0575'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0000, layer 0 is being updated for the 1-th time
# Epoch 100, Loss: 4.2852e-02, L2 Relative_error: ['0.6557', '0.7692', '0.8194', '0.8505'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0100, layer 0 is being updated for the 1-th time
# Epoch 200, Loss: 4.2095e-02, L2 Relative_error: ['0.6457', '0.7627', '0.8150', '0.8472'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0199, layer 0 is being updated for the 1-th time
# Epoch 300, Loss: 3.6182e-02, L2 Relative_error: ['0.4052', '0.5774', '0.6716', '0.7315'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0296, layer 0 is being updated for the 1-th time
# Epoch 400, Loss: 3.1390e-02, L2 Relative_error: ['0.3497', '0.5774', '0.6901', '0.7566'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0387, layer 0 is being updated for the 1-th time
# Epoch 500, Loss: 2.7766e-02, L2 Relative_error: ['0.3002', '0.5586', '0.6835', '0.7552'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0470, layer 0 is being updated for the 1-th time
# Epoch 600, Loss: 1.7846e-02, L2 Relative_error: ['0.2176', '0.5123', '0.6596', '0.7415'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0546, layer 0 is being updated for the 1-th time
# Epoch 700, Loss: 3.1012e-03, L2 Relative_error: ['0.0358', '0.4163', '0.6123', '0.7157'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0599, layer 0 is being updated for the 1-th time
# Epoch 800, Loss: 9.7294e-04, L2 Relative_error: ['0.0200', '0.4095', '0.6111', '0.7168'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0625, layer 0 is being updated for the 1-th time
# Epoch 900, Loss: 3.8384e-04, L2 Relative_error: ['0.0093', '0.4118', '0.6146', '0.7203'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0637, layer 0 is being updated for the 1-th time
# Epoch 1000, Loss: 1.8380e-04, L2 Relative_error: ['0.0043', '0.4140', '0.6170', '0.7223'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0642, layer 0 is being updated for the 1-th time
# Epoch 1100, Loss: 1.2623e-04, L2 Relative_error: ['0.0021', '0.4143', '0.6176', '0.7230'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0645, layer 0 is being updated for the 1-th time
# Epoch 1200, Loss: 1.9677e-04, L2 Relative_error: ['0.0028', '0.4150', '0.6181', '0.7233'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0647, layer 0 is being updated for the 1-th time
# Epoch 1300, Loss: 3.2083e-04, L2 Relative_error: ['0.0037', '0.4146', '0.6180', '0.7233'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0648, layer 0 is being updated for the 1-th time
# Epoch 1400, Loss: 6.2642e-05, L2 Relative_error: ['0.0012', '0.4145', '0.6180', '0.7233'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0649, layer 0 is being updated for the 1-th time
# Epoch 1500, Loss: 5.5975e-05, L2 Relative_error: ['0.0013', '0.4142', '0.6177', '0.7231'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0649, layer 0 is being updated for the 1-th time
# Epoch 1600, Loss: 1.9015e-04, L2 Relative_error: ['0.0045', '0.4138', '0.6173', '0.7228'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0650, layer 0 is being updated for the 1-th time
# Epoch 1700, Loss: 3.7835e-05, L2 Relative_error: ['0.0011', '0.4141', '0.6177', '0.7232'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0650, layer 0 is being updated for the 1-th time
# Epoch 1800, Loss: 3.5041e-05, L2 Relative_error: ['0.0009', '0.4142', '0.6178', '0.7232'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0651, layer 0 is being updated for the 1-th time
# Epoch 1900, Loss: 8.2917e-05, L2 Relative_error: ['0.0020', '0.4150', '0.6184', '0.7237'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0652, layer 0 is being updated for the 1-th time
# Epoch 2000, Loss: 2.5578e-05, L2 Relative_error: ['0.0012', '0.4153', '0.6187', '0.7239'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0653, layer 0 is being updated for the 1-th time
# Epoch 2100, Loss: 2.1913e-05, L2 Relative_error: ['0.0007', '0.4148', '0.6183', '0.7236'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0653, layer 0 is being updated for the 1-th time
# Epoch 2200, Loss: 2.0585e-05, L2 Relative_error: ['0.0006', '0.4143', '0.6179', '0.7233'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0654, layer 0 is being updated for the 1-th time
# Epoch 2300, Loss: 1.9356e-05, L2 Relative_error: ['0.0008', '0.4145', '0.6179', '0.7233'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0655, layer 0 is being updated for the 1-th time
# Epoch 2400, Loss: 1.5601e-05, L2 Relative_error: ['0.0005', '0.4146', '0.6181', '0.7235'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0655, layer 0 is being updated for the 1-th time
# Epoch 2500, Loss: 3.3727e-05, L2 Relative_error: ['0.0013', '0.4151', '0.6185', '0.7238'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0656, layer 0 is being updated for the 1-th time
# Epoch 2600, Loss: 1.3040e-05, L2 Relative_error: ['0.0008', '0.4140', '0.6177', '0.7232'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0658, layer 0 is being updated for the 1-th time
# self.omegas_t[self.K][-1] : 0.9948970079421997, loss.numpy() : 0.000272016623057425
# stack 0 has converged, passing to the next stack
# Epoch 2700, Loss: 2.4780e-04, L2 Relative_error: ['0.0054', '0.4186', '0.6209', '0.7258'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0659, layer 1 is being updated for the 1-th time
# Epoch 2800, Loss: 2.5161e-04, L2 Relative_error: ['0.0054', '0.4211', '0.6223', '0.7268'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0660, layer 1 is being updated for the 1-th time
# Epoch 2900, Loss: 2.4077e-04, L2 Relative_error: ['0.0054', '0.4249', '0.6248', '0.7288'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0662, layer 1 is being updated for the 1-th time
# Epoch 3000, Loss: 2.4800e-04, L2 Relative_error: ['0.0054', '0.4251', '0.6240', '0.7277'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0663, layer 1 is being updated for the 1-th time
# Epoch 3100, Loss: 2.5208e-04, L2 Relative_error: ['0.0054', '0.4324', '0.6295', '0.7322'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0665, layer 1 is being updated for the 1-th time
# Epoch 3200, Loss: 2.5692e-04, L2 Relative_error: ['0.0054', '0.4515', '0.6411', '0.7406'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0666, layer 1 is being updated for the 1-th time
# Epoch 3300, Loss: 2.4007e-04, L2 Relative_error: ['0.0054', '0.4832', '0.6606', '0.7546'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0668, layer 1 is being updated for the 1-th time
# Epoch 3400, Loss: 2.6980e-04, L2 Relative_error: ['0.0054', '0.4929', '0.6662', '0.7583'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0670, layer 1 is being updated for the 1-th time
# Epoch 3500, Loss: 2.4326e-04, L2 Relative_error: ['0.0054', '0.4898', '0.6642', '0.7567'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0671, layer 1 is being updated for the 1-th time
# Epoch 3600, Loss: 2.6134e-04, L2 Relative_error: ['0.0054', '0.4940', '0.6665', '0.7582'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0673, layer 1 is being updated for the 1-th time
# Epoch 3700, Loss: 2.4096e-04, L2 Relative_error: ['0.0054', '0.4938', '0.6666', '0.7583'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0675, layer 1 is being updated for the 1-th time
# Epoch 3800, Loss: 2.4121e-04, L2 Relative_error: ['0.0054', '0.4945', '0.6668', '0.7581'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0676, layer 1 is being updated for the 1-th time
# Epoch 3900, Loss: 2.6310e-04, L2 Relative_error: ['0.0054', '0.4995', '0.6705', '0.7610'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0678, layer 1 is being updated for the 1-th time
# Epoch 4000, Loss: 2.4645e-04, L2 Relative_error: ['0.0054', '0.4974', '0.6691', '0.7598'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0680, layer 1 is being updated for the 1-th time
# Epoch 4100, Loss: 2.5015e-04, L2 Relative_error: ['0.0054', '0.4979', '0.6695', '0.7600'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0682, layer 1 is being updated for the 1-th time
# Epoch 4200, Loss: 2.6754e-04, L2 Relative_error: ['0.0054', '0.5015', '0.6718', '0.7615'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0684, layer 1 is being updated for the 1-th time
# Epoch 4300, Loss: 2.5865e-04, L2 Relative_error: ['0.0054', '0.5025', '0.6723', '0.7617'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0686, layer 1 is being updated for the 1-th time
# Epoch 4400, Loss: 2.5956e-04, L2 Relative_error: ['0.0054', '0.5019', '0.6717', '0.7610'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0688, layer 1 is being updated for the 1-th time
# Epoch 4500, Loss: 2.5028e-04, L2 Relative_error: ['0.0054', '0.5004', '0.6715', '0.7611'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0690, layer 1 is being updated for the 1-th time
# Epoch 4600, Loss: 2.4554e-04, L2 Relative_error: ['0.0054', '0.5015', '0.6724', '0.7619'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0692, layer 1 is being updated for the 1-th time
# Epoch 4700, Loss: 2.5147e-04, L2 Relative_error: ['0.0054', '0.5015', '0.6724', '0.7619'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0694, layer 1 is being updated for the 1-th time
# Epoch 4800, Loss: 2.6206e-04, L2 Relative_error: ['0.0054', '0.5011', '0.6725', '0.7622'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0696, layer 1 is being updated for the 1-th time
# Epoch 4900, Loss: 2.3991e-04, L2 Relative_error: ['0.0054', '0.5016', '0.6729', '0.7622'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0698, layer 1 is being updated for the 1-th time
# Epoch 5000, Loss: 2.5004e-04, L2 Relative_error: ['0.0054', '0.5010', '0.6729', '0.7626'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0700, layer 1 is being updated for the 1-th time
# Epoch 5100, Loss: 2.5808e-04, L2 Relative_error: ['0.0054', '0.5020', '0.6731', '0.7624'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0702, layer 1 is being updated for the 1-th time
# Epoch 5200, Loss: 2.4579e-04, L2 Relative_error: ['0.0054', '0.5011', '0.6734', '0.7630'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0704, layer 1 is being updated for the 1-th time
# Epoch 5300, Loss: 2.4080e-04, L2 Relative_error: ['0.0054', '0.5025', '0.6745', '0.7640'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0707, layer 1 is being updated for the 1-th time
# Epoch 5400, Loss: 2.4332e-04, L2 Relative_error: ['0.0054', '0.4994', '0.6725', '0.7626'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0709, layer 1 is being updated for the 1-th time
# Epoch 5500, Loss: 2.5005e-04, L2 Relative_error: ['0.0054', '0.4997', '0.6729', '0.7631'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0711, layer 1 is being updated for the 1-th time
# Epoch 5600, Loss: 2.4554e-04, L2 Relative_error: ['0.0054', '0.5006', '0.6745', '0.7648'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0713, layer 1 is being updated for the 1-th time
# Epoch 5700, Loss: 2.5104e-04, L2 Relative_error: ['0.0054', '0.4997', '0.6737', '0.7641'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0716, layer 1 is being updated for the 1-th time
# Epoch 5800, Loss: 2.4525e-04, L2 Relative_error: ['0.0054', '0.4985', '0.6729', '0.7636'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0718, layer 1 is being updated for the 1-th time
# Epoch 5900, Loss: 2.2863e-04, L2 Relative_error: ['0.0054', '0.4964', '0.6725', '0.7639'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0720, layer 1 is being updated for the 1-th time
# Epoch 6000, Loss: 2.3043e-04, L2 Relative_error: ['0.0054', '0.4977', '0.6736', '0.7648'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0723, layer 1 is being updated for the 1-th time
# Epoch 6100, Loss: 2.5324e-04, L2 Relative_error: ['0.0054', '0.4977', '0.6740', '0.7653'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0725, layer 1 is being updated for the 1-th time
# Epoch 6200, Loss: 2.4910e-04, L2 Relative_error: ['0.0054', '0.4973', '0.6746', '0.7661'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0727, layer 1 is being updated for the 1-th time
# Epoch 6300, Loss: 2.5096e-04, L2 Relative_error: ['0.0054', '0.4964', '0.6747', '0.7665'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0730, layer 1 is being updated for the 1-th time
# Epoch 6400, Loss: 2.5794e-04, L2 Relative_error: ['0.0054', '0.4969', '0.6757', '0.7676'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0732, layer 1 is being updated for the 1-th time
# Epoch 6500, Loss: 2.4521e-04, L2 Relative_error: ['0.0054', '0.4909', '0.6729', '0.7663'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0735, layer 1 is being updated for the 1-th time
# Epoch 6600, Loss: 2.5026e-04, L2 Relative_error: ['0.0054', '0.4905', '0.6735', '0.7670'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0738, layer 1 is being updated for the 1-th time
# Epoch 6700, Loss: 2.5129e-04, L2 Relative_error: ['0.0054', '0.4867', '0.6724', '0.7672'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0740, layer 1 is being updated for the 1-th time
# Epoch 6800, Loss: 2.4930e-04, L2 Relative_error: ['0.0054', '0.4844', '0.6721', '0.7675'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0743, layer 1 is being updated for the 1-th time
# Epoch 6900, Loss: 2.5335e-04, L2 Relative_error: ['0.0054', '0.4831', '0.6731', '0.7693'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0745, layer 1 is being updated for the 1-th time
# Epoch 7000, Loss: 2.5459e-04, L2 Relative_error: ['0.0054', '0.4760', '0.6709', '0.7692'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0748, layer 1 is being updated for the 1-th time
# Epoch 7100, Loss: 2.4469e-04, L2 Relative_error: ['0.0054', '0.4694', '0.6695', '0.7697'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0751, layer 1 is being updated for the 1-th time
# Epoch 7200, Loss: 2.2782e-04, L2 Relative_error: ['0.0054', '0.4618', '0.6681', '0.7705'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0753, layer 1 is being updated for the 1-th time
# Epoch 7300, Loss: 2.4748e-04, L2 Relative_error: ['0.0054', '0.4577', '0.6705', '0.7749'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0756, layer 1 is being updated for the 1-th time
# Epoch 7400, Loss: 2.3799e-04, L2 Relative_error: ['0.0054', '0.4327', '0.6608', '0.7721'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0759, layer 1 is being updated for the 1-th time
# Epoch 7500, Loss: 2.4058e-04, L2 Relative_error: ['0.0054', '0.4141', '0.6576', '0.7744'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0761, layer 1 is being updated for the 1-th time
# Epoch 7600, Loss: 2.6133e-04, L2 Relative_error: ['0.0054', '0.3922', '0.6536', '0.7782'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0764, layer 1 is being updated for the 1-th time
# Epoch 7700, Loss: 2.4970e-04, L2 Relative_error: ['0.0054', '0.3634', '0.6436', '0.7779'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0767, layer 1 is being updated for the 1-th time
# Epoch 7800, Loss: 2.5276e-04, L2 Relative_error: ['0.0054', '0.3270', '0.6245', '0.7697'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0770, layer 1 is being updated for the 1-th time
# Epoch 7900, Loss: 2.2892e-04, L2 Relative_error: ['0.0054', '0.2725', '0.5876', '0.7468'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0773, layer 1 is being updated for the 1-th time
# Epoch 8000, Loss: 2.4471e-04, L2 Relative_error: ['0.0054', '0.2291', '0.5564', '0.7266'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0775, layer 1 is being updated for the 1-th time
# Epoch 8100, Loss: 2.2998e-04, L2 Relative_error: ['0.0054', '0.1968', '0.5323', '0.7104'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0778, layer 1 is being updated for the 1-th time
# Epoch 8200, Loss: 2.6307e-04, L2 Relative_error: ['0.0054', '0.1682', '0.5102', '0.6949'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0781, layer 1 is being updated for the 1-th time
# Epoch 8300, Loss: 2.6737e-04, L2 Relative_error: ['0.0054', '0.1433', '0.4907', '0.6811'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0784, layer 1 is being updated for the 1-th time
# Epoch 8400, Loss: 2.4701e-04, L2 Relative_error: ['0.0054', '0.1272', '0.4780', '0.6722'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0787, layer 1 is being updated for the 1-th time
# Epoch 8500, Loss: 2.5027e-04, L2 Relative_error: ['0.0054', '0.1126', '0.4665', '0.6641'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0790, layer 1 is being updated for the 1-th time
# Epoch 8600, Loss: 2.4907e-04, L2 Relative_error: ['0.0054', '0.1060', '0.4613', '0.6604'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0793, layer 1 is being updated for the 1-th time
# self.omegas_t[self.K][-1] : 0.9759489297866821, loss.numpy() : 0.005636531859636307
# stack 1 has converged, passing to the next stack
# Epoch 8700, Loss: 2.3886e-04, L2 Relative_error: ['0.0054', '0.0959', '0.4532', '0.6546'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0796, layer 2 is being updated for the 1-th time
# Epoch 8800, Loss: 2.5775e-04, L2 Relative_error: ['0.0054', '0.0959', '0.4613', '0.6609'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0799, layer 2 is being updated for the 1-th time
# Epoch 8900, Loss: 2.5787e-04, L2 Relative_error: ['0.0054', '0.0959', '0.4622', '0.6617'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0802, layer 2 is being updated for the 1-th time
# Epoch 9000, Loss: 2.5682e-04, L2 Relative_error: ['0.0054', '0.0959', '0.4588', '0.6590'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0806, layer 2 is being updated for the 1-th time
# Epoch 9100, Loss: 2.4462e-04, L2 Relative_error: ['0.0054', '0.0959', '0.4613', '0.6610'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0809, layer 2 is being updated for the 1-th time
# Epoch 9200, Loss: 2.5492e-04, L2 Relative_error: ['0.0054', '0.0959', '0.4641', '0.6631'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0812, layer 2 is being updated for the 1-th time
# Epoch 9300, Loss: 2.4383e-04, L2 Relative_error: ['0.0054', '0.0959', '0.4640', '0.6628'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0815, layer 2 is being updated for the 1-th time
# Epoch 9400, Loss: 2.4212e-04, L2 Relative_error: ['0.0054', '0.0959', '0.4665', '0.6645'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0818, layer 2 is being updated for the 1-th time
# Epoch 9500, Loss: 2.6616e-04, L2 Relative_error: ['0.0054', '0.0959', '0.4780', '0.6718'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0822, layer 2 is being updated for the 1-th time
# Epoch 9600, Loss: 2.3834e-04, L2 Relative_error: ['0.0054', '0.0959', '0.4956', '0.6827'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0825, layer 2 is being updated for the 1-th time
# Epoch 9700, Loss: 2.5021e-04, L2 Relative_error: ['0.0054', '0.0959', '0.4997', '0.6857'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0828, layer 2 is being updated for the 1-th time
# Epoch 9800, Loss: 2.5176e-04, L2 Relative_error: ['0.0054', '0.0959', '0.5017', '0.6876'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0832, layer 2 is being updated for the 1-th time
# Epoch 9900, Loss: 2.4829e-04, L2 Relative_error: ['0.0054', '0.0959', '0.5039', '0.6896'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0835, layer 2 is being updated for the 1-th time
# Epoch 10000, Loss: 2.6214e-04, L2 Relative_error: ['0.0054', '0.0959', '0.5055', '0.6913'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0839, layer 2 is being updated for the 1-th time
# Epoch 10100, Loss: 2.7462e-04, L2 Relative_error: ['0.0054', '0.0959', '0.5071', '0.6922'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0842, layer 2 is being updated for the 1-th time
# Epoch 10200, Loss: 2.6770e-04, L2 Relative_error: ['0.0054', '0.0959', '0.5108', '0.6945'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0846, layer 2 is being updated for the 1-th time
# Epoch 10300, Loss: 2.4854e-04, L2 Relative_error: ['0.0054', '0.0959', '0.5112', '0.6944'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0849, layer 2 is being updated for the 1-th time
# Epoch 10400, Loss: 2.4912e-04, L2 Relative_error: ['0.0054', '0.0959', '0.5121', '0.6948'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0853, layer 2 is being updated for the 1-th time
# Epoch 10500, Loss: 2.4121e-04, L2 Relative_error: ['0.0054', '0.0959', '0.5152', '0.6972'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0856, layer 2 is being updated for the 1-th time
# Epoch 10600, Loss: 2.5458e-04, L2 Relative_error: ['0.0054', '0.0959', '0.5161', '0.6980'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0860, layer 2 is being updated for the 1-th time
# Epoch 10700, Loss: 2.6578e-04, L2 Relative_error: ['0.0054', '0.0959', '0.5170', '0.6981'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0864, layer 2 is being updated for the 1-th time
# Epoch 10800, Loss: 2.4782e-04, L2 Relative_error: ['0.0054', '0.0959', '0.5174', '0.6988'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0867, layer 2 is being updated for the 1-th time
# Epoch 10900, Loss: 2.6065e-04, L2 Relative_error: ['0.0054', '0.0959', '0.5188', '0.7000'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0871, layer 2 is being updated for the 1-th time
# Epoch 11000, Loss: 2.5377e-04, L2 Relative_error: ['0.0054', '0.0959', '0.5188', '0.7000'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0875, layer 2 is being updated for the 1-th time
# Epoch 11100, Loss: 2.6971e-04, L2 Relative_error: ['0.0054', '0.0959', '0.5188', '0.7007'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0878, layer 2 is being updated for the 1-th time
# Epoch 11200, Loss: 2.4630e-04, L2 Relative_error: ['0.0054', '0.0959', '0.5192', '0.7014'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0882, layer 2 is being updated for the 1-th time
# Epoch 11300, Loss: 2.5637e-04, L2 Relative_error: ['0.0054', '0.0959', '0.5192', '0.7013'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0886, layer 2 is being updated for the 1-th time
# Epoch 11400, Loss: 2.7459e-04, L2 Relative_error: ['0.0054', '0.0959', '0.5198', '0.7014'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0890, layer 2 is being updated for the 1-th time
# Epoch 11500, Loss: 2.2942e-04, L2 Relative_error: ['0.0054', '0.0959', '0.5198', '0.7020'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0894, layer 2 is being updated for the 1-th time
# Epoch 11600, Loss: 2.5478e-04, L2 Relative_error: ['0.0054', '0.0959', '0.5198', '0.7024'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0898, layer 2 is being updated for the 1-th time
# Epoch 11700, Loss: 2.3559e-04, L2 Relative_error: ['0.0054', '0.0959', '0.5196', '0.7027'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0902, layer 2 is being updated for the 1-th time
# Epoch 11800, Loss: 2.5393e-04, L2 Relative_error: ['0.0054', '0.0959', '0.5214', '0.7037'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0905, layer 2 is being updated for the 1-th time
# Epoch 11900, Loss: 2.5790e-04, L2 Relative_error: ['0.0054', '0.0959', '0.5207', '0.7040'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0909, layer 2 is being updated for the 1-th time
# Epoch 12000, Loss: 2.4862e-04, L2 Relative_error: ['0.0054', '0.0959', '0.5208', '0.7042'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0913, layer 2 is being updated for the 1-th time
# Epoch 12100, Loss: 2.4709e-04, L2 Relative_error: ['0.0054', '0.0959', '0.5213', '0.7046'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0917, layer 2 is being updated for the 1-th time
# Epoch 12200, Loss: 2.6129e-04, L2 Relative_error: ['0.0054', '0.0959', '0.5222', '0.7059'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0921, layer 2 is being updated for the 1-th time
# Epoch 12300, Loss: 2.7002e-04, L2 Relative_error: ['0.0054', '0.0959', '0.5227', '0.7063'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0926, layer 2 is being updated for the 1-th time
# Epoch 12400, Loss: 2.7806e-04, L2 Relative_error: ['0.0054', '0.0959', '0.5222', '0.7064'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0930, layer 2 is being updated for the 1-th time
# Epoch 12500, Loss: 2.6177e-04, L2 Relative_error: ['0.0054', '0.0959', '0.5228', '0.7076'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0934, layer 2 is being updated for the 1-th time
# Epoch 12600, Loss: 2.4066e-04, L2 Relative_error: ['0.0054', '0.0959', '0.5227', '0.7075'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0938, layer 2 is being updated for the 1-th time
# Epoch 12700, Loss: 2.4751e-04, L2 Relative_error: ['0.0054', '0.0959', '0.5237', '0.7089'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0942, layer 2 is being updated for the 1-th time
# Epoch 12800, Loss: 2.6668e-04, L2 Relative_error: ['0.0054', '0.0959', '0.5251', '0.7098'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0947, layer 2 is being updated for the 1-th time
# Epoch 12900, Loss: 2.6502e-04, L2 Relative_error: ['0.0054', '0.0959', '0.5234', '0.7093'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0951, layer 2 is being updated for the 1-th time
# Epoch 13000, Loss: 2.6622e-04, L2 Relative_error: ['0.0054', '0.0959', '0.5250', '0.7108'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0955, layer 2 is being updated for the 1-th time
# Epoch 13100, Loss: 2.3590e-04, L2 Relative_error: ['0.0054', '0.0959', '0.5248', '0.7120'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0960, layer 2 is being updated for the 1-th time
# Epoch 13200, Loss: 2.4857e-04, L2 Relative_error: ['0.0054', '0.0959', '0.5252', '0.7132'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0964, layer 2 is being updated for the 1-th time
# Epoch 13300, Loss: 2.6278e-04, L2 Relative_error: ['0.0054', '0.0959', '0.5278', '0.7150'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0969, layer 2 is being updated for the 1-th time
# Epoch 13400, Loss: 2.4815e-04, L2 Relative_error: ['0.0054', '0.0959', '0.5284', '0.7162'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0973, layer 2 is being updated for the 1-th time
# Epoch 13500, Loss: 2.3128e-04, L2 Relative_error: ['0.0054', '0.0959', '0.5303', '0.7182'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0977, layer 2 is being updated for the 1-th time
# Epoch 13600, Loss: 2.6015e-04, L2 Relative_error: ['0.0054', '0.0959', '0.5299', '0.7191'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0982, layer 2 is being updated for the 1-th time
# Epoch 13700, Loss: 2.4180e-04, L2 Relative_error: ['0.0054', '0.0959', '0.5294', '0.7198'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0986, layer 2 is being updated for the 1-th time
# Epoch 13800, Loss: 2.4231e-04, L2 Relative_error: ['0.0054', '0.0959', '0.5308', '0.7218'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0990, layer 2 is being updated for the 1-th time
# Epoch 13900, Loss: 2.4450e-04, L2 Relative_error: ['0.0054', '0.0959', '0.5321', '0.7238'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0995, layer 2 is being updated for the 1-th time
# Epoch 14000, Loss: 2.7186e-04, L2 Relative_error: ['0.0054', '0.0959', '0.5315', '0.7249'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.0999, layer 2 is being updated for the 1-th time
# Epoch 14100, Loss: 2.4333e-04, L2 Relative_error: ['0.0054', '0.0959', '0.5316', '0.7270'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.1004, layer 2 is being updated for the 1-th time
# Epoch 14200, Loss: 2.6422e-04, L2 Relative_error: ['0.0054', '0.0959', '0.5329', '0.7298'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.1009, layer 2 is being updated for the 1-th time
# Epoch 14300, Loss: 2.6253e-04, L2 Relative_error: ['0.0054', '0.0959', '0.5313', '0.7312'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.1013, layer 2 is being updated for the 1-th time
# Epoch 14400, Loss: 2.6480e-04, L2 Relative_error: ['0.0054', '0.0959', '0.5351', '0.7372'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.1018, layer 2 is being updated for the 1-th time
# Epoch 14500, Loss: 2.5005e-04, L2 Relative_error: ['0.0054', '0.0959', '0.5369', '0.7429'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.1023, layer 2 is being updated for the 1-th time
# Epoch 14600, Loss: 2.5427e-04, L2 Relative_error: ['0.0054', '0.0959', '0.5385', '0.7483'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.1028, layer 2 is being updated for the 1-th time
# Epoch 14700, Loss: 2.7123e-04, L2 Relative_error: ['0.0054', '0.0959', '0.5445', '0.7564'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.1033, layer 2 is being updated for the 1-th time
# Epoch 14800, Loss: 2.4842e-04, L2 Relative_error: ['0.0054', '0.0959', '0.5474', '0.7621'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.1038, layer 2 is being updated for the 1-th time
# Epoch 14900, Loss: 2.7364e-04, L2 Relative_error: ['0.0054', '0.0959', '0.5456', '0.7634'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.1042, layer 2 is being updated for the 1-th time
# Epoch 15000, Loss: 2.5015e-04, L2 Relative_error: ['0.0054', '0.0959', '0.5404', '0.7618'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.1047, layer 2 is being updated for the 1-th time
# Epoch 15100, Loss: 2.6892e-04, L2 Relative_error: ['0.0054', '0.0959', '0.5399', '0.7624'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.1052, layer 2 is being updated for the 1-th time
# Epoch 15200, Loss: 2.6344e-04, L2 Relative_error: ['0.0054', '0.0959', '0.5345', '0.7596'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.1057, layer 2 is being updated for the 1-th time
# Epoch 15300, Loss: 2.4563e-04, L2 Relative_error: ['0.0054', '0.0959', '0.5298', '0.7571'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.1062, layer 2 is being updated for the 1-th time
# Epoch 15400, Loss: 2.3506e-04, L2 Relative_error: ['0.0054', '0.0959', '0.5242', '0.7535'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.1067, layer 2 is being updated for the 1-th time
# Epoch 15500, Loss: 2.6579e-04, L2 Relative_error: ['0.0054', '0.0959', '0.5198', '0.7508'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.1072, layer 2 is being updated for the 1-th time
# Epoch 15600, Loss: 2.4056e-04, L2 Relative_error: ['0.0054', '0.0959', '0.5167', '0.7489'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.1077, layer 2 is being updated for the 1-th time
# Epoch 15700, Loss: 2.5635e-04, L2 Relative_error: ['0.0054', '0.0959', '0.5123', '0.7460'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.1082, layer 2 is being updated for the 1-th time
# Epoch 15800, Loss: 2.6302e-04, L2 Relative_error: ['0.0054', '0.0959', '0.5082', '0.7435'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.1087, layer 2 is being updated for the 1-th time
# Epoch 15900, Loss: 2.9805e-04, L2 Relative_error: ['0.0054', '0.0959', '0.5041', '0.7407'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.1092, layer 2 is being updated for the 1-th time
# Epoch 16000, Loss: 2.4054e-04, L2 Relative_error: ['0.0054', '0.0959', '0.4986', '0.7371'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.1098, layer 2 is being updated for the 1-th time
# Epoch 16100, Loss: 2.5870e-04, L2 Relative_error: ['0.0054', '0.0959', '0.4949', '0.7347'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.1103, layer 2 is being updated for the 1-th time
# self.omegas_t[self.K][-1] : 0.9089584946632385, loss.numpy() : 0.007920987904071808
# stack 2 has converged, passing to the next stack
# Epoch 16200, Loss: 2.5743e-04, L2 Relative_error: ['0.0054', '0.0959', '0.4918', '0.7344'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.1108, layer 3 is being updated for the 1-th time
# Epoch 16300, Loss: 2.5345e-04, L2 Relative_error: ['0.0054', '0.0959', '0.4918', '0.7365'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.1113, layer 3 is being updated for the 1-th time
# Epoch 16400, Loss: 2.5693e-04, L2 Relative_error: ['0.0054', '0.0959', '0.4918', '0.7371'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.1119, layer 3 is being updated for the 1-th time
# Epoch 16500, Loss: 2.8629e-04, L2 Relative_error: ['0.0054', '0.0959', '0.4918', '0.7356'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.1124, layer 3 is being updated for the 1-th time
# Epoch 16600, Loss: 2.5671e-04, L2 Relative_error: ['0.0054', '0.0959', '0.4918', '0.7372'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.1130, layer 3 is being updated for the 1-th time
# Epoch 16700, Loss: 2.6032e-04, L2 Relative_error: ['0.0054', '0.0959', '0.4918', '0.7381'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.1135, layer 3 is being updated for the 1-th time
# Epoch 16800, Loss: 2.6308e-04, L2 Relative_error: ['0.0054', '0.0959', '0.4918', '0.7393'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.1141, layer 3 is being updated for the 1-th time
# Epoch 16900, Loss: 2.6943e-04, L2 Relative_error: ['0.0054', '0.0959', '0.4918', '0.7431'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.1146, layer 3 is being updated for the 1-th time
# Epoch 17000, Loss: 2.8264e-04, L2 Relative_error: ['0.0054', '0.0959', '0.4918', '0.7467'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.1152, layer 3 is being updated for the 1-th time
# Epoch 17100, Loss: 2.5818e-04, L2 Relative_error: ['0.0054', '0.0959', '0.4918', '0.7510'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.1158, layer 3 is being updated for the 1-th time
# Epoch 17200, Loss: 2.7144e-04, L2 Relative_error: ['0.0054', '0.0959', '0.4918', '0.7546'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.1163, layer 3 is being updated for the 1-th time
# Epoch 17300, Loss: 2.6706e-04, L2 Relative_error: ['0.0054', '0.0959', '0.4918', '0.7583'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.1169, layer 3 is being updated for the 1-th time
# Epoch 17400, Loss: 2.3321e-04, L2 Relative_error: ['0.0054', '0.0959', '0.4918', '0.7594'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.1175, layer 3 is being updated for the 1-th time
# Epoch 17500, Loss: 2.7403e-04, L2 Relative_error: ['0.0054', '0.0959', '0.4918', '0.7618'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.1180, layer 3 is being updated for the 1-th time
# Epoch 17600, Loss: 2.5502e-04, L2 Relative_error: ['0.0054', '0.0959', '0.4918', '0.7622'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.1186, layer 3 is being updated for the 1-th time
# Epoch 17700, Loss: 2.6057e-04, L2 Relative_error: ['0.0054', '0.0959', '0.4918', '0.7617'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.1192, layer 3 is being updated for the 1-th time
# Epoch 17800, Loss: 2.6536e-04, L2 Relative_error: ['0.0054', '0.0959', '0.4918', '0.7615'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.1197, layer 3 is being updated for the 1-th time
# Epoch 17900, Loss: 2.6093e-04, L2 Relative_error: ['0.0054', '0.0959', '0.4918', '0.7621'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.1203, layer 3 is being updated for the 1-th time
# Epoch 18000, Loss: 2.5256e-04, L2 Relative_error: ['0.0054', '0.0959', '0.4918', '0.7615'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.1209, layer 3 is being updated for the 1-th time
# Epoch 18100, Loss: 2.8305e-04, L2 Relative_error: ['0.0054', '0.0959', '0.4918', '0.7597'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.1215, layer 3 is being updated for the 1-th time
# Epoch 18200, Loss: 2.5427e-04, L2 Relative_error: ['0.0054', '0.0959', '0.4918', '0.7586'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.1221, layer 3 is being updated for the 1-th time
# Epoch 18300, Loss: 2.7953e-04, L2 Relative_error: ['0.0054', '0.0959', '0.4918', '0.7591'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.1227, layer 3 is being updated for the 1-th time
# Epoch 18400, Loss: 2.7613e-04, L2 Relative_error: ['0.0054', '0.0959', '0.4918', '0.7582'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.1233, layer 3 is being updated for the 1-th time
# Epoch 18500, Loss: 2.6252e-04, L2 Relative_error: ['0.0054', '0.0959', '0.4918', '0.7600'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.1240, layer 3 is being updated for the 1-th time
# Epoch 18600, Loss: 2.7994e-04, L2 Relative_error: ['0.0054', '0.0959', '0.4918', '0.7598'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.1246, layer 3 is being updated for the 1-th time
# Epoch 18700, Loss: 2.7173e-04, L2 Relative_error: ['0.0054', '0.0959', '0.4918', '0.7590'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.1252, layer 3 is being updated for the 1-th time
# Epoch 18800, Loss: 2.7303e-04, L2 Relative_error: ['0.0054', '0.0959', '0.4918', '0.7604'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.1259, layer 3 is being updated for the 1-th time
# Epoch 18900, Loss: 2.4570e-04, L2 Relative_error: ['0.0054', '0.0959', '0.4918', '0.7614'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.1265, layer 3 is being updated for the 1-th time
# Epoch 19000, Loss: 2.4950e-04, L2 Relative_error: ['0.0054', '0.0959', '0.4918', '0.7609'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.1271, layer 3 is being updated for the 1-th time
# Epoch 19100, Loss: 2.6560e-04, L2 Relative_error: ['0.0054', '0.0959', '0.4918', '0.7619'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.1277, layer 3 is being updated for the 1-th time
# Epoch 19200, Loss: 2.5769e-04, L2 Relative_error: ['0.0054', '0.0959', '0.4918', '0.7631'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.1283, layer 3 is being updated for the 1-th time
# Epoch 19300, Loss: 2.5941e-04, L2 Relative_error: ['0.0054', '0.0959', '0.4918', '0.7631'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.1289, layer 3 is being updated for the 1-th time
# Epoch 19400, Loss: 2.8182e-04, L2 Relative_error: ['0.0054', '0.0959', '0.4918', '0.7642'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.1296, layer 3 is being updated for the 1-th time
# Epoch 19500, Loss: 2.7166e-04, L2 Relative_error: ['0.0054', '0.0959', '0.4918', '0.7654'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.1302, layer 3 is being updated for the 1-th time
# Epoch 19600, Loss: 2.5935e-04, L2 Relative_error: ['0.0054', '0.0959', '0.4918', '0.7657'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.1309, layer 3 is being updated for the 1-th time
# Epoch 19700, Loss: 2.6259e-04, L2 Relative_error: ['0.0054', '0.0959', '0.4918', '0.7667'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.1315, layer 3 is being updated for the 1-th time
# Epoch 19800, Loss: 2.5014e-04, L2 Relative_error: ['0.0054', '0.0959', '0.4918', '0.7671'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.1322, layer 3 is being updated for the 1-th time
# Epoch 19900, Loss: 2.6279e-04, L2 Relative_error: ['0.0054', '0.0959', '0.4918', '0.7682'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.1328, layer 3 is being updated for the 1-th time
# Epoch 20000, Loss: 2.7064e-04, L2 Relative_error: ['0.0054', '0.0959', '0.4918', '0.7696'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.1335, layer 3 is being updated for the 1-th time
# Epoch 20100, Loss: 2.4571e-04, L2 Relative_error: ['0.0054', '0.0959', '0.4918', '0.7699'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.1342, layer 3 is being updated for the 1-th time
# Epoch 20200, Loss: 2.5158e-04, L2 Relative_error: ['0.0054', '0.0959', '0.4918', '0.7704'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.1348, layer 3 is being updated for the 1-th time
# Epoch 20300, Loss: 2.7494e-04, L2 Relative_error: ['0.0054', '0.0959', '0.4918', '0.7707'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.1355, layer 3 is being updated for the 1-th time
# Epoch 20400, Loss: 2.6625e-04, L2 Relative_error: ['0.0054', '0.0959', '0.4918', '0.7720'], self.gammas: ['0.2500', '0.5000', '0.7500', '1.0000'], epsilon : 1.0e-02, lambda_phys : 1.1362, layer 3 is being updated for the 1-th time
# ...
# self.omegas_t[self.K][-1] : 0.9720648527145386, loss.numpy() : 0.0007045227102935314
# all stacks converged, updating gammas
# Epoch 231900, Loss: 1.0749e-03, L2 Relative_error: ['0.0015', '0.0023', '0.0079', '0.0268'], self.gammas: ['0.5407', '0.6597', '0.7980', '1.0000'], epsilon : 1.0e+00, lambda_phys : 11.8367, layer 0 is being updated for the 95-th time
# Epoch 232000, Loss: 3.3426e-05, L2 Relative_error: ['0.0002', '0.0030', '0.0083', '0.0269'], self.gammas: ['0.5407', '0.6597', '0.7980', '1.0000'], epsilon : 1.0e+00, lambda_phys : 11.8458, layer 0 is being updated for the 95-th time
# Epoch 232100, Loss: 1.4832e-03, L2 Relative_error: ['0.0020', '0.0020', '0.0077', '0.0267'], self.gammas: ['0.5407', '0.6597', '0.7980', '1.0000'], epsilon : 1.0e+00, lambda_phys : 11.8556, layer 0 is being updated for the 95-th time
# self.omegas_t[self.K][-1] : 0.9572363495826721, loss.numpy() : 0.00025360900326631963
# stack 0 has converged, passing to the next stack
# Epoch 232200, Loss: 5.7250e-04, L2 Relative_error: ['0.0010', '0.0026', '0.0077', '0.0264'], self.gammas: ['0.5407', '0.6597', '0.7980', '1.0000'], epsilon : 1.0e+00, lambda_phys : 11.8672, layer 1 is being updated for the 95-th time
# Epoch 232300, Loss: 5.4482e-04, L2 Relative_error: ['0.0010', '0.0026', '0.0077', '0.0264'], self.gammas: ['0.5407', '0.6597', '0.7980', '1.0000'], epsilon : 1.0e+00, lambda_phys : 11.8766, layer 1 is being updated for the 95-th time
# self.omegas_t[self.K][-1] : 0.9947006106376648, loss.numpy() : 0.0002440934331389144
# stack 1 has converged, passing to the next stack
# Epoch 232400, Loss: 6.1132e-04, L2 Relative_error: ['0.0010', '0.0026', '0.0074', '0.0260'], self.gammas: ['0.5407', '0.6597', '0.7980', '1.0000'], epsilon : 1.0e+00, lambda_phys : 11.8852, layer 2 is being updated for the 95-th time
# Epoch 232500, Loss: 5.4405e-04, L2 Relative_error: ['0.0010', '0.0026', '0.0073', '0.0259'], self.gammas: ['0.5407', '0.6597', '0.7980', '1.0000'], epsilon : 1.0e+00, lambda_phys : 11.8936, layer 2 is being updated for the 95-th time
# Epoch 232600, Loss: 5.8615e-04, L2 Relative_error: ['0.0010', '0.0026', '0.0073', '0.0259'], self.gammas: ['0.5407', '0.6597', '0.7980', '1.0000'], epsilon : 1.0e+00, lambda_phys : 11.9019, layer 2 is being updated for the 95-th time
# self.omegas_t[self.K][-1] : 0.9949135184288025, loss.numpy() : 0.000236302032135427
# stack 2 has converged, passing to the next stack
# Epoch 232700, Loss: 5.7381e-04, L2 Relative_error: ['0.0010', '0.0026', '0.0071', '0.0248'], self.gammas: ['0.5407', '0.6597', '0.7980', '1.0000'], epsilon : 1.0e+00, lambda_phys : 11.9101, layer 3 is being updated for the 95-th time
# Epoch 232800, Loss: 5.3804e-04, L2 Relative_error: ['0.0010', '0.0026', '0.0071', '0.0251'], self.gammas: ['0.5407', '0.6597', '0.7980', '1.0000'], epsilon : 1.0e+00, lambda_phys : 11.9184, layer 3 is being updated for the 95-th time
# Epoch 232900, Loss: 5.7080e-04, L2 Relative_error: ['0.0010', '0.0026', '0.0071', '0.0250'], self.gammas: ['0.5407', '0.6597', '0.7980', '1.0000'], epsilon : 1.0e+00, lambda_phys : 11.9263, layer 3 is being updated for the 95-th time
# self.omegas_t[self.K][-1] : 0.972884476184845, loss.numpy() : 0.0007009245455265045
# all stacks converged, updating gammas
# Epoch 233000, Loss: 7.0557e-04, L2 Relative_error: ['0.0010', '0.0033', '0.0078', '0.0254'], self.gammas: ['0.5411', '0.6597', '0.7980', '1.0000'], epsilon : 1.0e+00, lambda_phys : 11.9357, layer 0 is being updated for the 96-th time
# self.omegas_t[self.K][-1] : 0.9698901772499084, loss.numpy() : 0.00017981170094572008
# stack 0 has converged, passing to the next stack
# Epoch 233100, Loss: 2.8508e-04, L2 Relative_error: ['0.0007', '0.0021', '0.0070', '0.0250'], self.gammas: ['0.5411', '0.6597', '0.7980', '1.0000'], epsilon : 1.0e+00, lambda_phys : 11.9482, layer 1 is being updated for the 96-th time
# Epoch 233200, Loss: 2.9399e-04, L2 Relative_error: ['0.0007', '0.0022', '0.0070', '0.0251'], self.gammas: ['0.5411', '0.6597', '0.7980', '1.0000'], epsilon : 1.0e+00, lambda_phys : 11.9560, layer 1 is being updated for the 96-th time
# self.omegas_t[self.K][-1] : 0.995456337928772, loss.numpy() : 0.00023899550433270633
# stack 1 has converged, passing to the next stack
# Epoch 233300, Loss: 2.9363e-04, L2 Relative_error: ['0.0007', '0.0022', '0.0070', '0.0251'], self.gammas: ['0.5411', '0.6597', '0.7980', '1.0000'], epsilon : 1.0e+00, lambda_phys : 11.9614, layer 2 is being updated for the 96-th time
# Epoch 233400, Loss: 2.8946e-04, L2 Relative_error: ['0.0007', '0.0022', '0.0070', '0.0251'], self.gammas: ['0.5411', '0.6597', '0.7980', '1.0000'], epsilon : 1.0e+00, lambda_phys : 11.9660, layer 2 is being updated for the 96-th time
# self.omegas_t[self.K][-1] : 0.994870662689209, loss.numpy() : 0.00023707994841970503
# stack 2 has converged, passing to the next stack
# Epoch 233500, Loss: 2.8340e-04, L2 Relative_error: ['0.0007', '0.0022', '0.0069', '0.0252'], self.gammas: ['0.5411', '0.6597', '0.7980', '1.0000'], epsilon : 1.0e+00, lambda_phys : 11.9703, layer 3 is being updated for the 96-th time
# Epoch 233600, Loss: 2.8968e-04, L2 Relative_error: ['0.0007', '0.0022', '0.0069', '0.0252'], self.gammas: ['0.5411', '0.6597', '0.7980', '1.0000'], epsilon : 1.0e+00, lambda_phys : 11.9745, layer 3 is being updated for the 96-th time
# Epoch 233700, Loss: 2.8747e-04, L2 Relative_error: ['0.0007', '0.0022', '0.0069', '0.0249'], self.gammas: ['0.5411', '0.6597', '0.7980', '1.0000'], epsilon : 1.0e+00, lambda_phys : 11.9787, layer 3 is being updated for the 96-th time
# Epoch 233800, Loss: 2.8204e-04, L2 Relative_error: ['0.0007', '0.0022', '0.0069', '0.0249'], self.gammas: ['0.5411', '0.6597', '0.7980', '1.0000'], epsilon : 1.0e+00, lambda_phys : 11.9829, layer 3 is being updated for the 96-th time
# self.omegas_t[self.K][-1] : 0.9731733202934265, loss.numpy() : 0.0007036435417830944
# all stacks converged, updating gammas
# Epoch 233900, Loss: 5.1707e-04, L2 Relative_error: ['0.0008', '0.0029', '0.0073', '0.0249'], self.gammas: ['0.5407', '0.6594', '0.7978', '1.0000'], epsilon : 1.0e+00, lambda_phys : 11.9870, layer 0 is being updated for the 97-th time
# Epoch 234000, Loss: 9.7145e-04, L2 Relative_error: ['0.0013', '0.0035', '0.0076', '0.0248'], self.gammas: ['0.5407', '0.6594', '0.7978', '1.0000'], epsilon : 1.0e+00, lambda_phys : 11.9931, layer 0 is being updated for the 97-th time
# Epoch 234100, Loss: 5.6659e-04, L2 Relative_error: ['0.0010', '0.0032', '0.0075', '0.0248'], self.gammas: ['0.5407', '0.6594', '0.7978', '1.0000'], epsilon : 1.0e+00, lambda_phys : 12.0002, layer 0 is being updated for the 97-th time
# self.omegas_t[self.K][-1] : 0.9544188380241394, loss.numpy() : 0.00027352673350833356
# stack 0 has converged, passing to the next stack
# Epoch 234200, Loss: 2.9551e-04, L2 Relative_error: ['0.0009', '0.0032', '0.0077', '0.0250'], self.gammas: ['0.5407', '0.6594', '0.7978', '1.0000'], epsilon : 1.0e+00, lambda_phys : 12.0061, layer 1 is being updated for the 97-th time
# Epoch 234300, Loss: 2.8309e-04, L2 Relative_error: ['0.0009', '0.0032', '0.0076', '0.0250'], self.gammas: ['0.5407', '0.6594', '0.7978', '1.0000'], epsilon : 1.0e+00, lambda_phys : 12.0110, layer 1 is being updated for the 97-th time
# self.omegas_t[self.K][-1] : 0.9954943656921387, loss.numpy() : 0.00023811522987671196
# stack 1 has converged, passing to the next stack
# Epoch 234400, Loss: 2.7732e-04, L2 Relative_error: ['0.0009', '0.0032', '0.0079', '0.0253'], self.gammas: ['0.5407', '0.6594', '0.7978', '1.0000'], epsilon : 1.0e+00, lambda_phys : 12.0154, layer 2 is being updated for the 97-th time
# Epoch 234500, Loss: 2.8371e-04, L2 Relative_error: ['0.0009', '0.0032', '0.0077', '0.0252'], self.gammas: ['0.5407', '0.6594', '0.7978', '1.0000'], epsilon : 1.0e+00, lambda_phys : 12.0197, layer 2 is being updated for the 97-th time
# Epoch 234600, Loss: 2.8471e-04, L2 Relative_error: ['0.0009', '0.0032', '0.0076', '0.0251'], self.gammas: ['0.5407', '0.6594', '0.7978', '1.0000'], epsilon : 1.0e+00, lambda_phys : 12.0240, layer 2 is being updated for the 97-th time
# self.omegas_t[self.K][-1] : 0.9951744675636292, loss.numpy() : 0.0002356174954911694
# stack 2 has converged, passing to the next stack
# Epoch 234700, Loss: 2.9470e-04, L2 Relative_error: ['0.0009', '0.0032', '0.0076', '0.0253'], self.gammas: ['0.5407', '0.6594', '0.7978', '1.0000'], epsilon : 1.0e+00, lambda_phys : 12.0283, layer 3 is being updated for the 97-th time
# self.omegas_t[self.K][-1] : 0.972629189491272, loss.numpy() : 0.0007075045723468065
# all stacks converged, updating gammas
# Epoch 234800, Loss: 2.2841e-03, L2 Relative_error: ['0.0032', '0.0036', '0.0078', '0.0257'], self.gammas: ['0.5426', '0.6603', '0.7981', '1.0000'], epsilon : 1.0e+00, lambda_phys : 12.0330, layer 0 is being updated for the 98-th time
# Epoch 234900, Loss: 1.5399e-03, L2 Relative_error: ['0.0015', '0.0036', '0.0081', '0.0259'], self.gammas: ['0.5426', '0.6603', '0.7981', '1.0000'], epsilon : 1.0e+00, lambda_phys : 12.0452, layer 0 is being updated for the 98-th time
# self.omegas_t[self.K][-1] : 0.9058079123497009, loss.numpy() : 0.0005674546118825674
# stack 0 has converged, passing to the next stack
# Epoch 235000, Loss: 2.3055e-04, L2 Relative_error: ['0.0006', '0.0019', '0.0064', '0.0248'], self.gammas: ['0.5426', '0.6603', '0.7981', '1.0000'], epsilon : 1.0e+00, lambda_phys : 12.0557, layer 1 is being updated for the 98-th time
# Epoch 235100, Loss: 2.3461e-04, L2 Relative_error: ['0.0006', '0.0019', '0.0064', '0.0248'], self.gammas: ['0.5426', '0.6603', '0.7981', '1.0000'], epsilon : 1.0e+00, lambda_phys : 12.0616, layer 1 is being updated for the 98-th time
# self.omegas_t[self.K][-1] : 0.9956894516944885, loss.numpy() : 0.00023302722547668964
# stack 1 has converged, passing to the next stack
# Epoch 235200, Loss: 2.2534e-04, L2 Relative_error: ['0.0006', '0.0020', '0.0059', '0.0239'], self.gammas: ['0.5426', '0.6603', '0.7981', '1.0000'], epsilon : 1.0e+00, lambda_phys : 12.0660, layer 2 is being updated for the 98-th time
# Epoch 235300, Loss: 2.4023e-04, L2 Relative_error: ['0.0006', '0.0020', '0.0058', '0.0239'], self.gammas: ['0.5426', '0.6603', '0.7981', '1.0000'], epsilon : 1.0e+00, lambda_phys : 12.0698, layer 2 is being updated for the 98-th time
# Epoch 235400, Loss: 2.1764e-04, L2 Relative_error: ['0.0006', '0.0020', '0.0058', '0.0238'], self.gammas: ['0.5426', '0.6603', '0.7981', '1.0000'], epsilon : 1.0e+00, lambda_phys : 12.0734, layer 2 is being updated for the 98-th time
# self.omegas_t[self.K][-1] : 0.9956302642822266, loss.numpy() : 0.0002311305288458243
# stack 2 has converged, passing to the next stack
# Epoch 235500, Loss: 2.1800e-04, L2 Relative_error: ['0.0006', '0.0020', '0.0057', '0.0224'], self.gammas: ['0.5426', '0.6603', '0.7981', '1.0000'], epsilon : 1.0e+00, lambda_phys : 12.0768, layer 3 is being updated for the 98-th time
# Epoch 235600, Loss: 2.2951e-04, L2 Relative_error: ['0.0006', '0.0020', '0.0057', '0.0230'], self.gammas: ['0.5426', '0.6603', '0.7981', '1.0000'], epsilon : 1.0e+00, lambda_phys : 12.0802, layer 3 is being updated for the 98-th time
# Epoch 235700, Loss: 2.3416e-04, L2 Relative_error: ['0.0006', '0.0020', '0.0057', '0.0228'], self.gammas: ['0.5426', '0.6603', '0.7981', '1.0000'], epsilon : 1.0e+00, lambda_phys : 12.0837, layer 3 is being updated for the 98-th time
# self.omegas_t[self.K][-1] : 0.9731785655021667, loss.numpy() : 0.0007031908025965095
# all stacks converged, updating gammas
# Epoch 235800, Loss: 8.6407e-04, L2 Relative_error: ['0.0016', '0.0015', '0.0054', '0.0228'], self.gammas: ['0.5426', '0.6603', '0.7981', '1.0000'], epsilon : 1.0e+00, lambda_phys : 12.0880, layer 0 is being updated for the 99-th time
# self.omegas_t[self.K][-1] : 0.9555087685585022, loss.numpy() : 0.00026952207554131746
# stack 0 has converged, passing to the next stack
# Epoch 235900, Loss: 1.2046e-04, L2 Relative_error: ['0.0005', '0.0024', '0.0060', '0.0230'], self.gammas: ['0.5426', '0.6603', '0.7981', '1.0000'], epsilon : 1.0e+00, lambda_phys : 12.0985, layer 1 is being updated for the 99-th time
# Epoch 236000, Loss: 1.2567e-04, L2 Relative_error: ['0.0005', '0.0024', '0.0061', '0.0231'], self.gammas: ['0.5426', '0.6603', '0.7981', '1.0000'], epsilon : 1.0e+00, lambda_phys : 12.1043, layer 1 is being updated for the 99-th time
# self.omegas_t[self.K][-1] : 0.9957214593887329, loss.numpy() : 0.00023267316282726824
# stack 1 has converged, passing to the next stack
# Epoch 236100, Loss: 1.2296e-04, L2 Relative_error: ['0.0005', '0.0024', '0.0061', '0.0232'], self.gammas: ['0.5426', '0.6603', '0.7981', '1.0000'], epsilon : 1.0e+00, lambda_phys : 12.1075, layer 2 is being updated for the 99-th time
# Epoch 236200, Loss: 1.2194e-04, L2 Relative_error: ['0.0005', '0.0024', '0.0062', '0.0232'], self.gammas: ['0.5426', '0.6603', '0.7981', '1.0000'], epsilon : 1.0e+00, lambda_phys : 12.1099, layer 2 is being updated for the 99-th time
# self.omegas_t[self.K][-1] : 0.9954478144645691, loss.numpy() : 0.0002321037754882127
# stack 2 has converged, passing to the next stack
# Epoch 236300, Loss: 1.2317e-04, L2 Relative_error: ['0.0005', '0.0024', '0.0062', '0.0233'], self.gammas: ['0.5426', '0.6603', '0.7981', '1.0000'], epsilon : 1.0e+00, lambda_phys : 12.1118, layer 3 is being updated for the 99-th time
# Epoch 236400, Loss: 1.1631e-04, L2 Relative_error: ['0.0005', '0.0024', '0.0062', '0.0232'], self.gammas: ['0.5426', '0.6603', '0.7981', '1.0000'], epsilon : 1.0e+00, lambda_phys : 12.1138, layer 3 is being updated for the 99-th time
# self.omegas_t[self.K][-1] : 0.9737676382064819, loss.numpy() : 0.0007009082473814487
# all stacks converged, updating gammas
# Epoch 236500, Loss: 5.1460e-04, L2 Relative_error: ['0.0011', '0.0031', '0.0069', '0.0239'], self.gammas: ['0.5441', '0.6612', '0.7984', '1.0000'], epsilon : 1.0e+00, lambda_phys : 12.1172, layer 0 is being updated for the 100-th time
# Epoch 236600, Loss: 3.3916e-04, L2 Relative_error: ['0.0009', '0.0025', '0.0065', '0.0238'], self.gammas: ['0.5441', '0.6612', '0.7984', '1.0000'], epsilon : 1.0e+00, lambda_phys : 12.1230, layer 0 is being updated for the 100-th time
# Epoch 236700, Loss: 1.1363e-03, L2 Relative_error: ['0.0017', '0.0026', '0.0065', '0.0238'], self.gammas: ['0.5441', '0.6612', '0.7984', '1.0000'], epsilon : 1.0e+00, lambda_phys : 12.1365, layer 0 is being updated for the 100-th time
# self.omegas_t[self.K][-1] : 0.9389535188674927, loss.numpy() : 0.0003707740397658199
# stack 0 has converged, passing to the next stack
# Epoch 236800, Loss: 1.6069e-04, L2 Relative_error: ['0.0004', '0.0019', '0.0056', '0.0232'], self.gammas: ['0.5441', '0.6612', '0.7984', '1.0000'], epsilon : 1.0e+00, lambda_phys : 12.1524, layer 1 is being updated for the 100-th time
# Epoch 236900, Loss: 1.6579e-04, L2 Relative_error: ['0.0004', '0.0021', '0.0056', '0.0232'], self.gammas: ['0.5441', '0.6612', '0.7984', '1.0000'], epsilon : 1.0e+00, lambda_phys : 12.1605, layer 1 is being updated for the 100-th time
# self.omegas_t[self.K][-1] : 0.9954380989074707, loss.numpy() : 0.00023161608260124922
# stack 1 has converged, passing to the next stack
# Epoch 237000, Loss: 1.5162e-04, L2 Relative_error: ['0.0004', '0.0020', '0.0052', '0.0224'], self.gammas: ['0.5441', '0.6612', '0.7984', '1.0000'], epsilon : 1.0e+00, lambda_phys : 12.1649, layer 2 is being updated for the 100-th time
# self.omegas_t[self.K][-1] : 0.995933473110199, loss.numpy() : 0.00022771887597627938
# stack 2 has converged, passing to the next stack
# Epoch 237100, Loss: 1.6175e-04, L2 Relative_error: ['0.0004', '0.0020', '0.0053', '0.0219'], self.gammas: ['0.5441', '0.6612', '0.7984', '1.0000'], epsilon : 1.0e+00, lambda_phys : 12.1680, layer 3 is being updated for the 100-th time
# Epoch 237200, Loss: 1.6043e-04, L2 Relative_error: ['0.0004', '0.0020', '0.0053', '0.0215'], self.gammas: ['0.5441', '0.6612', '0.7984', '1.0000'], epsilon : 1.0e+00, lambda_phys : 12.1707, layer 3 is being updated for the 100-th time
# self.omegas_t[self.K][-1] : 0.974436342716217, loss.numpy() : 0.0006969465175643563
# all stacks converged, updating gammas
# Early stopping triggered

# %%
for idx,alpha_val in enumerate(model.alpha):
    print(f"alpha_{idx} = {alpha_val}")
# Out:
# alpha_0 = <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=0.0>
# alpha_1 = <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=0.119492084>
# alpha_2 = <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=0.119348325>
# alpha_3 = <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=0.15253423>

# %%
u_pred_test, _, _ = model(t_test)
u_true_test = u_tests[-1]
absolute_error = tf.abs(u_pred_test - u_true_test).numpy()

plt.figure(figsize=(8, 6))
plt.hist(absolute_error, bins=30, alpha=0.75, label=["x1", "x2"], edgecolor='black')
plt.xlabel("Absolute Error")
plt.ylabel("Frequency")
plt.title("Distribution of Absolute Errors")
plt.legend()
plt.grid(True)
plt.savefig("distribution_absolute_errors_vanilla_pinn.eps", format='eps')
plt.show()

# %%
plt.figure(figsize=(6, 4))
plt.boxplot(absolute_error, tick_labels=["x1", "x2"], vert=True)
plt.ylabel('Absolute Error')
plt.title('Error Boxplot')
plt.grid(True)
plt.savefig('error_boxplot_curriculum_stacked_pinn.eps', format='eps')
plt.show()

# %%
"""
Plot the comparison of the output of each stack with the solution it tries to approximate
"""
# get the analytical solution each stack tries to approximate
n_steps = int(5e3)
u_tests = []
for i in range(n_stacked_mf_layers+1):
    u_test, t_test = analytical_solution(n_steps, mu=pinn.gammas[i]*real_mu, T_max=T_max, u_0=u_0)
    u_tests.append(u_test)
t_test = tf.reshape(t_test, (-1, 1))

u_approx = []
r_approx = []
u_old_approx = []
u_true = []
t_test_np =tf.reshape(t_test, [-1]).numpy()
sorted_indices = np.argsort(t_test_np)
t_sorted = t_test_np[sorted_indices]

# get the output of each stack and plot it
for i in range(n_stacked_mf_layers+1):
    u_i, u_old, r_i  = model(t_test, i=i)
    
    u_i_np = u_i.numpy()
    u_i_sorted = u_i_np[sorted_indices]
    u_approx.append(u_i_sorted)
    
    r_i_np = r_i.numpy()
    r_i_sorted = r_i_np[sorted_indices]
    r_approx.append(r_i_sorted)

    u_old_np = u_old.numpy()
    u_old_sorted = u_old_np[sorted_indices]
    u_old_approx.append(u_old_sorted)

    u_true_i_np = u_tests[i].numpy()
    u_true_i_sorted = u_true_i_np[sorted_indices]
    u_true.append(u_true_i_sorted)

    plt.figure(figsize=(10, 4))

    plt.subplot(2, 1, 1)
    plt.plot(t_sorted, u_i_sorted[:, 0], label=f'x_hat1_{i}')
    plt.plot(t_sorted, u_true_i_sorted[:, 0], linestyle='--', linewidth=1, label=f'x1_{i}')
    plt.plot(t_sorted, r_i_sorted[:, 0], linewidth=1, label=f'r_hat1_{i}', color='#A0A0A0')
    plt.plot(t_sorted, u_old_sorted[:, 0], linewidth=1.5, label=f'x_old_hat1_{i}', color='#AAAAAA')
    plt.xlabel("Time")
    plt.ylabel("State")
    plt.title(f"u_approx_{i} vs u_test_{i}")
    plt.legend()
    plt.grid(True)

    plt.subplot(2, 1, 2)
    plt.plot(t_sorted, u_i_sorted[:, 1], label=f'x_hat2_{i}')
    plt.plot(t_sorted, u_true_i_sorted[:, 1], linestyle='--', linewidth=1, label=f'x2_{i}')
    plt.plot(t_sorted, r_i_sorted[:, 1], linewidth=1, label=f'r_hat2_{i}', color='#A0A0A0')
    plt.plot(t_sorted, u_old_sorted[:, 1], linewidth=1.5, label=f'x_old_hat2_{i}', color='#AAAAAA')
    plt.xlabel("Time")
    plt.ylabel("State")
    plt.legend()
    plt.grid(True)
    plt.savefig(f"u_approx_{i} vs u_test_{i}.eps", format='eps')
    plt.show()
